# %% [markdown]
# <a href="https://colab.research.google.com/github/piliroberta/Multiscala_progetto/blob/main/cady_vuoto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Increase the output length 
from notebook.services.config import ConfigManager
cm = ConfigManager().update('notebook', {'limit_output': 10000000})

# %%
#@title Installing GROMACS and related packages
# !apt install gromacs &> /dev/null
# !apt install dssp &> /dev/null
# !ln -s /usr/bin/dssp /usr/local/bin/dssp
# !apt install ghostscript &> /dev/null

# %%
#@title Installing NGLview
# !pip install nglview  &> /dev/null
# !pip install simpletraj  &> /dev/null
# !pip install mdanalysis &> /dev/null
from google.colab import output
output.enable_custom_widget_manager()

# %%
# !mkdir cady_mini

# %%
# !rm position
# Out:
# rm: cannot remove 'position': Is a directory

# %%
# !gmx pdb2gmx -f cady_3.pdb -i posre.itp -p cady.top -o cady.gro -ff amber99sb-ildn  -ignh -heavyh
# Out:
#              :-) GROMACS - gmx pdb2gmx, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx pdb2gmx, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx pdb2gmx -f cady_3.pdb -i posre.itp -p cady.top -o cady.gro -ff amber99sb-ildn -ignh -heavyh
#
#
# Using the Amber99sb-ildn force field in directory amber99sb-ildn.ff
#
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/watermodels.dat
#
# Select the Water Model:
#  1: TIP3P     TIP 3-point, recommended
#  2: TIP4P     TIP 4-point
#  3: TIP4P-Ew  TIP 4-point optimized with Ewald
#  4: TIP5P     TIP 5-point (see http://redmine.gromacs.org/issues/1348 for issues)
#  5: SPC       simple point charge
#  6: SPC/E     extended simple point charge
#  7: None
# 7
# going to rename amber99sb-ildn.ff/aminoacids.r2b
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/aminoacids.r2b
# going to rename amber99sb-ildn.ff/dna.r2b
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/dna.r2b
# going to rename amber99sb-ildn.ff/rna.r2b
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/rna.r2b
# Reading cady_3.pdb...
# Read 'Glycine aRginine prOline Methionine Alanine Cystine Serine in water t= 30000.00000', 188 atoms
# Analyzing pdb file
# Splitting chemical chains based on TER records or chain id changing.
# There are 1 chains and 0 blocks of water and 20 residues with 188 atoms
#
#   chain  #res #atoms
#   1 ' '    20    188
#
# All occupancies are one
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/atomtypes.atp
# Reading residue database... (Amber99sb-ildn)
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/aminoacids.rtp
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/dna.rtp
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/rna.rtp
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/aminoacids.hdb
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/dna.hdb
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/rna.hdb
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/aminoacids.n.tdb
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/aminoacids.c.tdb
# Processing chain 1 (188 atoms, 20 residues)
# Identified residue GLY1 as a starting terminus.
# Identified residue ALA20 as a ending terminus.
# 8 out of 8 lines of specbond.dat converted successfully
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
#
# WARNING: Duplicate line found in or between hackblock and rtp entries
#
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/aminoacids.arn
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/dna.arn
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/rna.arn
# Checking for duplicate atoms....
# Generating any missing hydrogen atoms and/or adding termini.
# Now there are 20 residues with 390 atoms
# Making bonds...
# Number of bonds was 398, now 397
# Generating angles, dihedrals and pairs...
# Before cleaning: 1026 pairs
# Before cleaning: 1060 dihedrals
# Keeping all generated dihedrals
# Making cmap torsions...
# There are 1060 dihedrals,   87 impropers,  712 angles
#           1014 pairs,      397 bonds and     0 virtual sites
# Total mass 2627.276 a.m.u.
# Total charge 5.000 e
# Writing topology
#
# Writing coordinate file...
# 		--------- PLEASE NOTE ------------
# You have successfully generated a topology from: cady_3.pdb.
# The Amber99sb-ildn force field is used.
# 		--------- ETON ESAELP ------------
#
# GROMACS reminds you: "With a Lead Filled Snowshoe" (F. Zappa)

# %%
# !gmx editconf -f cady.gro -o box.gro -c -d 0.8 -bt dodecahedron
# Out:
#              :-) GROMACS - gmx editconf, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx editconf, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx editconf -f cady.gro -o box.gro -c -d 0.8 -bt dodecahedron
#
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 390 atoms
# Volume: 300.422 nm^3, corresponds to roughly 135100 electrons
# No velocities found
#     system size :  2.817  2.570  2.709 (nm)
#     diameter    :  3.341               (nm)
#     center      :  3.408  3.285  3.354 (nm)
#     box vectors :  6.817  6.569  6.708 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  : 300.42               (nm^3)
#     shift       :  0.297  0.421 -1.607 (nm)
# new center      :  3.706  3.706  1.747 (nm)
# new box vectors :  4.941  4.941  4.941 (nm)
# new box angles  :  60.00  60.00  90.00 (degrees)
# new box volume  :  85.28               (nm^3)
#
# GROMACS reminds you: "That Was Really Cool" (Butthead)

# %%
# !gmx solvate -cp box.gro -o solvated.gro -p cadyw.top
# Out:
#              :-) GROMACS - gmx solvate, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx solvate, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx solvate -cp box.gro -o solvated.gro -p cadyw.top
#
# Reading solute configuration
# Reading solvent configuration
#
# Initialising inter-atomic distances...
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary.
#
# NOTE: From version 5.0 gmx solvate uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#
# Generating solvent configuration
# Will generate new solvent configuration of 3x3x2 boxes
# Solvent box contains 10302 atoms in 3434 residues
# Removed 1950 solvent atoms due to solvent-solvent overlap
# Removed 396 solvent atoms due to solute-solvent overlap
# Sorting configuration
# Found 1 molecule type:
#     SOL (   3 atoms):  2652 residues
# Generated solvent containing 7956 atoms in 2652 residues
# Writing generated configuration to solvated.gro
#
# Output configuration contains 8346 atoms in 2672 residues
# Volume                 :     85.2836 (nm^3)
# Density                :     985.313 (g/l)
# Number of solvent molecules:   2652
#
# Processing topology
# Adding line for 2652 solvent molecules with resname (SOL) to topology file (cadyw.top)
#
# Back Off! I just backed up cadyw.top to ./#cadyw.top.1#
#
# GROMACS reminds you: "Two guys can move very fast when they're motivated enough and unemployed" (Eric Betzig)

# %%
# !tail -n 20 cady/solvated.gro
# Out:
#  2006SOL    HW2 6348   4.421   4.242   3.051
#  2007SOL     OW 6349   4.197   4.224   2.053
#  2007SOL    HW1 6350   4.258   4.304   2.057
#  2007SOL    HW2 6351   4.102   4.255   2.060
#  2008SOL     OW 6352   3.987   4.050   2.582
#  2008SOL    HW1 6353   3.908   4.101   2.548
#  2008SOL    HW2 6354   3.978   4.035   2.680
#  2009SOL     OW 6355   4.396   3.927   3.351
#  2009SOL    HW1 6356   4.486   3.911   3.311
#  2009SOL    HW2 6357   4.404   3.932   3.450
#  2010SOL     OW 6358   3.796   3.890   2.180
#  2010SOL    HW1 6359   3.779   3.973   2.126
#  2010SOL    HW2 6360   3.886   3.853   2.158
#  2011SOL     OW 6361   4.152   4.148   2.382
#  2011SOL    HW1 6362   4.182   4.076   2.320
#  2011SOL    HW2 6363   4.113   4.108   2.465
#  2012SOL     OW 6364   4.041   4.271   3.142
#  2012SOL    HW1 6365   4.079   4.212   3.214
#  2012SOL    HW2 6366   4.081   4.245   3.054
#    4.52316   4.52316   3.19836   0.00000   0.00000   0.00000   0.00000   2.26158   2.26158

# %%
# !tail cady/cadyw.top -n 5
# Out:
# [ molecules ]
# ; Compound        #mols
# Protein             1
# SOL              1992

# %%
# !touch dummy.mdp

# %%
# !gmx grompp -f dummy.mdp -c solvated.gro -p cadyw.top -o ions.tpr
# Out:
#               :-) GROMACS - gmx grompp, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx grompp -f dummy.mdp -c solvated.gro -p cadyw.top -o ions.tpr
#
#
# NOTE 1 [file dummy.mdp]:
#   For a correct single-point energy evaluation with nsteps = 0, use
#   continuation = yes to avoid constraining the input coordinates.
#
# Setting the LD random seed to 1612203390
# Generated 2145 of the 2145 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
# Generated 2145 of the 2145 1-4 parameter combinations
# Excluding 3 bonded neighbours molecule type 'Protein'
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# NOTE 2 [file cadyw.top, line 3752]:
#   System has non-zero total charge: 5.000000
#   Total charge should normally be an integer. See
#   http://www.gromacs.org/Documentation/Floating_Point_Arithmetic
#   for discussion on how close it should be to an integer.
#
#
#
# Analysing residue names:
# There are:    20    Protein residues
# There are:  2652      Water residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group rest is 17079.00
#
# NOTE 3 [file dummy.mdp]:
#   NVE simulation with an initial temperature of zero: will use a Verlet
#   buffer of 10%. Check your energy drift!
#
#
# NOTE 4 [file dummy.mdp]:
#   You are using a plain Coulomb cut-off, which might produce artifacts.
#   You might want to consider using PME electrostatics.
#
#
# This run will generate roughly 1 Mb of data
#
# There were 4 notes
#
# GROMACS reminds you: "There is no place like ~" (Anonymous)

# %%
# !echo "SOL" | gmx genion -s ions.tpr -p cadyw.top -o box_ions.gro -conc 0.15 -neutral
# Out:
#               :-) GROMACS - gmx genion, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx genion, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx genion -s ions.tpr -p cadyw.top -o box_ions.gro -conc 0.15 -neutral
#
# Reading file ions.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
# Reading file ions.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
# Will try to add 8 NA ions and 13 CL ions.
# Select a continuous group of solvent molecules
# Group     0 (         System) has  8346 elements
# Group     1 (        Protein) has   390 elements
# Group     2 (      Protein-H) has   188 elements
# Group     3 (        C-alpha) has    20 elements
# Group     4 (       Backbone) has    60 elements
# Group     5 (      MainChain) has    81 elements
# Group     6 (   MainChain+Cb) has   100 elements
# Group     7 (    MainChain+H) has   103 elements
# Group     8 (      SideChain) has   287 elements
# Group     9 (    SideChain-H) has   107 elements
# Group    10 (    Prot-Masses) has   390 elements
# Group    11 (    non-Protein) has  7956 elements
# Group    12 (          Water) has  7956 elements
# Group    13 (            SOL) has  7956 elements
# Group    14 (      non-Water) has   390 elements
# Select a group: Selected 13: 'SOL'
# Number of (3-atomic) solvent molecules: 2652
#
# Processing topology
# Replacing 21 solute molecules in topology file (cadyw.top)  by 8 NA and 13 CL ions.
#
# Back Off! I just backed up cadyw.top to ./#cadyw.top.2#
# Using random seed -902305481.
# Replacing solvent molecule 1160 (atom 3870) with NA
# Replacing solvent molecule 1003 (atom 3399) with NA
# Replacing solvent molecule 689 (atom 2457) with NA
# Replacing solvent molecule 1458 (atom 4764) with NA
# Replacing solvent molecule 230 (atom 1080) with NA
# Replacing solvent molecule 2568 (atom 8094) with NA
# Replacing solvent molecule 1045 (atom 3525) with NA
# Replacing solvent molecule 1292 (atom 4266) with NA
# Replacing solvent molecule 17 (atom 441) with CL
# Replacing solvent molecule 2182 (atom 6936) with CL
# Replacing solvent molecule 720 (atom 2550) with CL
# Replacing solvent molecule 1034 (atom 3492) with CL
# Replacing solvent molecule 1310 (atom 4320) with CL
# Replacing solvent molecule 163 (atom 879) with CL
# Replacing solvent molecule 1261 (atom 4173) with CL
# Replacing solvent molecule 2031 (atom 6483) with CL
# Replacing solvent molecule 150 (atom 840) with CL
# Replacing solvent molecule 1512 (atom 4926) with CL
# Replacing solvent molecule 664 (atom 2382) with CL
# Replacing solvent molecule 2291 (atom 7263) with CL
# Replacing solvent molecule 442 (atom 1716) with CL
#
#
# GROMACS reminds you: "If you open your mind too much, your brains will fall out." (Tim Minchin)

# %%
# !gmx grompp -f template.mdp -p cady.top -c box.gro -o cady.tpr -maxwarn 2
# Out:
#               :-) GROMACS - gmx grompp, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx grompp -f template.mdp -p cady.top -c box.gro -o cady.tpr -maxwarn 2
#
# Ignoring obsolete mdp entry 'ns-type'
# Replacing old mdp entry 'nstxtcout' by 'nstxout-compressed'
#
# NOTE 1 [file template.mdp]:
#   nstcomm < nstcalcenergy defeats the purpose of nstcalcenergy, setting
#   nstcomm to nstcalcenergy
#
# Setting the LD random seed to 1429281816
# Generated 2145 of the 2145 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
# Generated 2145 of the 2145 1-4 parameter combinations
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# NOTE 2 [file cady.top, line 3738]:
#   System has non-zero total charge: 5.000000
#   Total charge should normally be an integer. See
#   http://www.gromacs.org/Documentation/Floating_Point_Arithmetic
#   for discussion on how close it should be to an integer.
#
#
#
# Analysing residue names:
# There are:    20    Protein residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group rest is 1167.00
#
# NOTE 3 [file template.mdp]:
#   You are using a plain Coulomb cut-off, which might produce artifacts.
#   You might want to consider using PME electrostatics.
#
#
# This run will generate roughly 1 Mb of data
#
# There were 3 notes
#
# GROMACS reminds you: "By denying scientific principles, one may maintain any paradox." (Galileo Galilei)

# %%
! gmx mdrun -s cady.tpr -deffnm cadymin -v -ntmpi 2
# Out:
#               :-) GROMACS - gmx mdrun, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx mdrun, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx mdrun -s cady.tpr -deffnm cadymin -v -ntmpi 2
#
# Compiled SIMD: SSE2, but for this host/run AVX2_256 might be better (see log).
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file cady.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
#
# Using 2 MPI threads
# Using 1 OpenMP thread per tMPI thread
#
#
# Steepest Descents:
#    Tolerance (Fmax)   =  1.00000e+01
#    Number of steps    =         1000
# Step=    0, Dmax= 1.0e-02 nm, Epot= -3.83207e+02 Fmax= 6.34641e+03, atom= 81
# Step=    1, Dmax= 1.0e-02 nm, Epot= -1.93660e+03 Fmax= 5.07463e+03, atom= 41
# Step=    3, Dmax= 6.0e-03 nm, Epot= -2.36955e+03 Fmax= 3.65092e+03, atom= 41
# Step=    4, Dmax= 7.2e-03 nm, Epot= -2.44836e+03 Fmax= 5.76181e+03, atom= 41
# Step=    5, Dmax= 8.6e-03 nm, Epot= -2.50904e+03 Fmax= 6.77264e+03, atom= 41
# Step=    6, Dmax= 1.0e-02 nm, Epot= -2.51749e+03 Fmax= 7.63449e+03, atom= 41
# Step=    8, Dmax= 6.2e-03 nm, Epot= -2.79871e+03 Fmax= 1.33209e+03, atom= 41
# Step=   10, Dmax= 3.7e-03 nm, Epot= -2.82608e+03 Fmax= 3.63804e+03, atom= 41
# Step=   11, Dmax= 4.5e-03 nm, Epot= -2.86476e+03 Fmax= 2.83183e+03, atom= 41
# Step=   13, Dmax= 2.7e-03 nm, Epot= -2.89792e+03 Fmax= 9.17592e+02, atom= 41
# Step=   14, Dmax= 3.2e-03 nm, Epot= -2.89993e+03 Fmax= 3.89444e+03, atom= 41
# Step=   15, Dmax= 3.9e-03 nm, Epot= -2.94311e+03 Fmax= 1.55736e+03, atom= 41
# Step=   17, Dmax= 2.3e-03 nm, Epot= -2.95319e+03 Fmax= 1.83111e+03, atom= 41
# Step=   18, Dmax= 2.8e-03 nm, Epot= -2.96074e+03 Fmax= 2.07060e+03, atom= 41
# Step=   19, Dmax= 3.3e-03 nm, Epot= -2.96235e+03 Fmax= 2.77490e+03, atom= 41
# Step=   20, Dmax= 4.0e-03 nm, Epot= -2.96756e+03 Fmax= 2.88909e+03, atom= 41
# Step=   22, Dmax= 2.4e-03 nm, Epot= -2.99530e+03 Fmax= 5.94794e+02, atom= 388
# Step=   24, Dmax= 1.4e-03 nm, Epot= -3.00223e+03 Fmax= 1.79155e+03, atom= 388
# Step=   25, Dmax= 1.7e-03 nm, Epot= -3.01182e+03 Fmax= 7.95521e+02, atom= 388
# Step=   26, Dmax= 2.1e-03 nm, Epot= -3.01540e+03 Fmax= 2.58215e+03, atom= 388
# Step=   27, Dmax= 2.5e-03 nm, Epot= -3.02600e+03 Fmax= 1.17382e+03, atom= 388
# Step=   29, Dmax= 1.5e-03 nm, Epot= -3.03092e+03 Fmax= 1.21607e+03, atom= 388
# Step=   30, Dmax= 1.8e-03 nm, Epot= -3.03543e+03 Fmax= 1.43029e+03, atom= 388
# Step=   31, Dmax= 2.2e-03 nm, Epot= -3.03926e+03 Fmax= 1.98686e+03, atom= 388
# Step=   32, Dmax= 2.6e-03 nm, Epot= -3.04345e+03 Fmax= 1.88537e+03, atom= 388
# Step=   33, Dmax= 3.1e-03 nm, Epot= -3.04518e+03 Fmax= 2.99677e+03, atom= 388
# Step=   34, Dmax= 3.7e-03 nm, Epot= -3.04982e+03 Fmax= 2.62568e+03, atom= 388
# Step=   36, Dmax= 2.2e-03 nm, Epot= -3.05598e+03 Fmax= 8.66119e+02, atom= 388
# Step=   37, Dmax= 2.7e-03 nm, Epot= -3.05901e+03 Fmax= 3.01786e+03, atom= 388
# Step=   38, Dmax= 3.2e-03 nm, Epot= -3.06458e+03 Fmax= 1.99802e+03, atom= 388
# Step=   40, Dmax= 1.9e-03 nm, Epot= -3.06830e+03 Fmax= 8.94381e+02, atom= 388
# Step=   41, Dmax= 2.3e-03 nm, Epot= -3.07034e+03 Fmax= 2.84713e+03, atom= 388
# Step=   42, Dmax= 2.8e-03 nm, Epot= -3.07537e+03 Fmax= 1.34815e+03, atom= 388
# Step=   44, Dmax= 1.7e-03 nm, Epot= -3.07802e+03 Fmax= 1.30154e+03, atom= 388
# Step=   45, Dmax= 2.0e-03 nm, Epot= -3.08030e+03 Fmax= 1.65812e+03, atom= 388
# Step=   46, Dmax= 2.4e-03 nm, Epot= -3.08225e+03 Fmax= 2.13293e+03, atom= 388
# Step=   47, Dmax= 2.9e-03 nm, Epot= -3.08432e+03 Fmax= 2.19267e+03, atom= 388
# Step=   48, Dmax= 3.5e-03 nm, Epot= -3.08448e+03 Fmax= 3.22923e+03, atom= 388
# Step=   49, Dmax= 4.2e-03 nm, Epot= -3.08691e+03 Fmax= 3.04717e+03, atom= 388
# Step=   51, Dmax= 2.5e-03 nm, Epot= -3.09273e+03 Fmax= 8.34849e+02, atom= 388
# Step=   53, Dmax= 1.5e-03 nm, Epot= -3.09494e+03 Fmax= 1.32741e+03, atom= 388
# Step=   54, Dmax= 1.8e-03 nm, Epot= -3.09688e+03 Fmax= 1.52250e+03, atom= 388
# Step=   55, Dmax= 2.2e-03 nm, Epot= -3.09859e+03 Fmax= 1.67744e+03, atom= 388
# Step=   56, Dmax= 2.6e-03 nm, Epot= -3.09956e+03 Fmax= 2.39638e+03, atom= 388
# Step=   57, Dmax= 3.1e-03 nm, Epot= -3.10147e+03 Fmax= 2.26551e+03, atom= 388
# Step=   59, Dmax= 1.9e-03 nm, Epot= -3.10510e+03 Fmax= 6.48309e+02, atom= 388
# Step=   60, Dmax= 2.2e-03 nm, Epot= -3.10659e+03 Fmax= 2.52254e+03, atom= 388
# Step=   61, Dmax= 2.7e-03 nm, Epot= -3.10994e+03 Fmax= 1.66368e+03, atom= 388
# Step=   63, Dmax= 1.6e-03 nm, Epot= -3.11216e+03 Fmax= 7.32375e+02, atom= 388
# Step=   64, Dmax= 1.9e-03 nm, Epot= -3.11286e+03 Fmax= 2.41407e+03, atom= 388
# Step=   65, Dmax= 2.3e-03 nm, Epot= -3.11618e+03 Fmax= 1.06742e+03, atom= 388
# Step=   67, Dmax= 1.4e-03 nm, Epot= -3.11769e+03 Fmax= 1.15685e+03, atom= 388
# Step=   68, Dmax= 1.7e-03 nm, Epot= -3.11903e+03 Fmax= 1.29509e+03, atom= 388
# Step=   69, Dmax= 2.0e-03 nm, Epot= -3.11996e+03 Fmax= 1.88391e+03, atom= 388
# Step=   70, Dmax= 2.4e-03 nm, Epot= -3.12151e+03 Fmax= 1.70481e+03, atom= 388
# Step=   72, Dmax= 1.4e-03 nm, Epot= -3.12380e+03 Fmax= 5.66013e+02, atom= 388
# Step=   73, Dmax= 1.7e-03 nm, Epot= -3.12534e+03 Fmax= 1.85956e+03, atom= 388
# Step=   74, Dmax= 2.1e-03 nm, Epot= -3.12737e+03 Fmax= 1.40234e+03, atom= 388
# Step=   76, Dmax= 1.2e-03 nm, Epot= -3.12905e+03 Fmax= 4.42638e+02, atom= 388
# Step=   77, Dmax= 1.5e-03 nm, Epot= -3.13041e+03 Fmax= 2.08753e+03, atom= 388
# Step=   78, Dmax= 1.8e-03 nm, Epot= -3.13308e+03 Fmax= 5.99119e+02, atom= 388
# Step=   80, Dmax= 1.1e-03 nm, Epot= -3.13433e+03 Fmax= 1.17910e+03, atom= 388
# Step=   81, Dmax= 1.3e-03 nm, Epot= -3.13568e+03 Fmax= 7.20485e+02, atom= 388
# Step=   82, Dmax= 1.5e-03 nm, Epot= -3.13636e+03 Fmax= 1.80919e+03, atom= 388
# Step=   83, Dmax= 1.9e-03 nm, Epot= -3.13829e+03 Fmax= 9.65652e+02, atom= 388
# Step=   85, Dmax= 1.1e-03 nm, Epot= -3.13950e+03 Fmax= 8.28513e+02, atom= 388
# Step=   86, Dmax= 1.3e-03 nm, Epot= -3.14053e+03 Fmax= 1.10476e+03, atom= 388
# Step=   87, Dmax= 1.6e-03 nm, Epot= -3.14142e+03 Fmax= 1.46307e+03, atom= 388
# Step=   88, Dmax= 1.9e-03 nm, Epot= -3.14247e+03 Fmax= 1.39500e+03, atom= 388
# Step=   90, Dmax= 1.2e-03 nm, Epot= -3.14410e+03 Fmax= 4.39224e+02, atom= 388
# Step=   91, Dmax= 1.4e-03 nm, Epot= -3.14558e+03 Fmax= 1.45295e+03, atom= 388
# Step=   92, Dmax= 1.7e-03 nm, Epot= -3.14697e+03 Fmax= 1.18392e+03, atom= 388
# Step=   93, Dmax= 2.0e-03 nm, Epot= -3.14731e+03 Fmax= 1.75520e+03, atom= 388
# Step=   94, Dmax= 2.4e-03 nm, Epot= -3.14804e+03 Fmax= 2.02063e+03, atom= 388
# Step=   95, Dmax= 2.9e-03 nm, Epot= -3.14834e+03 Fmax= 2.28578e+03, atom= 388
# Step=   97, Dmax= 1.7e-03 nm, Epot= -3.15154e+03 Fmax= 4.17672e+02, atom= 388
# Step=   98, Dmax= 2.1e-03 nm, Epot= -3.15229e+03 Fmax= 2.38579e+03, atom= 388
# Step=   99, Dmax= 2.5e-03 nm, Epot= -3.15485e+03 Fmax= 1.50266e+03, atom= 388
# Step=  101, Dmax= 1.5e-03 nm, Epot= -3.15631e+03 Fmax= 7.35904e+02, atom= 388
# Step=  103, Dmax= 8.9e-04 nm, Epot= -3.15721e+03 Fmax= 6.95363e+02, atom= 388
# Step=  104, Dmax= 1.1e-03 nm, Epot= -3.15804e+03 Fmax= 8.75349e+02, atom= 388
# Step=  105, Dmax= 1.3e-03 nm, Epot= -3.15877e+03 Fmax= 1.17162e+03, atom= 388
# Step=  106, Dmax= 1.5e-03 nm, Epot= -3.15959e+03 Fmax= 1.13404e+03, atom= 388
# Step=  107, Dmax= 1.9e-03 nm, Epot= -3.15977e+03 Fmax= 1.79026e+03, atom= 388
# Step=  108, Dmax= 2.2e-03 nm, Epot= -3.16083e+03 Fmax= 1.56193e+03, atom= 388
# Step=  110, Dmax= 1.3e-03 nm, Epot= -3.16251e+03 Fmax= 5.28257e+02, atom= 388
# Step=  111, Dmax= 1.6e-03 nm, Epot= -3.16286e+03 Fmax= 1.77812e+03, atom= 388
# Step=  112, Dmax= 1.9e-03 nm, Epot= -3.16445e+03 Fmax= 1.22404e+03, atom= 388
# Step=  114, Dmax= 1.2e-03 nm, Epot= -3.16559e+03 Fmax= 4.99329e+02, atom= 388
# Step=  115, Dmax= 1.4e-03 nm, Epot= -3.16587e+03 Fmax= 1.75897e+03, atom= 388
# Step=  116, Dmax= 1.7e-03 nm, Epot= -3.16763e+03 Fmax= 7.42869e+02, atom= 388
# Step=  118, Dmax= 1.0e-03 nm, Epot= -3.16836e+03 Fmax= 8.52284e+02, atom= 388
# Step=  119, Dmax= 1.2e-03 nm, Epot= -3.16906e+03 Fmax= 9.12213e+02, atom= 388
# Step=  120, Dmax= 1.4e-03 nm, Epot= -3.16951e+03 Fmax= 1.36754e+03, atom= 388
# Step=  121, Dmax= 1.7e-03 nm, Epot= -3.17034e+03 Fmax= 1.21125e+03, atom= 388
# Step=  123, Dmax= 1.0e-03 nm, Epot= -3.17152e+03 Fmax= 4.16788e+02, atom= 388
# Step=  124, Dmax= 1.2e-03 nm, Epot= -3.17230e+03 Fmax= 1.33451e+03, atom= 388
# Step=  125, Dmax= 1.5e-03 nm, Epot= -3.17338e+03 Fmax= 1.00381e+03, atom= 388
# Step=  126, Dmax= 1.8e-03 nm, Epot= -3.17340e+03 Fmax= 1.64566e+03, atom= 388
# Step=  127, Dmax= 2.1e-03 nm, Epot= -3.17410e+03 Fmax= 1.70621e+03, atom= 388
# Step=  129, Dmax= 1.3e-03 nm, Epot= -3.17587e+03 Fmax= 2.29133e+02, atom= 388
# Step=  130, Dmax= 1.5e-03 nm, Epot= -3.17643e+03 Fmax= 2.46272e+03, atom= 388
# Step=  131, Dmax= 1.9e-03 nm, Epot= -3.17971e+03 Fmax= 3.39741e+02, atom= 388
# Step=  133, Dmax= 1.1e-03 nm, Epot= -3.18030e+03 Fmax= 1.52545e+03, atom= 388
# Step=  134, Dmax= 1.3e-03 nm, Epot= -3.18171e+03 Fmax= 4.75670e+02, atom= 388
# Step=  136, Dmax= 8.0e-04 nm, Epot= -3.18233e+03 Fmax= 8.34892e+02, atom= 388
# Step=  137, Dmax= 9.6e-04 nm, Epot= -3.18302e+03 Fmax= 5.79737e+02, atom= 388
# Step=  138, Dmax= 1.2e-03 nm, Epot= -3.18336e+03 Fmax= 1.28593e+03, atom= 388
# Step=  139, Dmax= 1.4e-03 nm, Epot= -3.18432e+03 Fmax= 7.80111e+02, atom= 388
# Step=  141, Dmax= 8.3e-04 nm, Epot= -3.18502e+03 Fmax= 5.45323e+02, atom= 388
# Step=  142, Dmax= 9.9e-04 nm, Epot= -3.18557e+03 Fmax= 8.89052e+02, atom= 388
# Step=  143, Dmax= 1.2e-03 nm, Epot= -3.18613e+03 Fmax= 1.00997e+03, atom= 388
# Step=  144, Dmax= 1.4e-03 nm, Epot= -3.18658e+03 Fmax= 1.11676e+03, atom= 388
# Step=  145, Dmax= 1.7e-03 nm, Epot= -3.18670e+03 Fmax= 1.59772e+03, atom= 388
# Step=  146, Dmax= 2.1e-03 nm, Epot= -3.18732e+03 Fmax= 1.50253e+03, atom= 388
# Step=  148, Dmax= 1.2e-03 nm, Epot= -3.18878e+03 Fmax= 4.38340e+02, atom= 388
# Step=  149, Dmax= 1.5e-03 nm, Epot= -3.18888e+03 Fmax= 1.66834e+03, atom= 388
# Step=  150, Dmax= 1.8e-03 nm, Epot= -3.19020e+03 Fmax= 1.12021e+03, atom= 388
# Step=  152, Dmax= 1.1e-03 nm, Epot= -3.19108e+03 Fmax= 4.73049e+02, atom= 388
# Step=  154, Dmax= 6.4e-04 nm, Epot= -3.19162e+03 Fmax= 5.79316e+02, atom= 388
# Step=  155, Dmax= 7.7e-04 nm, Epot= -3.19217e+03 Fmax= 5.35315e+02, atom= 388
# Step=  156, Dmax= 9.2e-04 nm, Epot= -3.19259e+03 Fmax= 9.68550e+02, atom= 388
# Step=  157, Dmax= 1.1e-03 nm, Epot= -3.19327e+03 Fmax= 6.75377e+02, atom= 388
# Step=  159, Dmax= 6.7e-04 nm, Epot= -3.19386e+03 Fmax= 3.95141e+02, atom= 388
# Step=  160, Dmax= 8.0e-04 nm, Epot= -3.19445e+03 Fmax= 7.27434e+02, atom= 388
# Step=  161, Dmax= 9.6e-04 nm, Epot= -3.19497e+03 Fmax= 8.08474e+02, atom= 388
# Step=  162, Dmax= 1.1e-03 nm, Epot= -3.19542e+03 Fmax= 8.84101e+02, atom= 388
# Step=  163, Dmax= 1.4e-03 nm, Epot= -3.19563e+03 Fmax= 1.31052e+03, atom= 388
# Step=  164, Dmax= 1.7e-03 nm, Epot= -3.19623e+03 Fmax= 1.16608e+03, atom= 388
# Step=  166, Dmax= 9.9e-04 nm, Epot= -3.19723e+03 Fmax= 4.01148e+02, atom= 388
# Step=  167, Dmax= 1.2e-03 nm, Epot= -3.19757e+03 Fmax= 1.27682e+03, atom= 388
# Step=  168, Dmax= 1.4e-03 nm, Epot= -3.19843e+03 Fmax= 9.74035e+02, atom= 388
# Step=  170, Dmax= 8.6e-04 nm, Epot= -3.19917e+03 Fmax= 2.99224e+02, atom= 388
# Step=  171, Dmax= 1.0e-03 nm, Epot= -3.19948e+03 Fmax= 1.45007e+03, atom= 388
# Step=  172, Dmax= 1.2e-03 nm, Epot= -3.20075e+03 Fmax= 4.03781e+02, atom= 388
# Step=  174, Dmax= 7.4e-04 nm, Epot= -3.20121e+03 Fmax= 8.24918e+02, atom= 388
# Step=  175, Dmax= 8.9e-04 nm, Epot= -3.20179e+03 Fmax= 4.86739e+02, atom= 388
# Step=  176, Dmax= 1.1e-03 nm, Epot= -3.20195e+03 Fmax= 1.26044e+03, atom= 388
# Step=  177, Dmax= 1.3e-03 nm, Epot= -3.20286e+03 Fmax= 6.54806e+02, atom= 388
# Step=  179, Dmax= 7.7e-04 nm, Epot= -3.20337e+03 Fmax= 5.83399e+02, atom= 388
# Step=  180, Dmax= 9.2e-04 nm, Epot= -3.20378e+03 Fmax= 7.52766e+02, atom= 388
# Step=  181, Dmax= 1.1e-03 nm, Epot= -3.20412e+03 Fmax= 1.01900e+03, atom= 388
# Step=  182, Dmax= 1.3e-03 nm, Epot= -3.20458e+03 Fmax= 9.54197e+02, atom= 388
# Step=  184, Dmax= 8.0e-04 nm, Epot= -3.20533e+03 Fmax= 3.11300e+02, atom= 388
# Step=  185, Dmax= 9.6e-04 nm, Epot= -3.20589e+03 Fmax= 1.00046e+03, atom= 388
# Step=  186, Dmax= 1.1e-03 nm, Epot= -3.20653e+03 Fmax= 8.18192e+02, atom= 388
# Step=  187, Dmax= 1.4e-03 nm, Epot= -3.20663e+03 Fmax= 1.21103e+03, atom= 388
# Step=  188, Dmax= 1.7e-03 nm, Epot= -3.20695e+03 Fmax= 1.39300e+03, atom= 388
# Step=  189, Dmax= 2.0e-03 nm, Epot= -3.20706e+03 Fmax= 1.57914e+03, atom= 388
# Step=  191, Dmax= 1.2e-03 nm, Epot= -3.20860e+03 Fmax= 2.85157e+02, atom= 388
# Step=  192, Dmax= 1.4e-03 nm, Epot= -3.20886e+03 Fmax= 1.65057e+03, atom= 388
# Step=  193, Dmax= 1.7e-03 nm, Epot= -3.21016e+03 Fmax= 1.03088e+03, atom= 388
# Step=  195, Dmax= 1.0e-03 nm, Epot= -3.21086e+03 Fmax= 4.97221e+02, atom= 388
# Step=  197, Dmax= 6.2e-04 nm, Epot= -3.21129e+03 Fmax= 5.11316e+02, atom= 388
# Step=  198, Dmax= 7.4e-04 nm, Epot= -3.21170e+03 Fmax= 5.52267e+02, atom= 388
# Step=  199, Dmax= 8.9e-04 nm, Epot= -3.21203e+03 Fmax= 8.90750e+02, atom= 388
# Step=  200, Dmax= 1.1e-03 nm, Epot= -3.21253e+03 Fmax= 6.85465e+02, atom= 388
# Step=  202, Dmax= 6.4e-04 nm, Epot= -3.21304e+03 Fmax= 3.42973e+02, atom= 388
# Step=  203, Dmax= 7.7e-04 nm, Epot= -3.21352e+03 Fmax= 7.22073e+02, atom= 388
# Step=  204, Dmax= 9.2e-04 nm, Epot= -3.21396e+03 Fmax= 7.54875e+02, atom= 388
# Step=  205, Dmax= 1.1e-03 nm, Epot= -3.21428e+03 Fmax= 8.67969e+02, atom= 388
# Step=  206, Dmax= 1.3e-03 nm, Epot= -3.21443e+03 Fmax= 1.24300e+03, atom= 388
# Step=  207, Dmax= 1.6e-03 nm, Epot= -3.21490e+03 Fmax= 1.13535e+03, atom= 388
# Step=  209, Dmax= 9.5e-04 nm, Epot= -3.21580e+03 Fmax= 3.72308e+02, atom= 388
# Step=  210, Dmax= 1.1e-03 nm, Epot= -3.21600e+03 Fmax= 1.23088e+03, atom= 388
# Step=  211, Dmax= 1.4e-03 nm, Epot= -3.21676e+03 Fmax= 9.34809e+02, atom= 388
# Step=  213, Dmax= 8.3e-04 nm, Epot= -3.21739e+03 Fmax= 2.88144e+02, atom= 388
# Step=  214, Dmax= 9.9e-04 nm, Epot= -3.21752e+03 Fmax= 1.39867e+03, atom= 388
# Step=  215, Dmax= 1.2e-03 nm, Epot= -3.21867e+03 Fmax= 3.82772e+02, atom= 388
# Step=  217, Dmax= 7.1e-04 nm, Epot= -3.21903e+03 Fmax= 8.02642e+02, atom= 388
# Step=  218, Dmax= 8.6e-04 nm, Epot= -3.21953e+03 Fmax= 4.57356e+02, atom= 388
# Step=  219, Dmax= 1.0e-03 nm, Epot= -3.21959e+03 Fmax= 1.22824e+03, atom= 388
# Step=  220, Dmax= 1.2e-03 nm, Epot= -3.22041e+03 Fmax= 6.12383e+02, atom= 388
# Step=  222, Dmax= 7.4e-04 nm, Epot= -3.22083e+03 Fmax= 5.81500e+02, atom= 388
# Step=  223, Dmax= 8.9e-04 nm, Epot= -3.22116e+03 Fmax= 7.03876e+02, atom= 388
# Step=  224, Dmax= 1.1e-03 nm, Epot= -3.22139e+03 Fmax= 1.00391e+03, atom= 388
# Step=  225, Dmax= 1.3e-03 nm, Epot= -3.22182e+03 Fmax= 8.92953e+02, atom= 388
# Step=  227, Dmax= 7.7e-04 nm, Epot= -3.22245e+03 Fmax= 3.26010e+02, atom= 388
# Step=  228, Dmax= 9.2e-04 nm, Epot= -3.22282e+03 Fmax= 9.43629e+02, atom= 388
# Step=  229, Dmax= 1.1e-03 nm, Epot= -3.22334e+03 Fmax= 8.07595e+02, atom= 388
# Step=  230, Dmax= 1.3e-03 nm, Epot= -3.22342e+03 Fmax= 1.14307e+03, atom= 388
# Step=  231, Dmax= 1.6e-03 nm, Epot= -3.22361e+03 Fmax= 1.36402e+03, atom= 388
# Step=  232, Dmax= 1.9e-03 nm, Epot= -3.22374e+03 Fmax= 1.49276e+03, atom= 388
# Step=  234, Dmax= 1.1e-03 nm, Epot= -3.22509e+03 Fmax= 3.01487e+02, atom= 388
# Step=  236, Dmax= 6.9e-04 nm, Epot= -3.22554e+03 Fmax= 6.37697e+02, atom= 388
# Step=  237, Dmax= 8.2e-04 nm, Epot= -3.22591e+03 Fmax= 6.90052e+02, atom= 388
# Step=  238, Dmax= 9.9e-04 nm, Epot= -3.22622e+03 Fmax= 7.56148e+02, atom= 388
# Step=  239, Dmax= 1.2e-03 nm, Epot= -3.22634e+03 Fmax= 1.14112e+03, atom= 388
# Step=  240, Dmax= 1.4e-03 nm, Epot= -3.22680e+03 Fmax= 9.81761e+02, atom= 388
# Step=  242, Dmax= 8.5e-04 nm, Epot= -3.22751e+03 Fmax= 3.72209e+02, atom= 388
# Step=  243, Dmax= 1.0e-03 nm, Epot= -3.22772e+03 Fmax= 1.06311e+03, atom= 388
# Step=  244, Dmax= 1.2e-03 nm, Epot= -3.22827e+03 Fmax= 8.81276e+02, atom= 388
# Step=  246, Dmax= 7.4e-04 nm, Epot= -3.22884e+03 Fmax= 2.10776e+02, atom= 388
# Step=  247, Dmax= 8.9e-04 nm, Epot= -3.22913e+03 Fmax= 1.34874e+03, atom= 388
# Step=  248, Dmax= 1.1e-03 nm, Epot= -3.23017e+03 Fmax= 2.44039e+02, atom= 388
# Step=  250, Dmax= 6.4e-04 nm, Epot= -3.23056e+03 Fmax= 8.59863e+02, atom= 388
# Step=  251, Dmax= 7.7e-04 nm, Epot= -3.23110e+03 Fmax= 2.71164e+02, atom= 388
# Step=  252, Dmax= 9.2e-04 nm, Epot= -3.23121e+03 Fmax= 1.30030e+03, atom= 388
# Step=  253, Dmax= 1.1e-03 nm, Epot= -3.23219e+03 Fmax= 3.49393e+02, atom= 388
# Step=  255, Dmax= 6.6e-04 nm, Epot= -3.23248e+03 Fmax= 7.56568e+02, atom= 388
# Step=  256, Dmax= 7.9e-04 nm, Epot= -3.23292e+03 Fmax= 4.09496e+02, atom= 388
# Step=  257, Dmax= 9.5e-04 nm, Epot= -3.23296e+03 Fmax= 1.16367e+03, atom= 388
# Step=  258, Dmax= 1.1e-03 nm, Epot= -3.23371e+03 Fmax= 5.41523e+02, atom= 388
# Step=  260, Dmax= 6.9e-04 nm, Epot= -3.23405e+03 Fmax= 5.72061e+02, atom= 388
# Step=  261, Dmax= 8.2e-04 nm, Epot= -3.23435e+03 Fmax= 6.19517e+02, atom= 388
# Step=  262, Dmax= 9.9e-04 nm, Epot= -3.23452e+03 Fmax= 9.72379e+02, atom= 388
# Step=  263, Dmax= 1.2e-03 nm, Epot= -3.23493e+03 Fmax= 7.85430e+02, atom= 388
# Step=  265, Dmax= 7.1e-04 nm, Epot= -3.23545e+03 Fmax= 3.49717e+02, atom= 388
# Step=  266, Dmax= 8.5e-04 nm, Epot= -3.23572e+03 Fmax= 8.38038e+02, atom= 388
# Step=  267, Dmax= 1.0e-03 nm, Epot= -3.23612e+03 Fmax= 7.91863e+02, atom= 388
# Step=  268, Dmax= 1.2e-03 nm, Epot= -3.23624e+03 Fmax= 1.01672e+03, atom= 388
# Step=  269, Dmax= 1.5e-03 nm, Epot= -3.23632e+03 Fmax= 1.31508e+03, atom= 388
# Step=  270, Dmax= 1.8e-03 nm, Epot= -3.23655e+03 Fmax= 1.33275e+03, atom= 388
# Step=  272, Dmax= 1.1e-03 nm, Epot= -3.23763e+03 Fmax= 3.34705e+02, atom= 388
# Step=  274, Dmax= 6.4e-04 nm, Epot= -3.23797e+03 Fmax= 5.48308e+02, atom= 388
# Step=  275, Dmax= 7.6e-04 nm, Epot= -3.23825e+03 Fmax= 6.91684e+02, atom= 388
# Step=  276, Dmax= 9.2e-04 nm, Epot= -3.23856e+03 Fmax= 6.50292e+02, atom= 388
# Step=  277, Dmax= 1.1e-03 nm, Epot= -3.23861e+03 Fmax= 1.11973e+03, atom= 388
# Step=  278, Dmax= 1.3e-03 nm, Epot= -3.23909e+03 Fmax= 8.48537e+02, atom= 388
# Step=  280, Dmax= 7.9e-04 nm, Epot= -3.23964e+03 Fmax= 4.12426e+02, atom= 388
# Step=  281, Dmax= 9.5e-04 nm, Epot= -3.23980e+03 Fmax= 9.32668e+02, atom= 388
# Step=  282, Dmax= 1.1e-03 nm, Epot= -3.24020e+03 Fmax= 8.76960e+02, atom= 388
# Step=  283, Dmax= 1.4e-03 nm, Epot= -3.24022e+03 Fmax= 1.14713e+03, atom= 388
# Step=  284, Dmax= 1.6e-03 nm, Epot= -3.24026e+03 Fmax= 1.44216e+03, atom= 388
# Step=  285, Dmax= 2.0e-03 nm, Epot= -3.24038e+03 Fmax= 1.51543e+03, atom= 388
# Step=  287, Dmax= 1.2e-03 nm, Epot= -3.24171e+03 Fmax= 3.37579e+02, atom= 388
# Step=  289, Dmax= 7.1e-04 nm, Epot= -3.24201e+03 Fmax= 6.47853e+02, atom= 388
# Step=  290, Dmax= 8.5e-04 nm, Epot= -3.24231e+03 Fmax= 7.22206e+02, atom= 388
# Step=  291, Dmax= 1.0e-03 nm, Epot= -3.24254e+03 Fmax= 7.76911e+02, atom= 388
# Step=  292, Dmax= 1.2e-03 nm, Epot= -3.24257e+03 Fmax= 1.18034e+03, atom= 388
# Step=  293, Dmax= 1.5e-03 nm, Epot= -3.24297e+03 Fmax= 1.01675e+03, atom= 388
# Step=  295, Dmax= 8.8e-04 nm, Epot= -3.24366e+03 Fmax= 3.80343e+02, atom= 388
# Step=  296, Dmax= 1.1e-03 nm, Epot= -3.24370e+03 Fmax= 1.10856e+03, atom= 388
# Step=  297, Dmax= 1.3e-03 nm, Epot= -3.24423e+03 Fmax= 8.97514e+02, atom= 388
# Step=  299, Dmax= 7.6e-04 nm, Epot= -3.24477e+03 Fmax= 2.32659e+02, atom= 388
# Step=  300, Dmax= 9.2e-04 nm, Epot= -3.24480e+03 Fmax= 1.35670e+03, atom= 388
# Step=  301, Dmax= 1.1e-03 nm, Epot= -3.24580e+03 Fmax= 2.90340e+02, atom= 388
# Step=  303, Dmax= 6.6e-04 nm, Epot= -3.24604e+03 Fmax= 8.28318e+02, atom= 388
# Step=  304, Dmax= 7.9e-04 nm, Epot= -3.24649e+03 Fmax= 3.39564e+02, atom= 388
# Step=  306, Dmax= 4.7e-04 nm, Epot= -3.24678e+03 Fmax= 4.55454e+02, atom= 388
# Step=  307, Dmax= 5.7e-04 nm, Epot= -3.24707e+03 Fmax= 3.58276e+02, atom= 388
# Step=  308, Dmax= 6.8e-04 nm, Epot= -3.24727e+03 Fmax= 7.80752e+02, atom= 388
# Step=  309, Dmax= 8.2e-04 nm, Epot= -3.24768e+03 Fmax= 4.27206e+02, atom= 388
# Step=  311, Dmax= 4.9e-04 nm, Epot= -3.24797e+03 Fmax= 3.83055e+02, atom= 388
# Step=  312, Dmax= 5.9e-04 nm, Epot= -3.24825e+03 Fmax= 4.48614e+02, atom= 388
# Step=  313, Dmax= 7.1e-04 nm, Epot= -3.24847e+03 Fmax= 7.13742e+02, atom= 388
# Step=  314, Dmax= 8.5e-04 nm, Epot= -3.24879e+03 Fmax= 5.34797e+02, atom= 388
# Step=  316, Dmax= 5.1e-04 nm, Epot= -3.24912e+03 Fmax= 2.95633e+02, atom= 388
# Step=  317, Dmax= 6.1e-04 nm, Epot= -3.24942e+03 Fmax= 5.42625e+02, atom= 388
# Step=  318, Dmax= 7.3e-04 nm, Epot= -3.24968e+03 Fmax= 6.48342e+02, atom= 388
# Step=  319, Dmax= 8.8e-04 nm, Epot= -3.24994e+03 Fmax= 6.39516e+02, atom= 388
# Step=  320, Dmax= 1.1e-03 nm, Epot= -3.24999e+03 Fmax= 1.06085e+03, atom= 388
# Step=  321, Dmax= 1.3e-03 nm, Epot= -3.25040e+03 Fmax= 8.30036e+02, atom= 388
# Step=  323, Dmax= 7.6e-04 nm, Epot= -3.25090e+03 Fmax= 3.81723e+02, atom= 388
# Step=  324, Dmax= 9.1e-04 nm, Epot= -3.25103e+03 Fmax= 9.06752e+02, atom= 388
# Step=  325, Dmax= 1.1e-03 nm, Epot= -3.25140e+03 Fmax= 8.32676e+02, atom= 388
# Step=  327, Dmax= 6.6e-04 nm, Epot= -3.25187e+03 Fmax= 1.40866e+02, atom= 388
# Step=  328, Dmax= 7.9e-04 nm, Epot= -3.25220e+03 Fmax= 1.32473e+03, atom= 388
# Step=  329, Dmax= 9.5e-04 nm, Epot= -3.25318e+03 Fmax= 1.08908e+02, atom= 390
# Step=  330, Dmax= 1.1e-03 nm, Epot= -3.25338e+03 Fmax= 1.91976e+03, atom= 388
# Step=  331, Dmax= 1.4e-03 nm, Epot= -3.25544e+03 Fmax= 1.41589e+02, atom= 388
# Step=  333, Dmax= 8.2e-04 nm, Epot= -3.25551e+03 Fmax= 1.37298e+03, atom= 388
# Step=  334, Dmax= 9.8e-04 nm, Epot= -3.25673e+03 Fmax= 1.15134e+02, atom= 372
# Step=  336, Dmax= 5.9e-04 nm, Epot= -3.25709e+03 Fmax= 9.29309e+02, atom= 388
# Step=  337, Dmax= 7.1e-04 nm, Epot= -3.25790e+03 Fmax= 1.22084e+02, atom= 388
# Step=  339, Dmax= 4.2e-04 nm, Epot= -3.25833e+03 Fmax= 6.83726e+02, atom= 388
# Step=  340, Dmax= 5.1e-04 nm, Epot= -3.25874e+03 Fmax= 9.56012e+01, atom= 390
# Step=  341, Dmax= 6.1e-04 nm, Epot= -3.25951e+03 Fmax= 8.50857e+02, atom= 388
# Step=  342, Dmax= 7.3e-04 nm, Epot= -3.26011e+03 Fmax= 2.35188e+02, atom= 388
# Step=  344, Dmax= 4.4e-04 nm, Epot= -3.26039e+03 Fmax= 5.24839e+02, atom= 388
# Step=  345, Dmax= 5.3e-04 nm, Epot= -3.26067e+03 Fmax= 2.39632e+02, atom= 388
# Step=  346, Dmax= 6.3e-04 nm, Epot= -3.26087e+03 Fmax= 8.52342e+02, atom= 388
# Step=  347, Dmax= 7.6e-04 nm, Epot= -3.26133e+03 Fmax= 2.73588e+02, atom= 388
# Step=  349, Dmax= 4.6e-04 nm, Epot= -3.26159e+03 Fmax= 5.02285e+02, atom= 388
# Step=  350, Dmax= 5.5e-04 nm, Epot= -3.26185e+03 Fmax= 2.87942e+02, atom= 388
# Step=  351, Dmax= 6.6e-04 nm, Epot= -3.26202e+03 Fmax= 8.23341e+02, atom= 388
# Step=  352, Dmax= 7.9e-04 nm, Epot= -3.26244e+03 Fmax= 3.42740e+02, atom= 388
# Step=  354, Dmax= 4.7e-04 nm, Epot= -3.26268e+03 Fmax= 4.46069e+02, atom= 388
# Step=  355, Dmax= 5.7e-04 nm, Epot= -3.26293e+03 Fmax= 3.66589e+02, atom= 388
# Step=  356, Dmax= 6.8e-04 nm, Epot= -3.26308e+03 Fmax= 7.62977e+02, atom= 388
# Step=  357, Dmax= 8.2e-04 nm, Epot= -3.26344e+03 Fmax= 4.42357e+02, atom= 388
# Step=  359, Dmax= 4.9e-04 nm, Epot= -3.26370e+03 Fmax= 3.60969e+02, atom= 388
# Step=  360, Dmax= 5.9e-04 nm, Epot= -3.26393e+03 Fmax= 4.66880e+02, atom= 388
# Step=  361, Dmax= 7.1e-04 nm, Epot= -3.26412e+03 Fmax= 6.85525e+02, atom= 388
# Step=  362, Dmax= 8.5e-04 nm, Epot= -3.26438e+03 Fmax= 5.58247e+02, atom= 388
# Step=  364, Dmax= 5.1e-04 nm, Epot= -3.26469e+03 Fmax= 2.63901e+02, atom= 388
# Step=  365, Dmax= 6.1e-04 nm, Epot= -3.26496e+03 Fmax= 5.65140e+02, atom= 388
# Step=  366, Dmax= 7.3e-04 nm, Epot= -3.26520e+03 Fmax= 6.17203e+02, atom= 388
# Step=  367, Dmax= 8.8e-04 nm, Epot= -3.26539e+03 Fmax= 6.65904e+02, atom= 388
# Step=  368, Dmax= 1.1e-03 nm, Epot= -3.26542e+03 Fmax= 1.02351e+03, atom= 388
# Step=  369, Dmax= 1.3e-03 nm, Epot= -3.26574e+03 Fmax= 8.61455e+02, atom= 388
# Step=  371, Dmax= 7.6e-04 nm, Epot= -3.26624e+03 Fmax= 3.43649e+02, atom= 388
# Step=  372, Dmax= 9.1e-04 nm, Epot= -3.26629e+03 Fmax= 9.31872e+02, atom= 388
# Step=  373, Dmax= 1.1e-03 nm, Epot= -3.26666e+03 Fmax= 7.98742e+02, atom= 388
# Step=  375, Dmax= 6.6e-04 nm, Epot= -3.26708e+03 Fmax= 1.71427e+02, atom= 388
# Step=  376, Dmax= 7.9e-04 nm, Epot= -3.26714e+03 Fmax= 1.23822e+03, atom= 388
# Step=  377, Dmax= 9.4e-04 nm, Epot= -3.26799e+03 Fmax= 1.77455e+02, atom= 388
# Step=  379, Dmax= 5.7e-04 nm, Epot= -3.26825e+03 Fmax= 8.32730e+02, atom= 388
# Step=  380, Dmax= 6.8e-04 nm, Epot= -3.26871e+03 Fmax= 1.74674e+02, atom= 388
# Step=  381, Dmax= 8.2e-04 nm, Epot= -3.26874e+03 Fmax= 1.28250e+03, atom= 388
# Step=  382, Dmax= 9.8e-04 nm, Epot= -3.26965e+03 Fmax= 1.86559e+02, atom= 388
# Step=  384, Dmax= 5.9e-04 nm, Epot= -3.26989e+03 Fmax= 8.53325e+02, atom= 388
# Step=  385, Dmax= 7.0e-04 nm, Epot= -3.27035e+03 Fmax= 1.91969e+02, atom= 388
# Step=  387, Dmax= 4.2e-04 nm, Epot= -3.27062e+03 Fmax= 5.54533e+02, atom= 388
# Step=  388, Dmax= 5.1e-04 nm, Epot= -3.27090e+03 Fmax= 1.84052e+02, atom= 388
# Step=  389, Dmax= 6.1e-04 nm, Epot= -3.27111e+03 Fmax= 8.95784e+02, atom= 388
# Step=  390, Dmax= 7.3e-04 nm, Epot= -3.27161e+03 Fmax= 1.90013e+02, atom= 388
# Step=  392, Dmax= 4.4e-04 nm, Epot= -3.27188e+03 Fmax= 5.84561e+02, atom= 388
# Step=  393, Dmax= 5.3e-04 nm, Epot= -3.27216e+03 Fmax= 1.83341e+02, atom= 388
# Step=  394, Dmax= 6.3e-04 nm, Epot= -3.27235e+03 Fmax= 9.36403e+02, atom= 388
# Step=  395, Dmax= 7.6e-04 nm, Epot= -3.27288e+03 Fmax= 1.91007e+02, atom= 388
# Step=  397, Dmax= 4.5e-04 nm, Epot= -3.27314e+03 Fmax= 6.10973e+02, atom= 388
# Step=  398, Dmax= 5.5e-04 nm, Epot= -3.27343e+03 Fmax= 1.87108e+02, atom= 388
# Step=  399, Dmax= 6.5e-04 nm, Epot= -3.27359e+03 Fmax= 9.70306e+02, atom= 388
# Step=  400, Dmax= 7.9e-04 nm, Epot= -3.27415e+03 Fmax= 1.99980e+02, atom= 388
# Step=  402, Dmax= 4.7e-04 nm, Epot= -3.27439e+03 Fmax= 6.26659e+02, atom= 388
# Step=  403, Dmax= 5.7e-04 nm, Epot= -3.27469e+03 Fmax= 2.01892e+02, atom= 388
# Step=  404, Dmax= 6.8e-04 nm, Epot= -3.27480e+03 Fmax= 9.86385e+02, atom= 388
# Step=  405, Dmax= 8.1e-04 nm, Epot= -3.27536e+03 Fmax= 2.27602e+02, atom= 388
# Step=  407, Dmax= 4.9e-04 nm, Epot= -3.27558e+03 Fmax= 6.16468e+02, atom= 388
# Step=  408, Dmax= 5.9e-04 nm, Epot= -3.27587e+03 Fmax= 2.41672e+02, atom= 388
# Step=  409, Dmax= 7.0e-04 nm, Epot= -3.27595e+03 Fmax= 9.65844e+02, atom= 388
# Step=  410, Dmax= 8.4e-04 nm, Epot= -3.27649e+03 Fmax= 2.91856e+02, atom= 388
# Step=  412, Dmax= 5.1e-04 nm, Epot= -3.27669e+03 Fmax= 5.62234e+02, atom= 388
# Step=  413, Dmax= 6.1e-04 nm, Epot= -3.27694e+03 Fmax= 3.23109e+02, atom= 388
# Step=  414, Dmax= 7.3e-04 nm, Epot= -3.27700e+03 Fmax= 8.95740e+02, atom= 388
# Step=  415, Dmax= 8.8e-04 nm, Epot= -3.27745e+03 Fmax= 4.05102e+02, atom= 388
# Step=  417, Dmax= 5.3e-04 nm, Epot= -3.27766e+03 Fmax= 4.58710e+02, atom= 388
# Step=  418, Dmax= 6.3e-04 nm, Epot= -3.27786e+03 Fmax= 4.47898e+02, atom= 388
# Step=  419, Dmax= 7.6e-04 nm, Epot= -3.27796e+03 Fmax= 7.87445e+02, atom= 388
# Step=  420, Dmax= 9.1e-04 nm, Epot= -3.27827e+03 Fmax= 5.54795e+02, atom= 388
# Step=  422, Dmax= 5.4e-04 nm, Epot= -3.27855e+03 Fmax= 3.25143e+02, atom= 388
# Step=  423, Dmax= 6.5e-04 nm, Epot= -3.27873e+03 Fmax= 5.87954e+02, atom= 388
# Step=  424, Dmax= 7.8e-04 nm, Epot= -3.27893e+03 Fmax= 6.74672e+02, atom= 388
# Step=  425, Dmax= 9.4e-04 nm, Epot= -3.27909e+03 Fmax= 7.07917e+02, atom= 388
# Step=  427, Dmax= 5.6e-04 nm, Epot= -3.27947e+03 Fmax= 1.95142e+02, atom= 388
# Step=  428, Dmax= 6.8e-04 nm, Epot= -3.27978e+03 Fmax= 6.87502e+02, atom= 388
# Step=  429, Dmax= 8.1e-04 nm, Epot= -3.28006e+03 Fmax= 6.12647e+02, atom= 388
# Step=  430, Dmax= 9.8e-04 nm, Epot= -3.28013e+03 Fmax= 8.14381e+02, atom= 388
# Step=  431, Dmax= 1.2e-03 nm, Epot= -3.28019e+03 Fmax= 1.04607e+03, atom= 388
# Step=  432, Dmax= 1.4e-03 nm, Epot= -3.28034e+03 Fmax= 1.05112e+03, atom= 388
# Step=  434, Dmax= 8.4e-04 nm, Epot= -3.28101e+03 Fmax= 2.78674e+02, atom= 388
# Step=  436, Dmax= 5.1e-04 nm, Epot= -3.28123e+03 Fmax= 4.16925e+02, atom= 388
# Step=  437, Dmax= 6.1e-04 nm, Epot= -3.28140e+03 Fmax= 5.78560e+02, atom= 388
# Step=  438, Dmax= 7.3e-04 nm, Epot= -3.28162e+03 Fmax= 4.84040e+02, atom= 388
# Step=  439, Dmax= 8.7e-04 nm, Epot= -3.28162e+03 Fmax= 9.36475e+02, atom= 388
# Step=  440, Dmax= 1.0e-03 nm, Epot= -3.28200e+03 Fmax= 6.24475e+02, atom= 388
# Step=  442, Dmax= 6.3e-04 nm, Epot= -3.28230e+03 Fmax= 3.86037e+02, atom= 388
# Step=  443, Dmax= 7.6e-04 nm, Epot= -3.28241e+03 Fmax= 6.86543e+02, atom= 388
# Step=  444, Dmax= 9.1e-04 nm, Epot= -3.28261e+03 Fmax= 7.62235e+02, atom= 388
# Step=  445, Dmax= 1.1e-03 nm, Epot= -3.28271e+03 Fmax= 8.44225e+02, atom= 388
# Step=  447, Dmax= 6.5e-04 nm, Epot= -3.28320e+03 Fmax= 1.91882e+02, atom= 388
# Step=  448, Dmax= 7.8e-04 nm, Epot= -3.28347e+03 Fmax= 8.26240e+02, atom= 388
# Step=  449, Dmax= 9.4e-04 nm, Epot= -3.28381e+03 Fmax= 6.65765e+02, atom= 388
# Step=  451, Dmax= 5.6e-04 nm, Epot= -3.28413e+03 Fmax= 1.63464e+02, atom= 388
# Step=  452, Dmax= 6.8e-04 nm, Epot= -3.28426e+03 Fmax= 1.04952e+03, atom= 388
# Step=  453, Dmax= 8.1e-04 nm, Epot= -3.28488e+03 Fmax= 1.64041e+02, atom= 388
# Step=  455, Dmax= 4.9e-04 nm, Epot= -3.28512e+03 Fmax= 7.09071e+02, atom= 388
# Step=  456, Dmax= 5.8e-04 nm, Epot= -3.28545e+03 Fmax= 1.53403e+02, atom= 388
# Step=  457, Dmax= 7.0e-04 nm, Epot= -3.28556e+03 Fmax= 1.11496e+03, atom= 388
# Step=  458, Dmax= 8.4e-04 nm, Epot= -3.28625e+03 Fmax= 1.45450e+02, atom= 388
# Step=  460, Dmax= 5.0e-04 nm, Epot= -3.28650e+03 Fmax= 7.74645e+02, atom= 388
# Step=  461, Dmax= 6.1e-04 nm, Epot= -3.28688e+03 Fmax= 1.23048e+02, atom= 388
# Step=  462, Dmax= 7.3e-04 nm, Epot= -3.28699e+03 Fmax= 1.23772e+03, atom= 388
# Step=  463, Dmax= 8.7e-04 nm, Epot= -3.28785e+03 Fmax= 9.33113e+01, atom= 390
# Step=  464, Dmax= 1.0e-03 nm, Epot= -3.28803e+03 Fmax= 1.65489e+03, atom= 388
# Step=  465, Dmax= 1.3e-03 nm, Epot= -3.28950e+03 Fmax= 2.38236e+02, atom= 388
# Step=  468, Dmax= 3.8e-04 nm, Epot= -3.28970e+03 Fmax= 4.10857e+02, atom= 388
# Step=  469, Dmax= 4.5e-04 nm, Epot= -3.28990e+03 Fmax= 2.36755e+02, atom= 388
# Step=  470, Dmax= 5.4e-04 nm, Epot= -3.29002e+03 Fmax= 6.94011e+02, atom= 388
# Step=  471, Dmax= 6.5e-04 nm, Epot= -3.29035e+03 Fmax= 2.66209e+02, atom= 388
# Step=  473, Dmax= 3.9e-04 nm, Epot= -3.29052e+03 Fmax= 3.96358e+02, atom= 388
# Step=  474, Dmax= 4.7e-04 nm, Epot= -3.29071e+03 Fmax= 2.73011e+02, atom= 388
# Step=  475, Dmax= 5.6e-04 nm, Epot= -3.29082e+03 Fmax= 6.78181e+02, atom= 388
# Step=  476, Dmax= 6.8e-04 nm, Epot= -3.29112e+03 Fmax= 3.17154e+02, atom= 388
# Step=  478, Dmax= 4.1e-04 nm, Epot= -3.29131e+03 Fmax= 3.59322e+02, atom= 388
# Step=  479, Dmax= 4.9e-04 nm, Epot= -3.29148e+03 Fmax= 3.29350e+02, atom= 388
# Step=  480, Dmax= 5.8e-04 nm, Epot= -3.29159e+03 Fmax= 6.41526e+02, atom= 388
# Step=  481, Dmax= 7.0e-04 nm, Epot= -3.29185e+03 Fmax= 3.86885e+02, atom= 388
# Step=  483, Dmax= 4.2e-04 nm, Epot= -3.29205e+03 Fmax= 3.04721e+02, atom= 388
# Step=  484, Dmax= 5.0e-04 nm, Epot= -3.29222e+03 Fmax= 3.98815e+02, atom= 388
# Step=  485, Dmax= 6.0e-04 nm, Epot= -3.29235e+03 Fmax= 5.94493e+02, atom= 388
# Step=  486, Dmax= 7.3e-04 nm, Epot= -3.29256e+03 Fmax= 4.68964e+02, atom= 388
# Step=  488, Dmax= 4.4e-04 nm, Epot= -3.29280e+03 Fmax= 2.39807e+02, atom= 388
# Step=  489, Dmax= 5.2e-04 nm, Epot= -3.29298e+03 Fmax= 4.68459e+02, atom= 388
# Step=  490, Dmax= 6.3e-04 nm, Epot= -3.29315e+03 Fmax= 5.51225e+02, atom= 388
# Step=  491, Dmax= 7.5e-04 nm, Epot= -3.29330e+03 Fmax= 5.46712e+02, atom= 388
# Step=  493, Dmax= 4.5e-04 nm, Epot= -3.29358e+03 Fmax= 1.82646e+02, atom= 388
# Step=  494, Dmax= 5.4e-04 nm, Epot= -3.29383e+03 Fmax= 5.20044e+02, atom= 388
# Step=  495, Dmax= 6.5e-04 nm, Epot= -3.29403e+03 Fmax= 5.31357e+02, atom= 388
# Step=  496, Dmax= 7.8e-04 nm, Epot= -3.29416e+03 Fmax= 5.81771e+02, atom= 388
# Step=  497, Dmax= 9.4e-04 nm, Epot= -3.29418e+03 Fmax= 9.23492e+02, atom= 388
# Step=  498, Dmax= 1.1e-03 nm, Epot= -3.29445e+03 Fmax= 7.32345e+02, atom= 388
# Step=  500, Dmax= 6.7e-04 nm, Epot= -3.29483e+03 Fmax= 3.56732e+02, atom= 388
# Step=  501, Dmax= 8.1e-04 nm, Epot= -3.29488e+03 Fmax= 7.52560e+02, atom= 388
# Step=  502, Dmax= 9.7e-04 nm, Epot= -3.29507e+03 Fmax= 8.13152e+02, atom= 388
# Step=  503, Dmax= 1.2e-03 nm, Epot= -3.29513e+03 Fmax= 8.93513e+02, atom= 388
# Step=  505, Dmax= 7.0e-04 nm, Epot= -3.29567e+03 Fmax= 2.26077e+02, atom= 388
# Step=  506, Dmax= 8.4e-04 nm, Epot= -3.29579e+03 Fmax= 8.45352e+02, atom= 388
# Step=  507, Dmax= 1.0e-03 nm, Epot= -3.29608e+03 Fmax= 7.69801e+02, atom= 388
# Step=  509, Dmax= 6.0e-04 nm, Epot= -3.29645e+03 Fmax= 1.29476e+02, atom= 389
# Step=  510, Dmax= 7.2e-04 nm, Epot= -3.29654e+03 Fmax= 1.17838e+03, atom= 388
# Step=  511, Dmax= 8.7e-04 nm, Epot= -3.29731e+03 Fmax= 1.29995e+02, atom= 389
# Step=  513, Dmax= 5.2e-04 nm, Epot= -3.29753e+03 Fmax= 8.22065e+02, atom= 388
# Step=  514, Dmax= 6.3e-04 nm, Epot= -3.29795e+03 Fmax= 1.20921e+02, atom= 389
# Step=  515, Dmax= 7.5e-04 nm, Epot= -3.29809e+03 Fmax= 1.17904e+03, atom= 388
# Step=  516, Dmax= 9.0e-04 nm, Epot= -3.29886e+03 Fmax= 1.62341e+02, atom= 388
# Step=  518, Dmax= 5.4e-04 nm, Epot= -3.29897e+03 Fmax= 8.55096e+02, atom= 388
# Step=  519, Dmax= 6.5e-04 nm, Epot= -3.29942e+03 Fmax= 1.20843e+02, atom= 389
# Step=  520, Dmax= 7.8e-04 nm, Epot= -3.29949e+03 Fmax= 1.24778e+03, atom= 388
# Step=  521, Dmax= 9.3e-04 nm, Epot= -3.30036e+03 Fmax= 1.45829e+02, atom= 388
# Step=  523, Dmax= 5.6e-04 nm, Epot= -3.30046e+03 Fmax= 9.29398e+02, atom= 388
# Step=  524, Dmax= 6.7e-04 nm, Epot= -3.30097e+03 Fmax= 1.06143e+02, atom= 390
# Step=  525, Dmax= 8.1e-04 nm, Epot= -3.30124e+03 Fmax= 1.11179e+03, atom= 388
# Step=  526, Dmax= 9.7e-04 nm, Epot= -3.30199e+03 Fmax= 3.26882e+02, atom= 388
# Step=  528, Dmax= 5.8e-04 nm, Epot= -3.30210e+03 Fmax= 6.66326e+02, atom= 388
# Step=  529, Dmax= 7.0e-04 nm, Epot= -3.30236e+03 Fmax= 3.47638e+02, atom= 388
# Step=  531, Dmax= 4.2e-04 nm, Epot= -3.30254e+03 Fmax= 3.62812e+02, atom= 388
# Step=  532, Dmax= 5.0e-04 nm, Epot= -3.30269e+03 Fmax= 3.32244e+02, atom= 388
# Step=  533, Dmax= 6.0e-04 nm, Epot= -3.30276e+03 Fmax= 6.94482e+02, atom= 388
# Step=  534, Dmax= 7.2e-04 nm, Epot= -3.30304e+03 Fmax= 3.60098e+02, atom= 388
# Step=  536, Dmax= 4.3e-04 nm, Epot= -3.30322e+03 Fmax= 3.73725e+02, atom= 388
# Step=  537, Dmax= 5.2e-04 nm, Epot= -3.30338e+03 Fmax= 3.49681e+02, atom= 388
# Step=  538, Dmax= 6.3e-04 nm, Epot= -3.30344e+03 Fmax= 7.08968e+02, atom= 388
# Step=  539, Dmax= 7.5e-04 nm, Epot= -3.30374e+03 Fmax= 3.85884e+02, atom= 388
# Step=  541, Dmax= 4.5e-04 nm, Epot= -3.30392e+03 Fmax= 3.69878e+02, atom= 388
# Step=  542, Dmax= 5.4e-04 nm, Epot= -3.30408e+03 Fmax= 3.78820e+02, atom= 388
# Step=  543, Dmax= 6.5e-04 nm, Epot= -3.30414e+03 Fmax= 7.11030e+02, atom= 388
# Step=  544, Dmax= 7.8e-04 nm, Epot= -3.30442e+03 Fmax= 4.24065e+02, atom= 388
# Step=  546, Dmax= 4.7e-04 nm, Epot= -3.30462e+03 Fmax= 3.53551e+02, atom= 388
# Step=  547, Dmax= 5.6e-04 nm, Epot= -3.30476e+03 Fmax= 4.19723e+02, atom= 388
# Step=  548, Dmax= 6.7e-04 nm, Epot= -3.30483e+03 Fmax= 7.00620e+02, atom= 388
# Step=  549, Dmax= 8.1e-04 nm, Epot= -3.30508e+03 Fmax= 4.75613e+02, atom= 388
# Step=  551, Dmax= 4.8e-04 nm, Epot= -3.30530e+03 Fmax= 3.23785e+02, atom= 388
# Step=  552, Dmax= 5.8e-04 nm, Epot= -3.30544e+03 Fmax= 4.69623e+02, atom= 388
# Step=  553, Dmax= 7.0e-04 nm, Epot= -3.30553e+03 Fmax= 6.82078e+02, atom= 388
# Step=  554, Dmax= 8.4e-04 nm, Epot= -3.30574e+03 Fmax= 5.35823e+02, atom= 388
# Step=  556, Dmax= 5.0e-04 nm, Epot= -3.30600e+03 Fmax= 2.86687e+02, atom= 388
# Step=  557, Dmax= 6.0e-04 nm, Epot= -3.30613e+03 Fmax= 5.22548e+02, atom= 388
# Step=  558, Dmax= 7.2e-04 nm, Epot= -3.30626e+03 Fmax= 6.62935e+02, atom= 388
# Step=  559, Dmax= 8.7e-04 nm, Epot= -3.30642e+03 Fmax= 5.97851e+02, atom= 388
# Step=  561, Dmax= 5.2e-04 nm, Epot= -3.30673e+03 Fmax= 2.49323e+02, atom= 388
# Step=  562, Dmax= 6.2e-04 nm, Epot= -3.30686e+03 Fmax= 5.71643e+02, atom= 388
# Step=  563, Dmax= 7.5e-04 nm, Epot= -3.30703e+03 Fmax= 6.50677e+02, atom= 388
# Step=  564, Dmax= 9.0e-04 nm, Epot= -3.30715e+03 Fmax= 6.55244e+02, atom= 388
# Step=  566, Dmax= 5.4e-04 nm, Epot= -3.30749e+03 Fmax= 2.18828e+02, atom= 388
# Step=  567, Dmax= 6.5e-04 nm, Epot= -3.30766e+03 Fmax= 6.12070e+02, atom= 388
# Step=  568, Dmax= 7.8e-04 nm, Epot= -3.30784e+03 Fmax= 6.50206e+02, atom= 388
# Step=  569, Dmax= 9.3e-04 nm, Epot= -3.30793e+03 Fmax= 7.03855e+02, atom= 388
# Step=  571, Dmax= 5.6e-04 nm, Epot= -3.30830e+03 Fmax= 1.99210e+02, atom= 388
# Step=  572, Dmax= 6.7e-04 nm, Epot= -3.30848e+03 Fmax= 6.45656e+02, atom= 388
# Step=  573, Dmax= 8.1e-04 nm, Epot= -3.30868e+03 Fmax= 6.57617e+02, atom= 388
# Step=  574, Dmax= 9.7e-04 nm, Epot= -3.30874e+03 Fmax= 7.46628e+02, atom= 388
# Step=  576, Dmax= 5.8e-04 nm, Epot= -3.30914e+03 Fmax= 1.86434e+02, atom= 388
# Step=  577, Dmax= 7.0e-04 nm, Epot= -3.30935e+03 Fmax= 6.77042e+02, atom= 388
# Step=  578, Dmax= 8.3e-04 nm, Epot= -3.30956e+03 Fmax= 6.72521e+02, atom= 388
# Step=  579, Dmax= 1.0e-03 nm, Epot= -3.30960e+03 Fmax= 7.86400e+02, atom= 388
# Step=  581, Dmax= 6.0e-04 nm, Epot= -3.31002e+03 Fmax= 1.79066e+02, atom= 388
# Step=  582, Dmax= 7.2e-04 nm, Epot= -3.31023e+03 Fmax= 7.07181e+02, atom= 388
# Step=  583, Dmax= 8.7e-04 nm, Epot= -3.31045e+03 Fmax= 6.86833e+02, atom= 388
# Step=  584, Dmax= 1.0e-03 nm, Epot= -3.31047e+03 Fmax= 8.26629e+02, atom= 388
# Step=  586, Dmax= 6.2e-04 nm, Epot= -3.31094e+03 Fmax= 1.71899e+02, atom= 388
# Step=  587, Dmax= 7.5e-04 nm, Epot= -3.31115e+03 Fmax= 7.38495e+02, atom= 388
# Step=  588, Dmax= 9.0e-04 nm, Epot= -3.31139e+03 Fmax= 7.06009e+02, atom= 388
# Step=  589, Dmax= 1.1e-03 nm, Epot= -3.31139e+03 Fmax= 8.66945e+02, atom= 388
# Step=  591, Dmax= 6.5e-04 nm, Epot= -3.31188e+03 Fmax= 1.66605e+02, atom= 388
# Step=  592, Dmax= 7.8e-04 nm, Epot= -3.31210e+03 Fmax= 7.68795e+02, atom= 388
# Step=  593, Dmax= 9.3e-04 nm, Epot= -3.31234e+03 Fmax= 7.23481e+02, atom= 388
# Step=  595, Dmax= 5.6e-04 nm, Epot= -3.31267e+03 Fmax= 1.12511e+02, atom= 390
# Step=  596, Dmax= 6.7e-04 nm, Epot= -3.31273e+03 Fmax= 1.06968e+03, atom= 388
# Step=  597, Dmax= 8.0e-04 nm, Epot= -3.31344e+03 Fmax= 1.28320e+02, atom= 388
# Step=  599, Dmax= 4.8e-04 nm, Epot= -3.31360e+03 Fmax= 8.01097e+02, atom= 388
# Step=  600, Dmax= 5.8e-04 nm, Epot= -3.31399e+03 Fmax= 9.56783e+01, atom= 390
# Step=  601, Dmax= 6.9e-04 nm, Epot= -3.31440e+03 Fmax= 8.80849e+02, atom= 388
# Step=  602, Dmax= 8.3e-04 nm, Epot= -3.31486e+03 Fmax= 3.51806e+02, atom= 388
# Step=  604, Dmax= 5.0e-04 nm, Epot= -3.31501e+03 Fmax= 4.89879e+02, atom= 388
# Step=  605, Dmax= 6.0e-04 nm, Epot= -3.31517e+03 Fmax= 3.67737e+02, atom= 388
# Step=  607, Dmax= 3.6e-04 nm, Epot= -3.31534e+03 Fmax= 2.37297e+02, atom= 388
# Step=  608, Dmax= 4.3e-04 nm, Epot= -3.31550e+03 Fmax= 3.29445e+02, atom= 388
# Step=  609, Dmax= 5.2e-04 nm, Epot= -3.31559e+03 Fmax= 5.49412e+02, atom= 388
# Step=  610, Dmax= 6.2e-04 nm, Epot= -3.31580e+03 Fmax= 3.47491e+02, atom= 388
# Step=  612, Dmax= 3.7e-04 nm, Epot= -3.31597e+03 Fmax= 2.82503e+02, atom= 388
# Step=  613, Dmax= 4.5e-04 nm, Epot= -3.31611e+03 Fmax= 3.22635e+02, atom= 388
# Step=  614, Dmax= 5.4e-04 nm, Epot= -3.31620e+03 Fmax= 5.90043e+02, atom= 388
# Step=  615, Dmax= 6.5e-04 nm, Epot= -3.31641e+03 Fmax= 3.44738e+02, atom= 388
# Step=  617, Dmax= 3.9e-04 nm, Epot= -3.31658e+03 Fmax= 3.08726e+02, atom= 388
# Step=  618, Dmax= 4.6e-04 nm, Epot= -3.31671e+03 Fmax= 3.26347e+02, atom= 388
# Step=  619, Dmax= 5.6e-04 nm, Epot= -3.31676e+03 Fmax= 6.18699e+02, atom= 388
# Step=  620, Dmax= 6.7e-04 nm, Epot= -3.31702e+03 Fmax= 3.53192e+02, atom= 388
# Step=  622, Dmax= 4.0e-04 nm, Epot= -3.31719e+03 Fmax= 3.22734e+02, atom= 388
# Step=  623, Dmax= 4.8e-04 nm, Epot= -3.31732e+03 Fmax= 3.39535e+02, atom= 388
# Step=  624, Dmax= 5.8e-04 nm, Epot= -3.31739e+03 Fmax= 6.36412e+02, atom= 388
# Step=  625, Dmax= 6.9e-04 nm, Epot= -3.31762e+03 Fmax= 3.73200e+02, atom= 388
# Step=  627, Dmax= 4.2e-04 nm, Epot= -3.31779e+03 Fmax= 3.24142e+02, atom= 388
# Step=  628, Dmax= 5.0e-04 nm, Epot= -3.31792e+03 Fmax= 3.62958e+02, atom= 388
# Step=  629, Dmax= 6.0e-04 nm, Epot= -3.31796e+03 Fmax= 6.42927e+02, atom= 388
# Step=  630, Dmax= 7.2e-04 nm, Epot= -3.31821e+03 Fmax= 4.04524e+02, atom= 388
# Step=  632, Dmax= 4.3e-04 nm, Epot= -3.31840e+03 Fmax= 3.13782e+02, atom= 388
# Step=  633, Dmax= 5.2e-04 nm, Epot= -3.31852e+03 Fmax= 3.96080e+02, atom= 388
# Step=  634, Dmax= 6.2e-04 nm, Epot= -3.31858e+03 Fmax= 6.39390e+02, atom= 388
# Step=  635, Dmax= 7.5e-04 nm, Epot= -3.31879e+03 Fmax= 4.46142e+02, atom= 388
# Step=  637, Dmax= 4.5e-04 nm, Epot= -3.31900e+03 Fmax= 2.93252e+02, atom= 388
# Step=  638, Dmax= 5.4e-04 nm, Epot= -3.31911e+03 Fmax= 4.36456e+02, atom= 388
# Step=  639, Dmax= 6.4e-04 nm, Epot= -3.31920e+03 Fmax= 6.29084e+02, atom= 388
# Step=  640, Dmax= 7.7e-04 nm, Epot= -3.31937e+03 Fmax= 4.95432e+02, atom= 388
# Step=  642, Dmax= 4.6e-04 nm, Epot= -3.31960e+03 Fmax= 2.65832e+02, atom= 388
# Step=  643, Dmax= 5.6e-04 nm, Epot= -3.31970e+03 Fmax= 4.80224e+02, atom= 388
# Step=  644, Dmax= 6.7e-04 nm, Epot= -3.31980e+03 Fmax= 6.17521e+02, atom= 388
# Step=  645, Dmax= 8.0e-04 nm, Epot= -3.31995e+03 Fmax= 5.47111e+02, atom= 388
# Step=  647, Dmax= 4.8e-04 nm, Epot= -3.32022e+03 Fmax= 2.37437e+02, atom= 388
# Step=  648, Dmax= 5.8e-04 nm, Epot= -3.32030e+03 Fmax= 5.22378e+02, atom= 388
# Step=  649, Dmax= 6.9e-04 nm, Epot= -3.32043e+03 Fmax= 6.09568e+02, atom= 388
# Step=  650, Dmax= 8.3e-04 nm, Epot= -3.32055e+03 Fmax= 5.97310e+02, atom= 388
# Step=  652, Dmax= 5.0e-04 nm, Epot= -3.32086e+03 Fmax= 2.12173e+02, atom= 388
# Step=  653, Dmax= 6.0e-04 nm, Epot= -3.32097e+03 Fmax= 5.59520e+02, atom= 388
# Step=  654, Dmax= 7.2e-04 nm, Epot= -3.32112e+03 Fmax= 6.07956e+02, atom= 388
# Step=  655, Dmax= 8.6e-04 nm, Epot= -3.32120e+03 Fmax= 6.42042e+02, atom= 388
# Step=  657, Dmax= 5.2e-04 nm, Epot= -3.32154e+03 Fmax= 1.93953e+02, atom= 388
# Step=  658, Dmax= 6.2e-04 nm, Epot= -3.32165e+03 Fmax= 5.91973e+02, atom= 388
# Step=  659, Dmax= 7.4e-04 nm, Epot= -3.32182e+03 Fmax= 6.16222e+02, atom= 388
# Step=  660, Dmax= 8.9e-04 nm, Epot= -3.32188e+03 Fmax= 6.82129e+02, atom= 388
# Step=  662, Dmax= 5.4e-04 nm, Epot= -3.32224e+03 Fmax= 1.82395e+02, atom= 388
# Step=  663, Dmax= 6.4e-04 nm, Epot= -3.32236e+03 Fmax= 6.21195e+02, atom= 388
# Step=  664, Dmax= 7.7e-04 nm, Epot= -3.32254e+03 Fmax= 6.25973e+02, atom= 388
# Step=  665, Dmax= 9.3e-04 nm, Epot= -3.32258e+03 Fmax= 7.20513e+02, atom= 388
# Step=  667, Dmax= 5.6e-04 nm, Epot= -3.32298e+03 Fmax= 1.72897e+02, atom= 388
# Step=  668, Dmax= 6.7e-04 nm, Epot= -3.32309e+03 Fmax= 6.50768e+02, atom= 388
# Step=  669, Dmax= 8.0e-04 nm, Epot= -3.32328e+03 Fmax= 6.41427e+02, atom= 388
# Step=  670, Dmax= 9.6e-04 nm, Epot= -3.32330e+03 Fmax= 7.57846e+02, atom= 388
# Step=  672, Dmax= 5.8e-04 nm, Epot= -3.32374e+03 Fmax= 1.66338e+02, atom= 388
# Step=  673, Dmax= 6.9e-04 nm, Epot= -3.32384e+03 Fmax= 6.79394e+02, atom= 388
# Step=  674, Dmax= 8.3e-04 nm, Epot= -3.32405e+03 Fmax= 6.57525e+02, atom= 388
# Step=  676, Dmax= 5.0e-04 nm, Epot= -3.32437e+03 Fmax= 1.00510e+02, atom= 390
# Step=  677, Dmax= 6.0e-04 nm, Epot= -3.32458e+03 Fmax= 8.58284e+02, atom= 388
# Step=  678, Dmax= 7.2e-04 nm, Epot= -3.32502e+03 Fmax= 2.33132e+02, atom= 388
# Step=  680, Dmax= 4.3e-04 nm, Epot= -3.32510e+03 Fmax= 5.16535e+02, atom= 388
# Step=  681, Dmax= 5.2e-04 nm, Epot= -3.32529e+03 Fmax= 2.63394e+02, atom= 388
# Step=  683, Dmax= 3.1e-04 nm, Epot= -3.32541e+03 Fmax= 2.71104e+02, atom= 388
# Step=  684, Dmax= 3.7e-04 nm, Epot= -3.32553e+03 Fmax= 2.82128e+02, atom= 388
# Step=  685, Dmax= 4.5e-04 nm, Epot= -3.32561e+03 Fmax= 4.81387e+02, atom= 388
# Step=  686, Dmax= 5.3e-04 nm, Epot= -3.32578e+03 Fmax= 3.26042e+02, atom= 388
# Step=  688, Dmax= 3.2e-04 nm, Epot= -3.32593e+03 Fmax= 2.18004e+02, atom= 388
# Step=  689, Dmax= 3.9e-04 nm, Epot= -3.32604e+03 Fmax= 3.48845e+02, atom= 388
# Step=  690, Dmax= 4.6e-04 nm, Epot= -3.32616e+03 Fmax= 4.28895e+02, atom= 388
# Step=  691, Dmax= 5.5e-04 nm, Epot= -3.32627e+03 Fmax= 4.05132e+02, atom= 388
# Step=  692, Dmax= 6.7e-04 nm, Epot= -3.32628e+03 Fmax= 7.01745e+02, atom= 388
# Step=  693, Dmax= 8.0e-04 nm, Epot= -3.32649e+03 Fmax= 5.09362e+02, atom= 388
# Step=  695, Dmax= 4.8e-04 nm, Epot= -3.32673e+03 Fmax= 2.76162e+02, atom= 388
# Step=  696, Dmax= 5.8e-04 nm, Epot= -3.32675e+03 Fmax= 5.75793e+02, atom= 388
# Step=  697, Dmax= 6.9e-04 nm, Epot= -3.32693e+03 Fmax= 5.47162e+02, atom= 388
# Step=  698, Dmax= 8.3e-04 nm, Epot= -3.32694e+03 Fmax= 7.02461e+02, atom= 388
# Step=  699, Dmax= 9.9e-04 nm, Epot= -3.32696e+03 Fmax= 8.98275e+02, atom= 388
# Step=  700, Dmax= 1.2e-03 nm, Epot= -3.32702e+03 Fmax= 9.53914e+02, atom= 388
# Step=  702, Dmax= 7.2e-04 nm, Epot= -3.32757e+03 Fmax= 2.10875e+02, atom= 388
# Step=  704, Dmax= 4.3e-04 nm, Epot= -3.32772e+03 Fmax= 3.37076e+02, atom= 388
# Step=  705, Dmax= 5.2e-04 nm, Epot= -3.32783e+03 Fmax= 4.80155e+02, atom= 388
# Step=  706, Dmax= 6.2e-04 nm, Epot= -3.32798e+03 Fmax= 3.98910e+02, atom= 388
# Step=  708, Dmax= 3.7e-04 nm, Epot= -3.32815e+03 Fmax= 1.87287e+02, atom= 388
# Step=  709, Dmax= 4.5e-04 nm, Epot= -3.32828e+03 Fmax= 3.64903e+02, atom= 388
# Step=  710, Dmax= 5.3e-04 nm, Epot= -3.32839e+03 Fmax= 4.79901e+02, atom= 388
# Step=  711, Dmax= 6.4e-04 nm, Epot= -3.32852e+03 Fmax= 4.79925e+02, atom= 388
# Step=  713, Dmax= 3.8e-04 nm, Epot= -3.32873e+03 Fmax= 1.53349e+02, atom= 388
# Step=  714, Dmax= 4.6e-04 nm, Epot= -3.32883e+03 Fmax= 5.46871e+02, atom= 388
# Step=  715, Dmax= 5.5e-04 nm, Epot= -3.32905e+03 Fmax= 3.76361e+02, atom= 388
# Step=  717, Dmax= 3.3e-04 nm, Epot= -3.32920e+03 Fmax= 1.52774e+02, atom= 390
# Step=  718, Dmax= 4.0e-04 nm, Epot= -3.32930e+03 Fmax= 4.98283e+02, atom= 388
# Step=  719, Dmax= 4.8e-04 nm, Epot= -3.32952e+03 Fmax= 2.62519e+02, atom= 388
# Step=  721, Dmax= 2.9e-04 nm, Epot= -3.32961e+03 Fmax= 2.53173e+02, atom= 388
# Step=  722, Dmax= 3.4e-04 nm, Epot= -3.32973e+03 Fmax= 2.94315e+02, atom= 388
# Step=  723, Dmax= 4.1e-04 nm, Epot= -3.32981e+03 Fmax= 4.25650e+02, atom= 388
# Step=  724, Dmax= 5.0e-04 nm, Epot= -3.32995e+03 Fmax= 3.57329e+02, atom= 388
# Step=  726, Dmax= 3.0e-04 nm, Epot= -3.33009e+03 Fmax= 1.69566e+02, atom= 388
# Step=  727, Dmax= 3.6e-04 nm, Epot= -3.33020e+03 Fmax= 3.79852e+02, atom= 388
# Step=  728, Dmax= 4.3e-04 nm, Epot= -3.33034e+03 Fmax= 3.56879e+02, atom= 388
# Step=  729, Dmax= 5.1e-04 nm, Epot= -3.33042e+03 Fmax= 4.47710e+02, atom= 388
# Step=  730, Dmax= 6.2e-04 nm, Epot= -3.33048e+03 Fmax= 5.87680e+02, atom= 388
# Step=  731, Dmax= 7.4e-04 nm, Epot= -3.33061e+03 Fmax= 5.67451e+02, atom= 388
# Step=  733, Dmax= 4.4e-04 nm, Epot= -3.33087e+03 Fmax= 1.84238e+02, atom= 388
# Step=  734, Dmax= 5.3e-04 nm, Epot= -3.33091e+03 Fmax= 6.17042e+02, atom= 388
# Step=  735, Dmax= 6.4e-04 nm, Epot= -3.33116e+03 Fmax= 4.42772e+02, atom= 388
# Step=  737, Dmax= 3.8e-04 nm, Epot= -3.33132e+03 Fmax= 1.73251e+02, atom= 388
# Step=  738, Dmax= 4.6e-04 nm, Epot= -3.33134e+03 Fmax= 6.60940e+02, atom= 388
# Step=  739, Dmax= 5.5e-04 nm, Epot= -3.33165e+03 Fmax= 2.14229e+02, atom= 388
# Step=  741, Dmax= 3.3e-04 nm, Epot= -3.33173e+03 Fmax= 3.89248e+02, atom= 388
# Step=  742, Dmax= 4.0e-04 nm, Epot= -3.33188e+03 Fmax= 2.42998e+02, atom= 388
# ...
# Step=  749, Dmax= 5.9e-04 nm, Epot= -3.33258e+03 Fmax= 4.20362e+02, atom= 388
# Step=  751, Dmax= 3.6e-04 nm, Epot= -3.33275e+03 Fmax= 1.99387e+02, atom= 388
# Step=  752, Dmax= 4.3e-04 nm, Epot= -3.33282e+03 Fmax= 4.53200e+02, atom= 388
# Step=  753, Dmax= 5.1e-04 nm, Epot= -3.33299e+03 Fmax= 4.16152e+02, atom= 388
# Step=  754, Dmax= 6.2e-04 nm, Epot= -3.33303e+03 Fmax= 5.41981e+02, atom= 388
# Step=  755, Dmax= 7.4e-04 nm, Epot= -3.33309e+03 Fmax= 6.82914e+02, atom= 388
# Step=  756, Dmax= 8.9e-04 nm, Epot= -3.33318e+03 Fmax= 6.95778e+02, atom= 388
# Step=  758, Dmax= 5.3e-04 nm, Epot= -3.33352e+03 Fmax= 1.52263e+02, atom= 388
# Step=  760, Dmax= 3.2e-04 nm, Epot= -3.33364e+03 Fmax= 3.37441e+02, atom= 388
# Step=  761, Dmax= 3.8e-04 nm, Epot= -3.33378e+03 Fmax= 3.33822e+02, atom= 388
# Step=  762, Dmax= 4.6e-04 nm, Epot= -3.33385e+03 Fmax= 3.84911e+02, atom= 388
# Step=  763, Dmax= 5.5e-04 nm, Epot= -3.33393e+03 Fmax= 5.56030e+02, atom= 388
# Step=  764, Dmax= 6.6e-04 nm, Epot= -3.33405e+03 Fmax= 4.77381e+02, atom= 388
# Step=  766, Dmax= 4.0e-04 nm, Epot= -3.33426e+03 Fmax= 1.65846e+02, atom= 388
# Step=  767, Dmax= 4.8e-04 nm, Epot= -3.33432e+03 Fmax= 5.62838e+02, atom= 388
# Step=  768, Dmax= 5.7e-04 nm, Epot= -3.33456e+03 Fmax= 3.96312e+02, atom= 388
# Step=  769, Dmax= 6.9e-04 nm, Epot= -3.33458e+03 Fmax= 5.96183e+02, atom= 388
# Step=  770, Dmax= 8.2e-04 nm, Epot= -3.33461e+03 Fmax= 7.62338e+02, atom= 388
# Step=  771, Dmax= 9.9e-04 nm, Epot= -3.33469e+03 Fmax= 7.71010e+02, atom= 388
# Step=  773, Dmax= 5.9e-04 nm, Epot= -3.33508e+03 Fmax= 1.70747e+02, atom= 388
# Step=  775, Dmax= 3.6e-04 nm, Epot= -3.33519e+03 Fmax= 3.73907e+02, atom= 388
# Step=  776, Dmax= 4.3e-04 nm, Epot= -3.33534e+03 Fmax= 3.65485e+02, atom= 388
# Step=  777, Dmax= 5.1e-04 nm, Epot= -3.33539e+03 Fmax= 4.32076e+02, atom= 388
# Step=  778, Dmax= 6.2e-04 nm, Epot= -3.33547e+03 Fmax= 6.06484e+02, atom= 388
# Step=  779, Dmax= 7.4e-04 nm, Epot= -3.33557e+03 Fmax= 5.42091e+02, atom= 388
# Step=  781, Dmax= 4.4e-04 nm, Epot= -3.33581e+03 Fmax= 1.70448e+02, atom= 388
# Step=  782, Dmax= 5.3e-04 nm, Epot= -3.33594e+03 Fmax= 5.22057e+02, atom= 388
# Step=  783, Dmax= 6.4e-04 nm, Epot= -3.33609e+03 Fmax= 4.60277e+02, atom= 388
# Step=  785, Dmax= 3.8e-04 nm, Epot= -3.33626e+03 Fmax= 1.37006e+02, atom= 390
# Step=  786, Dmax= 4.6e-04 nm, Epot= -3.33628e+03 Fmax= 6.95099e+02, atom= 388
# Step=  787, Dmax= 5.5e-04 nm, Epot= -3.33663e+03 Fmax= 1.74824e+02, atom= 388
# Step=  789, Dmax= 3.3e-04 nm, Epot= -3.33675e+03 Fmax= 3.36051e+02, atom= 388
# Step=  790, Dmax= 4.0e-04 nm, Epot= -3.33687e+03 Fmax= 2.25339e+02, atom= 388
# Step=  791, Dmax= 4.8e-04 nm, Epot= -3.33688e+03 Fmax= 5.89244e+02, atom= 388
# Step=  792, Dmax= 5.7e-04 nm, Epot= -3.33712e+03 Fmax= 2.87513e+02, atom= 388
# Step=  794, Dmax= 3.4e-04 nm, Epot= -3.33724e+03 Fmax= 2.85408e+02, atom= 388
# Step=  795, Dmax= 4.1e-04 nm, Epot= -3.33733e+03 Fmax= 3.44554e+02, atom= 388
# Step=  796, Dmax= 4.9e-04 nm, Epot= -3.33741e+03 Fmax= 4.69132e+02, atom= 388
# Step=  797, Dmax= 5.9e-04 nm, Epot= -3.33751e+03 Fmax= 4.38508e+02, atom= 388
# Step=  799, Dmax= 3.6e-04 nm, Epot= -3.33770e+03 Fmax= 1.40932e+02, atom= 388
# Step=  800, Dmax= 4.3e-04 nm, Epot= -3.33780e+03 Fmax= 5.02911e+02, atom= 388
# Step=  801, Dmax= 5.1e-04 nm, Epot= -3.33801e+03 Fmax= 3.24625e+02, atom= 388
# Step=  802, Dmax= 6.1e-04 nm, Epot= -3.33806e+03 Fmax= 5.40655e+02, atom= 388
# Step=  803, Dmax= 7.4e-04 nm, Epot= -3.33812e+03 Fmax= 6.46629e+02, atom= 388
# Step=  804, Dmax= 8.8e-04 nm, Epot= -3.33817e+03 Fmax= 7.08575e+02, atom= 388
# Step=  806, Dmax= 5.3e-04 nm, Epot= -3.33851e+03 Fmax= 1.38373e+02, atom= 388
# Step=  808, Dmax= 3.2e-04 nm, Epot= -3.33863e+03 Fmax= 3.41547e+02, atom= 388
# Step=  809, Dmax= 3.8e-04 nm, Epot= -3.33877e+03 Fmax= 2.90370e+02, atom= 388
# Step=  810, Dmax= 4.6e-04 nm, Epot= -3.33883e+03 Fmax= 4.09128e+02, atom= 388
# Step=  811, Dmax= 5.5e-04 nm, Epot= -3.33894e+03 Fmax= 4.90148e+02, atom= 388
# Step=  812, Dmax= 6.6e-04 nm, Epot= -3.33901e+03 Fmax= 5.19823e+02, atom= 388
# Step=  814, Dmax= 4.0e-04 nm, Epot= -3.33924e+03 Fmax= 1.21458e+02, atom= 388
# Step=  815, Dmax= 4.8e-04 nm, Epot= -3.33946e+03 Fmax= 4.40291e+02, atom= 388
# Step=  816, Dmax= 5.7e-04 nm, Epot= -3.33959e+03 Fmax= 4.41602e+02, atom= 388
# Step=  817, Dmax= 6.8e-04 nm, Epot= -3.33964e+03 Fmax= 5.44745e+02, atom= 388
# Step=  819, Dmax= 4.1e-04 nm, Epot= -3.33987e+03 Fmax= 1.23707e+02, atom= 390
# Step=  820, Dmax= 4.9e-04 nm, Epot= -3.33990e+03 Fmax= 5.91031e+02, atom= 388
# Step=  821, Dmax= 5.9e-04 nm, Epot= -3.34023e+03 Fmax= 3.56544e+02, atom= 388
# Step=  823, Dmax= 3.5e-04 nm, Epot= -3.34037e+03 Fmax= 1.48010e+02, atom= 388
# Step=  824, Dmax= 4.3e-04 nm, Epot= -3.34041e+03 Fmax= 6.22470e+02, atom= 388
# Step=  825, Dmax= 5.1e-04 nm, Epot= -3.34068e+03 Fmax= 1.62615e+02, atom= 388
# Step=  827, Dmax= 3.1e-04 nm, Epot= -3.34077e+03 Fmax= 3.80234e+02, atom= 388
# Step=  828, Dmax= 3.7e-04 nm, Epot= -3.34091e+03 Fmax= 1.84388e+02, atom= 388
# Step=  829, Dmax= 4.4e-04 nm, Epot= -3.34093e+03 Fmax= 5.84545e+02, atom= 388
# Step=  830, Dmax= 5.3e-04 nm, Epot= -3.34118e+03 Fmax= 2.28255e+02, atom= 388
# Step=  832, Dmax= 3.2e-04 nm, Epot= -3.34126e+03 Fmax= 3.14487e+02, atom= 388
# Step=  833, Dmax= 3.8e-04 nm, Epot= -3.34137e+03 Fmax= 2.69876e+02, atom= 388
# Step=  834, Dmax= 4.6e-04 nm, Epot= -3.34141e+03 Fmax= 4.98822e+02, atom= 388
# Step=  835, Dmax= 5.5e-04 nm, Epot= -3.34157e+03 Fmax= 3.43131e+02, atom= 388
# Step=  837, Dmax= 3.3e-04 nm, Epot= -3.34170e+03 Fmax= 2.01913e+02, atom= 388
# Step=  838, Dmax= 4.0e-04 nm, Epot= -3.34177e+03 Fmax= 4.00549e+02, atom= 388
# Step=  839, Dmax= 4.7e-04 nm, Epot= -3.34189e+03 Fmax= 3.75766e+02, atom= 388
# Step=  840, Dmax= 5.7e-04 nm, Epot= -3.34194e+03 Fmax= 4.95185e+02, atom= 388
# Step=  841, Dmax= 6.8e-04 nm, Epot= -3.34198e+03 Fmax= 6.10299e+02, atom= 388
# Step=  842, Dmax= 8.2e-04 nm, Epot= -3.34206e+03 Fmax= 6.46289e+02, atom= 388
# Step=  844, Dmax= 4.9e-04 nm, Epot= -3.34238e+03 Fmax= 1.41853e+02, atom= 388
# Step=  846, Dmax= 3.0e-04 nm, Epot= -3.34248e+03 Fmax= 3.04000e+02, atom= 388
# Step=  847, Dmax= 3.5e-04 nm, Epot= -3.34260e+03 Fmax= 2.87500e+02, atom= 388
# Step=  848, Dmax= 4.3e-04 nm, Epot= -3.34267e+03 Fmax= 3.61767e+02, atom= 388
# Step=  849, Dmax= 5.1e-04 nm, Epot= -3.34275e+03 Fmax= 4.78655e+02, atom= 388
# Step=  850, Dmax= 6.1e-04 nm, Epot= -3.34285e+03 Fmax= 4.58595e+02, atom= 388
# Step=  852, Dmax= 3.7e-04 nm, Epot= -3.34304e+03 Fmax= 1.39499e+02, atom= 388
# Step=  853, Dmax= 4.4e-04 nm, Epot= -3.34311e+03 Fmax= 5.24833e+02, atom= 388
# Step=  854, Dmax= 5.3e-04 nm, Epot= -3.34333e+03 Fmax= 3.27065e+02, atom= 388
# Step=  855, Dmax= 6.3e-04 nm, Epot= -3.34335e+03 Fmax= 5.67797e+02, atom= 388
# Step=  856, Dmax= 7.6e-04 nm, Epot= -3.34342e+03 Fmax= 6.55070e+02, atom= 388
# Step=  857, Dmax= 9.1e-04 nm, Epot= -3.34344e+03 Fmax= 7.45835e+02, atom= 388
# Step=  859, Dmax= 5.5e-04 nm, Epot= -3.34380e+03 Fmax= 1.26668e+02, atom= 388
# Step=  861, Dmax= 3.3e-04 nm, Epot= -3.34389e+03 Fmax= 3.72587e+02, atom= 388
# Step=  862, Dmax= 3.9e-04 nm, Epot= -3.34406e+03 Fmax= 2.75238e+02, atom= 388
# Step=  863, Dmax= 4.7e-04 nm, Epot= -3.34408e+03 Fmax= 4.50138e+02, atom= 388
# Step=  864, Dmax= 5.7e-04 nm, Epot= -3.34421e+03 Fmax= 4.72548e+02, atom= 388
# Step=  865, Dmax= 6.8e-04 nm, Epot= -3.34423e+03 Fmax= 5.73578e+02, atom= 388
# Step=  866, Dmax= 8.2e-04 nm, Epot= -3.34426e+03 Fmax= 7.40109e+02, atom= 388
# Step=  867, Dmax= 9.8e-04 nm, Epot= -3.34431e+03 Fmax= 7.67394e+02, atom= 388
# Step=  869, Dmax= 5.9e-04 nm, Epot= -3.34469e+03 Fmax= 1.69716e+02, atom= 388
# Step=  870, Dmax= 7.1e-04 nm, Epot= -3.34471e+03 Fmax= 7.46301e+02, atom= 388
# Step=  871, Dmax= 8.5e-04 nm, Epot= -3.34495e+03 Fmax= 5.60435e+02, atom= 388
# Step=  873, Dmax= 5.1e-04 nm, Epot= -3.34515e+03 Fmax= 2.22166e+02, atom= 388
# Step=  875, Dmax= 3.1e-04 nm, Epot= -3.34524e+03 Fmax= 2.99263e+02, atom= 388
# Step=  876, Dmax= 3.7e-04 nm, Epot= -3.34533e+03 Fmax= 2.64202e+02, atom= 388
# Step=  877, Dmax= 4.4e-04 nm, Epot= -3.34537e+03 Fmax= 4.74020e+02, atom= 388
# Step=  878, Dmax= 5.3e-04 nm, Epot= -3.34551e+03 Fmax= 3.37075e+02, atom= 388
# Step=  880, Dmax= 3.2e-04 nm, Epot= -3.34564e+03 Fmax= 1.86573e+02, atom= 388
# Step=  881, Dmax= 3.8e-04 nm, Epot= -3.34570e+03 Fmax= 3.95102e+02, atom= 388
# Step=  882, Dmax= 4.6e-04 nm, Epot= -3.34583e+03 Fmax= 3.50376e+02, atom= 388
# Step=  883, Dmax= 5.5e-04 nm, Epot= -3.34586e+03 Fmax= 4.88871e+02, atom= 388
# Step=  884, Dmax= 6.6e-04 nm, Epot= -3.34593e+03 Fmax= 5.72846e+02, atom= 388
# Step=  885, Dmax= 7.9e-04 nm, Epot= -3.34597e+03 Fmax= 6.36563e+02, atom= 388
# Step=  887, Dmax= 4.7e-04 nm, Epot= -3.34627e+03 Fmax= 1.21311e+02, atom= 388
# Step=  888, Dmax= 5.7e-04 nm, Epot= -3.34642e+03 Fmax= 5.55968e+02, atom= 388
# Step=  889, Dmax= 6.8e-04 nm, Epot= -3.34657e+03 Fmax= 4.93578e+02, atom= 388
# Step=  891, Dmax= 4.1e-04 nm, Epot= -3.34676e+03 Fmax= 1.36155e+02, atom= 388
# Step=  893, Dmax= 2.5e-04 nm, Epot= -3.34684e+03 Fmax= 3.05300e+02, atom= 388
# Step=  894, Dmax= 2.9e-04 nm, Epot= -3.34696e+03 Fmax= 1.48155e+02, atom= 388
# Step=  895, Dmax= 3.5e-04 nm, Epot= -3.34707e+03 Fmax= 3.91223e+02, atom= 388
# Step=  896, Dmax= 4.2e-04 nm, Epot= -3.34718e+03 Fmax= 2.57880e+02, atom= 388
# Step=  898, Dmax= 2.5e-04 nm, Epot= -3.34728e+03 Fmax= 1.72612e+02, atom= 388
# Step=  899, Dmax= 3.1e-04 nm, Epot= -3.34736e+03 Fmax= 2.93091e+02, atom= 388
# Step=  900, Dmax= 3.7e-04 nm, Epot= -3.34746e+03 Fmax= 3.18121e+02, atom= 388
# Step=  901, Dmax= 4.4e-04 nm, Epot= -3.34753e+03 Fmax= 3.54995e+02, atom= 388
# Step=  902, Dmax= 5.3e-04 nm, Epot= -3.34758e+03 Fmax= 5.12908e+02, atom= 388
# Step=  903, Dmax= 6.3e-04 nm, Epot= -3.34769e+03 Fmax= 4.57412e+02, atom= 388
# Step=  905, Dmax= 3.8e-04 nm, Epot= -3.34787e+03 Fmax= 1.59481e+02, atom= 388
# Step=  906, Dmax= 4.6e-04 nm, Epot= -3.34790e+03 Fmax= 5.33008e+02, atom= 388
# Step=  907, Dmax= 5.5e-04 nm, Epot= -3.34810e+03 Fmax= 3.47506e+02, atom= 388
# Step=  909, Dmax= 3.3e-04 nm, Epot= -3.34821e+03 Fmax= 1.55516e+02, atom= 388
# Step=  910, Dmax= 3.9e-04 nm, Epot= -3.34823e+03 Fmax= 5.46767e+02, atom= 388
# Step=  911, Dmax= 4.7e-04 nm, Epot= -3.34845e+03 Fmax= 1.78676e+02, atom= 388
# Step=  913, Dmax= 2.8e-04 nm, Epot= -3.34853e+03 Fmax= 3.17402e+02, atom= 388
# Step=  914, Dmax= 3.4e-04 nm, Epot= -3.34863e+03 Fmax= 2.05359e+02, atom= 388
# Step=  915, Dmax= 4.1e-04 nm, Epot= -3.34865e+03 Fmax= 4.95509e+02, atom= 388
# Step=  916, Dmax= 4.9e-04 nm, Epot= -3.34883e+03 Fmax= 2.56889e+02, atom= 388
# Step=  918, Dmax= 2.9e-04 nm, Epot= -3.34892e+03 Fmax= 2.38624e+02, atom= 388
# Step=  919, Dmax= 3.5e-04 nm, Epot= -3.34900e+03 Fmax= 3.02611e+02, atom= 388
# Step=  920, Dmax= 4.2e-04 nm, Epot= -3.34906e+03 Fmax= 4.00435e+02, atom= 388
# Step=  921, Dmax= 5.1e-04 nm, Epot= -3.34916e+03 Fmax= 3.78899e+02, atom= 388
# Step=  923, Dmax= 3.0e-04 nm, Epot= -3.34930e+03 Fmax= 1.21798e+02, atom= 388
# Step=  924, Dmax= 3.7e-04 nm, Epot= -3.34938e+03 Fmax= 4.32245e+02, atom= 388
# Step=  925, Dmax= 4.4e-04 nm, Epot= -3.34954e+03 Fmax= 2.81640e+02, atom= 388
# Step=  927, Dmax= 2.6e-04 nm, Epot= -3.34964e+03 Fmax= 1.39378e+02, atom= 390
# Step=  928, Dmax= 3.2e-04 nm, Epot= -3.34971e+03 Fmax= 3.90000e+02, atom= 388
# Step=  929, Dmax= 3.8e-04 nm, Epot= -3.34986e+03 Fmax= 1.92213e+02, atom= 388
# Step=  931, Dmax= 2.3e-04 nm, Epot= -3.34993e+03 Fmax= 2.02848e+02, atom= 388
# Step=  932, Dmax= 2.7e-04 nm, Epot= -3.35003e+03 Fmax= 2.16102e+02, atom= 388
# Step=  933, Dmax= 3.3e-04 nm, Epot= -3.35008e+03 Fmax= 3.43956e+02, atom= 388
# Step=  934, Dmax= 3.9e-04 nm, Epot= -3.35020e+03 Fmax= 2.59639e+02, atom= 388
# Step=  936, Dmax= 2.4e-04 nm, Epot= -3.35029e+03 Fmax= 1.38874e+02, atom= 388
# Step=  937, Dmax= 2.8e-04 nm, Epot= -3.35037e+03 Fmax= 2.92921e+02, atom= 388
# Step=  938, Dmax= 3.4e-04 nm, Epot= -3.35048e+03 Fmax= 2.73268e+02, atom= 388
# Step=  939, Dmax= 4.1e-04 nm, Epot= -3.35054e+03 Fmax= 3.51098e+02, atom= 388
# Step=  940, Dmax= 4.9e-04 nm, Epot= -3.35060e+03 Fmax= 4.54050e+02, atom= 388
# Step=  941, Dmax= 5.9e-04 nm, Epot= -3.35069e+03 Fmax= 4.45685e+02, atom= 388
# Step=  943, Dmax= 3.5e-04 nm, Epot= -3.35086e+03 Fmax= 1.27570e+02, atom= 388
# Step=  944, Dmax= 4.2e-04 nm, Epot= -3.35092e+03 Fmax= 5.11719e+02, atom= 388
# Step=  945, Dmax= 5.1e-04 nm, Epot= -3.35112e+03 Fmax= 3.06638e+02, atom= 388
# Step=  947, Dmax= 3.0e-04 nm, Epot= -3.35121e+03 Fmax= 1.59380e+02, atom= 388
# Step=  948, Dmax= 3.6e-04 nm, Epot= -3.35124e+03 Fmax= 4.90552e+02, atom= 388
# Step=  949, Dmax= 4.4e-04 nm, Epot= -3.35143e+03 Fmax= 1.82139e+02, atom= 388
# Step=  951, Dmax= 2.6e-04 nm, Epot= -3.35150e+03 Fmax= 2.77425e+02, atom= 388
# Step=  952, Dmax= 3.2e-04 nm, Epot= -3.35160e+03 Fmax= 2.07248e+02, atom= 388
# Step=  953, Dmax= 3.8e-04 nm, Epot= -3.35163e+03 Fmax= 4.42647e+02, atom= 388
# Step=  954, Dmax= 4.5e-04 nm, Epot= -3.35178e+03 Fmax= 2.54918e+02, atom= 388
# Step=  955, Dmax= 5.4e-04 nm, Epot= -3.35178e+03 Fmax= 5.82695e+02, atom= 388
# Step=  956, Dmax= 6.5e-04 nm, Epot= -3.35193e+03 Fmax= 4.19542e+02, atom= 388
# Step=  958, Dmax= 3.9e-04 nm, Epot= -3.35208e+03 Fmax= 2.21659e+02, atom= 388
# Step=  959, Dmax= 4.7e-04 nm, Epot= -3.35209e+03 Fmax= 4.96813e+02, atom= 388
# Step=  960, Dmax= 5.6e-04 nm, Epot= -3.35223e+03 Fmax= 4.14794e+02, atom= 388
# Step=  962, Dmax= 3.4e-04 nm, Epot= -3.35237e+03 Fmax= 1.27209e+02, atom= 390
# Step=  963, Dmax= 4.1e-04 nm, Epot= -3.35241e+03 Fmax= 5.32156e+02, atom= 388
# Step=  964, Dmax= 4.9e-04 nm, Epot= -3.35263e+03 Fmax= 2.17572e+02, atom= 388
# Step=  966, Dmax= 2.9e-04 nm, Epot= -3.35272e+03 Fmax= 2.32979e+02, atom= 388
# Step=  967, Dmax= 3.5e-04 nm, Epot= -3.35279e+03 Fmax= 3.04029e+02, atom= 388
# Step=  968, Dmax= 4.2e-04 nm, Epot= -3.35285e+03 Fmax= 3.98340e+02, atom= 388
# Step=  969, Dmax= 5.1e-04 nm, Epot= -3.35294e+03 Fmax= 3.78467e+02, atom= 388
# Step=  971, Dmax= 3.0e-04 nm, Epot= -3.35307e+03 Fmax= 1.20638e+02, atom= 388
# Step=  972, Dmax= 3.6e-04 nm, Epot= -3.35314e+03 Fmax= 4.32679e+02, atom= 388
# Step=  973, Dmax= 4.4e-04 nm, Epot= -3.35330e+03 Fmax= 2.78815e+02, atom= 388
# Step=  975, Dmax= 2.6e-04 nm, Epot= -3.35340e+03 Fmax= 1.40696e+02, atom= 390
# Step=  976, Dmax= 3.1e-04 nm, Epot= -3.35344e+03 Fmax= 3.88093e+02, atom= 388
# Step=  977, Dmax= 3.8e-04 nm, Epot= -3.35360e+03 Fmax= 1.92545e+02, atom= 388
# Step=  978, Dmax= 4.5e-04 nm, Epot= -3.35361e+03 Fmax= 5.03091e+02, atom= 388
# Step=  979, Dmax= 5.4e-04 nm, Epot= -3.35376e+03 Fmax= 3.30778e+02, atom= 388
# Step=  981, Dmax= 3.3e-04 nm, Epot= -3.35388e+03 Fmax= 2.10997e+02, atom= 388
# Step=  982, Dmax= 3.9e-04 nm, Epot= -3.35393e+03 Fmax= 3.87435e+02, atom= 388
# Step=  983, Dmax= 4.7e-04 nm, Epot= -3.35402e+03 Fmax= 3.82590e+02, atom= 388
# Step=  984, Dmax= 5.6e-04 nm, Epot= -3.35406e+03 Fmax= 4.81831e+02, atom= 388
# Step=  985, Dmax= 6.8e-04 nm, Epot= -3.35408e+03 Fmax= 6.13332e+02, atom= 388
# Step=  986, Dmax= 8.1e-04 nm, Epot= -3.35415e+03 Fmax= 6.32745e+02, atom= 388
# Step=  988, Dmax= 4.9e-04 nm, Epot= -3.35442e+03 Fmax= 1.47884e+02, atom= 388
# Step=  990, Dmax= 2.9e-04 nm, Epot= -3.35450e+03 Fmax= 2.97008e+02, atom= 388
# Step=  991, Dmax= 3.5e-04 nm, Epot= -3.35459e+03 Fmax= 2.88576e+02, atom= 388
# Step=  992, Dmax= 4.2e-04 nm, Epot= -3.35465e+03 Fmax= 3.56610e+02, atom= 388
# Step=  993, Dmax= 5.1e-04 nm, Epot= -3.35469e+03 Fmax= 4.75152e+02, atom= 388
# Step=  994, Dmax= 6.1e-04 nm, Epot= -3.35478e+03 Fmax= 4.55134e+02, atom= 388
# Step=  996, Dmax= 3.6e-04 nm, Epot= -3.35495e+03 Fmax= 1.36778e+02, atom= 388
# Step=  997, Dmax= 4.4e-04 nm, Epot= -3.35496e+03 Fmax= 5.25697e+02, atom= 388
# Step=  998, Dmax= 5.2e-04 nm, Epot= -3.35517e+03 Fmax= 3.19094e+02, atom= 388
# Step= 1000, Dmax= 3.1e-04 nm, Epot= -3.35527e+03 Fmax= 1.63075e+02, atom= 388
#
# Energy minimization reached the maximum number of steps before the forces
# reached the requested precision Fmax < 10.
#
# writing lowest energy coordinates.
#
# Steepest Descents did not converge to Fmax < 10 in 1001 steps.
# Potential Energy  = -3.3552705e+03
# Maximum force     =  1.6307451e+02 on atom 388
# Norm of force     =  1.9020962e+01
#
# GROMACS reminds you: "But I always say, one's company, two's a crowd, and three's a party." (Andy Warhol)

# %%
! echo -e "Potential \n 0" | gmx energy -f cadymin.edr -o potential.xvg
# Out:
#               :-) GROMACS - gmx energy, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx energy, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx energy -f cadymin.edr -o potential.xvg
#
# Opened cadymin.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Proper-Dih.      4  Improper-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Coulomb-(SR)
#   9  Potential       10  Pressure        11  Vir-XX          12  Vir-XY
#  13  Vir-XZ          14  Vir-YX          15  Vir-YY          16  Vir-YZ
#  17  Vir-ZX          18  Vir-ZY          19  Vir-ZZ          20  Pres-XX
#  21  Pres-XY         22  Pres-XZ         23  Pres-YX         24  Pres-YY
#  25  Pres-YZ         26  Pres-ZX         27  Pres-ZY         28  Pres-ZZ
#  29  #Surf*SurfTen   30  T-rest
#
# Last energy frame read 788 time 1000.000
#
# Statistics over 1001 steps [ 0.0000 through 1000.0000 ps ], 1 data sets
# All statistics are over 789 points (frames)
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Potential                  -3261.11         46    152.046   -310.165  (kJ/mol)
#
# GROMACS reminds you: "I'll Match Your DNA" (Red Hot Chili Peppers)

# %%
import matplotlib.pyplot as plt # Import from the library matplotlib  the package pyplot and alias it as plt 
import numpy as np #import the library numpy and alias it as np
'''load the data from the potential.xvg format into data, ...
define the comments as raw starting with either # or @'''
data=np.loadtxt("potential.xvg",comments=["#","@"])
step=data[:,0] #assign the first column of data to the variable step
energy=data[:,1] #assign the second column of data to the variable potential
plt.plot(step,energy) #plot the function potential(data)
plt.xlabel("Step",size=14) #assign the x label 
plt.ylabel("Energy [KJ/mol]",size=14) #assign the y label
plt.title("Potential energy as a function of step"); #assign a title 
#save the figure in png format with a resolution of 300 dot per inch "dpi" 
plt.savefig("potential_steep_w.png",format="png", dpi=300)

# %%
ls
# Out:
#  box.gro        cadywmin.log     dummy.mdp     potential_steep_w.png
#  box_ions.gro   cadywmin.trr     ions.tpr      potential.xvg
#  cady_3.pdb     cadyw.top        mdout.mdp     sample_data/
#  cadyw.gro     '#cadyw.top.1#'   position2/    solvated.gro
#  cadywmin.edr  '#cadyw.top.2#'   posre.itp     template.mdp
#  cadywmin.gro   cadyw.tpr       'posre.mdp '

# %%
# !gmx grompp -f template.mdp -p cady.top -c cadymin.gro -r cadymin.gro  -o posre2.tpr -maxwarn 2
# Out:
#               :-) GROMACS - gmx grompp, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx grompp -f template.mdp -p cady.top -c cadymin.gro -r cadymin.gro -o posre2.tpr -maxwarn 2
#
# Ignoring obsolete mdp entry 'ns-type'
# Replacing old mdp entry 'nstxtcout' by 'nstxout-compressed'
#
# NOTE 1 [file template.mdp]:
#   nstcomm < nstcalcenergy defeats the purpose of nstcalcenergy, setting
#   nstcomm to nstcalcenergy
#
# Setting the LD random seed to 797797810
# Generated 2145 of the 2145 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
# Generated 2145 of the 2145 1-4 parameter combinations
# Excluding 3 bonded neighbours molecule type 'Protein'
# turning all bonds into constraints...
#
# NOTE 2 [file cady.top, line 3738]:
#   System has non-zero total charge: 5.000000
#   Total charge should normally be an integer. See
#   http://www.gromacs.org/Documentation/Floating_Point_Arithmetic
#   for discussion on how close it should be to an integer.
#
#
#
#
# NOTE 3 [file unknown]:
#   You are using constraints on all bonds, whereas the forcefield has been
#   parametrized only with constraints involving hydrogen atoms. We suggest
#   using constraints = h-bonds instead, this will also improve performance.
#
# Velocities were taken from a Maxwell distribution at 300 K
# The center of mass of the position restraint coord's is  3.675  3.702  1.726
# The center of mass of the position restraint coord's is  3.675  3.702  1.726
# Analysing residue names:
# There are:    20    Protein residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group Protein is 770.00
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 300 K
# Calculated rlist for 1x1 atom pair-list as 1.038 nm, buffer size 0.038 nm
# Set rlist, assuming 4x4 atom pair-list, to 1.027 nm, buffer size 0.027 nm
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# NOTE 4 [file template.mdp]:
#   Removing center of mass motion in the presence of position restraints
#   might cause artifacts. When you are using position restraints to
#   equilibrate a macro-molecule, the artifacts are usually negligible.
#
#
# NOTE 5 [file template.mdp]:
#   You are using a plain Coulomb cut-off, which might produce artifacts.
#   You might want to consider using PME electrostatics.
#
#
# This run will generate roughly 39 Mb of data
#
# There were 5 notes
#
# GROMACS reminds you: "I didn't know what MD was. I think I've managed to catch up." (Berk Hess)

# %%
# !gmx mdrun -s posre2.tpr -deffnm posre2 -v -nt 10
# Out:
#               :-) GROMACS - gmx mdrun, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx mdrun, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx mdrun -s posre2.tpr -deffnm posre2 -v -nt 10
#
# Compiled SIMD: SSE2, but for this host/run AVX2_256 might be better (see log).
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file posre2.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
# Changing nstlist from 20 to 80, rlist from 1.027 to 1.147
#
#
# Using 1 MPI thread
#
# Non-default thread affinity set, disabling internal thread affinity
#
# Using 10 OpenMP threads
#
#
# WARNING: Oversubscribing the available 2 logical CPU cores with 10 threads.
#          This will cause considerable performance loss.
# starting mdrun 'Glycine aRginine prOline Methionine Alanine Cystine Serine in water t= 30000.00000'
# 250000 steps,    250.0 ps.
# step 249900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 250000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     3770.163      377.016     1000.0
#                  (ns/day)    (hour/ns)
# Performance:       57.292        0.419
#
# GROMACS reminds you: "Try to calculate the numbers that have been" (The Smoke Fairies)

# %%
! echo -e "Temperature" | gmx energy -f posre2.edr -o Temp2.xvg
# Out:
#               :-) GROMACS - gmx energy, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx energy, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx energy -f posre2.edr -o Temp2.xvg
#
# Opened posre2.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Angle            2  Proper-Dih.      3  Improper-Dih.    4  LJ-14
#   5  Coulomb-14       6  LJ-(SR)          7  Coulomb-(SR)     8  Position-Rest.
#   9  Potential       10  Kinetic-En.     11  Total-Energy    12  Conserved-En.
#  13  Temperature     14  Pressure        15  Constr.-rmsd    16  Box-X
#  17  Box-Y           18  Box-Z           19  Volume          20  Density
#  21  pV              22  Enthalpy        23  Vir-XX          24  Vir-XY
#  25  Vir-XZ          26  Vir-YX          27  Vir-YY          28  Vir-YZ
#  29  Vir-ZX          30  Vir-ZY          31  Vir-ZZ          32  Pres-XX
#  33  Pres-XY         34  Pres-XZ         35  Pres-YX         36  Pres-YY
#  37  Pres-YZ         38  Pres-ZX         39  Pres-ZY         40  Pres-ZZ
#  41  #Surf*SurfTen   42  T-Protein       43  Lamb-Protein
#
#
# Back Off! I just backed up Temp2.xvg to ./#Temp2.xvg.1#
# Last energy frame read 25000 time  250.000
#
# Statistics over 250001 steps [ 0.0000 through 250.0000 ps ], 1 data sets
# All statistics are over 25001 points (frames)
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Temperature                 299.945        1.2    17.1931    6.28822  (K)
#
# GROMACS reminds you: "Baseball Heroes Only" (P.J. Harvey)

# %%
# !gmx grompp -f template.mdp -p cady.top -c posre2.gro  -o cady_D2.tpr -maxwarn 2
# Out:
#               :-) GROMACS - gmx grompp, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx grompp -f template.mdp -p cady.top -c posre2.gro -o cady_D2.tpr -maxwarn 2
#
# Ignoring obsolete mdp entry 'ns-type'
# Replacing old mdp entry 'nstxtcout' by 'nstxout-compressed'
#
# NOTE 1 [file template.mdp]:
#   nstcomm < nstcalcenergy defeats the purpose of nstcalcenergy, setting
#   nstcomm to nstcalcenergy
#
# Setting the LD random seed to -1720781356
# Generated 2145 of the 2145 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
# Generated 2145 of the 2145 1-4 parameter combinations
# Excluding 3 bonded neighbours molecule type 'Protein'
# turning all bonds into constraints...
#
# NOTE 2 [file cady.top, line 3738]:
#   System has non-zero total charge: 5.000000
#   Total charge should normally be an integer. See
#   http://www.gromacs.org/Documentation/Floating_Point_Arithmetic
#   for discussion on how close it should be to an integer.
#
#
#
#
# NOTE 3 [file unknown]:
#   You are using constraints on all bonds, whereas the forcefield has been
#   parametrized only with constraints involving hydrogen atoms. We suggest
#   using constraints = h-bonds instead, this will also improve performance.
#
# Analysing residue names:
# There are:    20    Protein residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group Protein is 770.00
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 300 K
# Calculated rlist for 1x1 atom pair-list as 1.085 nm, buffer size 0.085 nm
# Set rlist, assuming 4x4 atom pair-list, to 1.062 nm, buffer size 0.062 nm
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# NOTE 4 [file template.mdp]:
#   You are using a plain Coulomb cut-off, which might produce artifacts.
#   You might want to consider using PME electrostatics.
#
#
# This run will generate roughly 12 Mb of data
#
# There were 4 notes
#
# GROMACS reminds you: "It has not escaped our notice that the specific pairing we have postulated immediately suggests a possible copying mechanism for the genetic material." (Watson & Crick)

# %%
# !gmx mdrun -deffnm cady_D2 -s cady_D2.tpr -v -nt 10
# Out:
#               :-) GROMACS - gmx mdrun, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx mdrun, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx mdrun -deffnm cady_D2 -s cady_D2.tpr -v -nt 10
#
# Compiled SIMD: SSE2, but for this host/run AVX2_256 might be better (see log).
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file cady_D2.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
# Changing nstlist from 20 to 50, rlist from 1.062 to 1.187
#
#
# Using 1 MPI thread
#
# Non-default thread affinity set, disabling internal thread affinity
#
# Using 10 OpenMP threads
#
#
# WARNING: Oversubscribing the available 2 logical CPU cores with 10 threads.
#          This will cause considerable performance loss.
# starting mdrun 'Glycine aRginine prOline Methionine Alanine Cystine Serine in water t= 30000.00000'
# 2000000 steps,   4000.0 ps.
# step 1999900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 2000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:    29165.086     2916.509     1000.0
#                          48:36
#                  (ns/day)    (hour/ns)
# Performance:      118.498        0.203
#
# GROMACS reminds you: "Input, output, electricity" (Joni Mitchell)

# %%
 # !echo -e "Temperature" | gmx energy -f cady_D2.edr -o Temp_D2.xvg
# Out:
#               :-) GROMACS - gmx energy, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx energy, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx energy -f cady_D2.edr -o Temp_D2.xvg
#
# Opened cady_D2.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Angle            2  Proper-Dih.      3  Improper-Dih.    4  LJ-14
#   5  Coulomb-14       6  LJ-(SR)          7  Coulomb-(SR)     8  Potential
#   9  Kinetic-En.     10  Total-Energy    11  Conserved-En.   12  Temperature
#  13  Pressure        14  Constr.-rmsd    15  Box-X           16  Box-Y
#  17  Box-Z           18  Volume          19  Density         20  pV
#  21  Enthalpy        22  Vir-XX          23  Vir-XY          24  Vir-XZ
#  25  Vir-YX          26  Vir-YY          27  Vir-YZ          28  Vir-ZX
#  29  Vir-ZY          30  Vir-ZZ          31  Pres-XX         32  Pres-XY
#  33  Pres-XZ         34  Pres-YX         35  Pres-YY         36  Pres-YZ
#  37  Pres-ZX         38  Pres-ZY         39  Pres-ZZ         40  #Surf*SurfTen
#  41  T-Protein       42  Lamb-Protein
#
# Last energy frame read 2000 time 4000.000
#
# Statistics over 2000001 steps [ 0.0000 through 4000.0000 ps ], 1 data sets
# All statistics are over 2001 points (frames)
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Temperature                 299.226       0.38    15.1432    0.75058  (K)
#
# GROMACS reminds you: "It's Time to Move On" (F. Black)

# %%
import matplotlib.pyplot as plt # Import from the library matplotlib  the package pyplot and alias it as plt 
import numpy as np #import the library numpy and alias it as np
'''load the data from the potential.xvg format into data, ...
define the comments as raw starting with either # or @'''
data=np.loadtxt("Temp_D2.xvg",comments=["#","@"])
step=data[:,0] #assign the first column of data to the variable step
energy=data[:,1] #assign the second column of data to the variable potential
plt.plot(step,energy) #plot the function potential(data)
plt.xlabel("Time [ps]",size=14) #assign the x label 
plt.ylabel("Temperature [K]",size=14) #assign the y label
plt.title("Temperature as a function of Time"); #assign a title 
plt.xlim(3750,4000)
# Out:
# (3750.0, 4000.0)

# %%
! echo -e "0 \n" | gmx trjconv -s cady_D2.tpr -f cady_D2.xtc -pbc mol -o cady_D2_new.xtc -ur compact
# Out:
#              :-) GROMACS - gmx trjconv, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx trjconv -s cady_D2.tpr -f cady_D2.xtc -pbc mol -o cady_D2_new.xtc -ur compact
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write xtc: Compressed trajectory (portable xdr format): xtc
# Reading file cady_D2.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
# Reading file cady_D2.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
# Select group for output
# Group     0 (         System) has   390 elements
# Group     1 (        Protein) has   390 elements
# Group     2 (      Protein-H) has   188 elements
# Group     3 (        C-alpha) has    20 elements
# Group     4 (       Backbone) has    60 elements
# Group     5 (      MainChain) has    81 elements
# Group     6 (   MainChain+Cb) has   100 elements
# Group     7 (    MainChain+H) has   103 elements
# Group     8 (      SideChain) has   287 elements
# Group     9 (    SideChain-H) has   107 elements
# Select a group: Selected 0: 'System'
# Reading frame       0 time    0.000
# Precision of cady_D2.xtc is 0.001 (nm)
# Using output precision of 0.001 (nm)
# Last frame       2000 time 4000.000
#
#
# GROMACS reminds you: "Science is organized knowledge. Wisdom is organized life." (Immanuel Kant)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
comm=["#","@"]
temperature=np.loadtxt(f"Temp_D2.xvg",usecols=(1),comments=comm) 
v=temperature[1075:2001]
print(v)
print(np.mean(v))
print(np.std(v))
# Out:
# [302.614075 300.554504 297.31015  277.570953 319.188843 300.787994
#  301.03772  331.034119 286.508057 312.748291 326.33374  316.945038
#  323.405304 320.868439 287.801788 261.774414 305.466034 317.9505
#  299.290405 284.953064 287.132782 307.028931 303.026917 288.452118
#  296.60022  306.570068 303.093689 285.40332  296.787262 301.625854
#  278.865784 333.310669 306.266266 313.474854 307.635498 291.957611
#  283.882416 327.255035 302.129089 283.099274 307.440186 307.660736
#  334.461151 287.15979  320.345581 328.863922 311.427063 273.878448
#  293.450073 301.203033 341.902222 293.70639  278.223053 291.68161
#  310.791992 292.798645 315.856934 300.661377 297.368439 281.903748
#  302.538147 319.550842 274.857361 326.815491 302.422363 304.740967
#  282.580688 303.052643 294.868835 295.570923 309.778198 309.605621
#  312.039307 286.032959 311.047028 331.331909 309.19516  282.468445
#  296.256592 322.674927 312.519958 321.311523 317.70517  311.567413
#  280.375977 291.380341 294.049835 285.586609 310.436554 301.130005
#  294.022003 286.098816 294.48587  289.581085 310.665741 293.425781
#  274.246979 289.706207 270.753601 278.834961 299.737915 295.851807
#  313.123138 302.84726  289.797058 296.695312 318.028625 282.967957
#  296.896606 322.861389 292.124817 306.424744 288.003265 288.683655
#  299.920105 327.091888 295.378815 312.569153 312.146301 288.89743
#  297.380005 292.710663 297.898315 342.868439 298.752899 280.383636
#  309.171478 268.922546 307.814789 320.711884 287.382599 294.431274
#  295.148224 341.626434 330.343689 287.774719 294.972656 276.056091
#  301.952728 316.920013 308.877502 294.83783  284.337616 296.766113
#  286.972748 276.135895 273.657043 303.407867 304.959717 312.054321
#  305.037109 292.119843 295.414215 274.575623 311.81369  314.940186
#  313.649323 324.376434 317.822693 291.066895 331.34082  299.370972
#  316.849182 296.699036 268.881378 293.710571 289.517426 289.643799
#  325.884949 298.890442 277.792725 289.217499 300.323059 308.425751
#  304.059692 278.980682 303.543335 318.009155 274.704498 287.214569
#  290.20517  270.01062  297.951752 261.398987 286.362823 343.033966
#  293.763885 306.021851 302.356781 288.883057 302.348724 279.074585
#  307.379028 300.982422 293.907623 307.324249 298.760986 286.793091
#  294.714722 320.365936 316.504211 305.046112 278.960327 282.622986
#  275.744385 307.968475 282.830627 288.239227 319.67807  293.874207
#  291.621582 310.533813 300.988281 307.201477 286.211914 299.439087
#  299.852417 272.637878 293.066803 288.281189 291.91806  323.20282
#  295.287445 321.174988 331.279205 280.468414 289.996368 304.494202
#  299.026276 309.783203 309.069458 295.817139 298.790619 281.896637
#  275.489929 280.198822 296.442719 297.79776  276.76825  300.987518
#  293.661713 302.492615 321.321075 295.618744 277.57785  284.290955
#  314.575623 301.628204 294.718597 290.291504 302.333374 300.931396
#  299.043701 314.63504  334.510925 294.529877 313.277466 289.438568
#  282.721497 274.191864 297.706635 291.263855 294.41748  312.160828
#  301.572418 306.774658 287.600525 324.292328 319.675934 291.547058
#  329.496643 302.066101 292.372437 299.863708 284.766724 291.746185
#  300.355255 301.011688 256.963013 273.70578  273.525391 280.041229
#  296.48233  307.494934 296.601715 291.294128 296.459991 292.388153
#  318.76355  302.802979 303.533417 292.647308 329.395508 290.495911
#  301.083405 306.196289 300.938263 323.171844 316.98996  311.989716
#  301.015564 286.433594 307.609131 291.143555 296.356049 267.903198
#  301.254547 293.937012 285.66748  329.186615 312.68277  299.201294
#  306.54184  314.707581 311.398254 318.007751 302.644806 312.705139
#  303.472198 315.678101 283.630005 307.563507 304.032715 292.796417
#  289.82135  302.776398 287.347046 308.191925 300.94397  318.680908
#  280.598663 288.909882 282.640045 305.448883 303.312225 293.356201
#  304.183075 312.03302  311.955658 316.81781  311.625153 322.088776
#  267.980713 278.891571 311.041565 312.62561  300.607605 298.535492
#  291.542267 300.919525 314.009979 300.15625  305.036987 325.62207
#  283.677826 268.696716 304.968445 319.99939  306.512695 287.514862
#  319.639648 313.31604  309.944183 297.780121 324.469574 310.239929
#  330.93811  282.83432  322.477814 296.997833 289.008667 288.588989
#  278.220642 289.99881  302.486938 281.677856 306.969482 291.091644
#  291.8638   259.709106 287.684143 299.237091 291.202667 310.894623
#  301.35022  298.616821 293.203217 294.641083 308.161072 302.721558
#  276.041046 298.656525 303.95932  285.713104 308.992798 329.587341
#  312.326782 327.715576 330.576416 305.588379 313.897278 267.165894
#  297.616913 301.073761 280.589081 283.027313 286.063171 295.204895
#  308.622864 289.265411 300.083038 286.760925 323.895447 305.416199
#  327.540741 327.047424 321.627075 294.791748 279.013855 298.334686
#  291.278595 276.837799 318.794708 301.672821 318.632507 332.009277
#  313.712738 300.525513 313.812195 287.429047 281.435272 307.965302
#  319.111542 325.874481 281.893219 266.652069 279.186249 302.865723
#  295.671509 298.733551 286.515533 291.403442 305.414307 301.762177
#  287.09082  313.636322 297.0448   285.893524 307.878601 313.124268
#  293.64325  309.194122 299.163605 317.757355 296.82019  303.620117
#  259.523651 306.794098 323.274292 338.861511 319.841278 283.720123
#  286.56134  317.966736 301.837189 288.470428 325.88031  272.121857
#  288.107483 306.672302 293.714996 291.771027 291.414734 291.806519
#  281.449188 286.313232 331.874329 319.111572 275.305206 304.351715
#  307.726959 303.975159 293.074585 288.808594 296.714233 303.138977
#  303.976898 288.202576 286.283234 286.707703 286.371429 296.81076
#  271.683411 299.903442 305.477478 314.631653 324.107147 300.131226
#  294.621033 280.124084 289.480408 290.766693 287.186829 273.804779
#  302.472839 301.577545 299.1763   307.614563 298.997284 297.737457
#  281.088562 308.595856 313.547333 291.527374 289.811096 297.735596
#  309.416382 313.576965 290.037933 330.060394 331.519745 306.670319
#  295.677521 326.44577  293.457245 311.034973 309.093781 300.981476
#  304.368835 295.659851 294.407623 306.73111  304.542786 295.11557
#  272.807129 282.109955 298.047791 290.010132 322.320129 326.216949
#  325.253326 277.172882 261.795349 297.5242   289.312164 311.47287
#  330.5159   300.895264 308.93396  266.56546  289.301849 309.048004
#  308.73233  286.067413 304.318024 277.407928 287.868286 294.717194
#  285.999146 257.829529 281.29187  315.778046 288.822021 309.123596
#  305.426727 316.078186 292.899994 286.290558 278.523773 301.875732
#  294.248138 276.807312 290.78952  279.56015  314.574585 305.186676
#  272.904816 298.775177 296.64328  296.926239 312.809875 265.204742
#  301.106171 292.980011 297.044128 291.832458 336.144501 291.262878
#  295.07901  283.30011  289.450623 313.112488 283.886902 294.297791
#  287.961548 290.770569 306.711334 295.645813 301.294312 297.501526
#  314.325256 283.895721 300.620667 290.042877 301.2117   294.728149
#  324.294617 295.51413  308.131378 300.38681  332.760559 319.20752
#  305.260315 300.590973 270.654663 268.491882 286.196259 296.746063
#  287.729248 289.520966 294.769531 308.309082 296.580078 310.850037
#  284.42511  281.712067 281.152618 313.488037 294.851074 293.115173
#  286.294586 303.025635 297.73288  345.099304 325.765594 299.486267
#  277.959167 284.295654 284.026337 312.336975 271.481934 276.228058
#  272.648621 303.698669 305.476227 316.068909 316.938995 325.366364
#  317.90387  288.14975  275.888062 284.815033 303.021179 302.000854
#  315.04599  329.125702 285.009369 273.744446 285.30307  304.85965
#  300.600128 255.954041 301.142487 286.171295 307.359772 305.641632
#  313.310974 267.635559 298.714447 298.33429  282.61972  304.68869
#  316.365234 290.349945 300.393219 290.813202 305.072357 295.884644
#  313.149902 285.477875 308.103302 308.188141 302.443878 299.567535
#  295.749359 301.141937 284.557373 288.600555 286.859497 313.354797
#  308.05188  293.814697 271.657837 271.371918 316.881836 296.258392
#  281.37262  266.401581 307.89035  310.703949 312.004242 282.204681
#  312.625977 282.948822 285.722565 301.993256 307.915131 297.855774
#  325.200775 291.396942 304.516083 309.317352 293.091797 301.428345
#  302.767639 311.049255 297.061615 309.477264 300.939728 291.782104
#  308.008362 327.500732 328.11972  308.421143 287.199554 287.566437
#  275.90921  278.864594 316.900208 320.52359  304.784332 272.001587
#  287.149841 302.252106 297.714691 329.649384 323.501953 316.042664
#  286.034607 332.722656 305.734436 318.143982 310.505676 305.200531
#  265.198242 302.505585 282.15271  309.699554 277.931671 286.543427
#  282.182159 298.303925 308.016266 270.880737 301.451111 292.813751
#  318.332703 310.806061 281.035919 294.831482 298.790436 306.744629
#  284.456055 293.627441 300.336884 297.414642 299.256042 328.448608
#  300.135071 294.273102 298.058167 282.084229 293.546967 307.363922
#  303.718475 315.041656 289.721283 314.242157 328.017242 284.401184
#  291.130554 287.971771 325.365875 318.538239 315.561401 330.066376
#  292.41925  305.891479 288.478546 288.039948 299.074402 280.35788
#  301.774963 301.356598 276.096832 306.283722 304.529236 281.83136
#  298.618195 275.590637 280.830383 310.671722 299.465057 307.214478
#  279.669861 300.973755 294.634277 296.290802 307.266205 271.354004
#  276.232056 299.768097 310.752289 312.312561 279.659637 267.544647
#  302.793243 291.023376 312.972168 303.846405 284.292023 309.470428
#  322.696625 301.781586 322.12384  301.98645  292.961975 295.337372
#  314.923279 277.822723 322.53952  297.519928 301.884155 280.722076
#  324.039459 313.524811 313.611786 303.272003 300.755402 303.426453
#  300.171936 301.373657 324.484497 277.084076 309.243195 300.541962
#  298.26593  310.97052  289.361877 302.172577 294.262634 320.733398
#  317.632294 299.87146  282.469818 310.471893 311.053772 293.089142
#  287.918121 299.114807 287.943512 287.104248 299.089233 286.752594
#  281.803345 307.696716 312.712189 282.98114  289.036621 275.283142
#  317.372162 306.838165 294.85498  270.227997 277.169861 279.873444
#  312.929718 299.665649 296.684021 308.755463 308.633728 285.99704
#  280.595917 299.834076 298.902374 319.32251  348.411041 314.421692
#  300.592621 270.43045  305.506989 342.94873  293.829651 300.824554
#  309.074493 301.364685 341.491608 309.421326 298.622345 295.850677
#  284.834442 307.371887 301.956757 269.981415 277.66629  281.2612
#  296.902466 306.666626 305.142365 269.493469 270.067047 289.932587
#  286.544922 315.825592 315.991852 306.670258 312.472961 269.123413
#  328.733917 318.066895 307.10144  297.651703 315.984436 310.069824
#  290.763885 322.736084]
# 299.39055023650104
# 15.653223181960113

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math
media = 299.39055023650104
deviazione_standard = 15.653223181960113
x = np.linspace(media - 3*deviazione_standard, media + 3*deviazione_standard, 100)
plt.plot(x, stats.norm.pdf(x, media, deviazione_standard))
plt.show()

# %%
# !echo -e "Backbone\nBackbone" | gmx rms -s cady_3.pdb -f cady_D2_new.xtc -o rmsd2.xvg 
# !echo -e "System" | gmx trjconv -s cady_D2.tpr -f cady_D2_new.xtc -dump 4000 -o struct2ns.pdb
# Out:
#                :-) GROMACS - gmx rms, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx rms, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx rms -s cady_3.pdb -f cady_D2_new.xtc -o rmsd2.xvg
#
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary.
#
# Select group for least squares fit
# Group     0 (         System) has   390 elements
# Group     1 (        Protein) has   390 elements
# Group     2 (      Protein-H) has   188 elements
# Group     3 (        C-alpha) has    20 elements
# Group     4 (       Backbone) has    60 elements
# Group     5 (      MainChain) has    81 elements
# Group     6 (   MainChain+Cb) has   100 elements
# Group     7 (    MainChain+H) has   103 elements
# Group     8 (      SideChain) has   287 elements
# Group     9 (    SideChain-H) has   107 elements
# Select a group: Selected 4: 'Backbone'
# Select group for RMSD calculation
# Group     0 (         System) has   390 elements
# Group     1 (        Protein) has   390 elements
# Group     2 (      Protein-H) has   188 elements
# Group     3 (        C-alpha) has    20 elements
# Group     4 (       Backbone) has    60 elements
# Group     5 (      MainChain) has    81 elements
# Group     6 (   MainChain+Cb) has   100 elements
# Group     7 (    MainChain+H) has   103 elements
# Group     8 (      SideChain) has   287 elements
# Group     9 (    SideChain-H) has   107 elements
# Select a group: Selected 4: 'Backbone'
#
# WARNING: If there are molecules in the input trajectory file
#          that are broken across periodic boundaries, they
#          cannot be made whole (or treated as whole) without
#          you providing a run input file.
#
# Last frame       2000 time 4000.000
#
# GROMACS reminds you: "The scientist is not a person who gives the right answers, he's one who asks the right questions." (Claude Levi-Strauss)
#
#              :-) GROMACS - gmx trjconv, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx trjconv -s cady_D2.tpr -f cady_D2_new.xtc -dump 4000 -o struct2ns.pdb
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file cady_D2.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
# Reading file cady_D2.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
# Select group for output
# Group     0 (         System) has   390 elements
# Group     1 (        Protein) has   390 elements
# Group     2 (      Protein-H) has   188 elements
# Group     3 (        C-alpha) has    20 elements
# Group     4 (       Backbone) has    60 elements
# Group     5 (      MainChain) has    81 elements
# Group     6 (   MainChain+Cb) has   100 elements
# Group     7 (    MainChain+H) has   103 elements
# Group     8 (      SideChain) has   287 elements
# Group     9 (    SideChain-H) has   107 elements
# Select a group: Selected 0: 'System'
# Reading frame       0 time    0.000
# Precision of cady_D2_new.xtc is 0.001 (nm)
# Reading frame    2000 time 4000.000
# Dumping frame at t= 4000 ps
# Last frame       2000 time 4000.000
#
#
# GROMACS reminds you: "Perl: The only language that looks the same before and after RSA encryption." (Keith Bostic)

# %%
# !echo -e "Backbone\nBackbone" | gmx rms -s struct2ns.pdb -f cady_D2_new.xtc -o rmsd2_4ns.xvg -tu ns
# Out:
#                :-) GROMACS - gmx rms, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx rms, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx rms -s struct2ns.pdb -f cady_D2_new.xtc -o rmsd2_4ns.xvg -tu ns
#
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary.
#
# Select group for least squares fit
# Group     0 (         System) has   390 elements
# Group     1 (        Protein) has   390 elements
# Group     2 (      Protein-H) has   188 elements
# Group     3 (        C-alpha) has    20 elements
# Group     4 (       Backbone) has    60 elements
# Group     5 (      MainChain) has    81 elements
# Group     6 (   MainChain+Cb) has   100 elements
# Group     7 (    MainChain+H) has   103 elements
# Group     8 (      SideChain) has   287 elements
# Group     9 (    SideChain-H) has   107 elements
# Select a group: Selected 4: 'Backbone'
# Select group for RMSD calculation
# Group     0 (         System) has   390 elements
# Group     1 (        Protein) has   390 elements
# Group     2 (      Protein-H) has   188 elements
# Group     3 (        C-alpha) has    20 elements
# Group     4 (       Backbone) has    60 elements
# Group     5 (      MainChain) has    81 elements
# Group     6 (   MainChain+Cb) has   100 elements
# Group     7 (    MainChain+H) has   103 elements
# Group     8 (      SideChain) has   287 elements
# Group     9 (    SideChain-H) has   107 elements
# Select a group: Selected 4: 'Backbone'
#
# WARNING: If there are molecules in the input trajectory file
#          that are broken across periodic boundaries, they
#          cannot be made whole (or treated as whole) without
#          you providing a run input file.
#
# Last frame       2000 time    4.000
#
# GROMACS reminds you: "Scientists do not join hands every Sunday and sing "Yes gravity is real! I know gravity is real! I will have faith! I believe in my heart that what goes up, up, up must come down, down, down. Amen!" If they did, we would think they were pretty insecure about the concept." (Dan Barker)

# %%
time, rmsd = np.loadtxt('rmsd2.xvg',comments=['@','#'],unpack=True)
_, rmsd9 = np.loadtxt('rmsd2_4ns.xvg',comments=['@','#'],unpack=True)

# Prepare the figure
fig = plt.figure()
ax = fig.add_subplot(111,)

# Plot your data
ax.plot(time,rmsd,label='Ref: 0 ns',c='k')
ax.plot(time,rmsd9,label='Ref: 4 ns',c='r')

# Adjust the plot and personalize
ax.set_xlim(time[0],time[-1])
m = np.max(np.concatenate((rmsd,rmsd9)))*1.05
ax.set_ylim(0,m)
ax.set_xlabel(r"Time [ps]")
ax.set_ylabel(r"RMSD [nm]")
ax.legend(frameon=False)
plt.xlim(0,2000)

# This allows you to adjust the figure limits to make your figure nice
# (Recommended but not compulsory)
fig.tight_layout()

# %%
# !echo "Protein" | gmx rmsf -f cady_D1.xtc -s cady_D1.tpr -o rmsf1_eq.xvg -ox average1.pdb -b 1800 -e 1990
# !echo -e "Backbone\nBackbone" | gmx rms -s average1.pdb -f cady_D1.xtc -o rmsd_av1.xvg -tu ns
# Out:
#                :-) GROMACS - gmx rmsf, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx rmsf, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx rmsf -f cady_D1.xtc -s cady_D1.tpr -o rmsf1_eq.xvg -ox average1.pdb -b 1800 -e 1990
#
# Reading file cady_D1.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
# Reading file cady_D1.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
# Select group(s) for root mean square calculation
# Group     0 (         System) has  8304 elements
# Group     1 (        Protein) has   390 elements
# Group     2 (      Protein-H) has   188 elements
# Group     3 (        C-alpha) has    20 elements
# Group     4 (       Backbone) has    60 elements
# Group     5 (      MainChain) has    81 elements
# Group     6 (   MainChain+Cb) has   100 elements
# Group     7 (    MainChain+H) has   103 elements
# Group     8 (      SideChain) has   287 elements
# Group     9 (    SideChain-H) has   107 elements
# Group    10 (    Prot-Masses) has   390 elements
# Group    11 (    non-Protein) has  7914 elements
# Group    12 (          Water) has  7893 elements
# Group    13 (            SOL) has  7893 elements
# Group    14 (      non-Water) has   411 elements
# Group    15 (            Ion) has    21 elements
# Group    16 (             NA) has     8 elements
# Group    17 (             CL) has    13 elements
# Group    18 ( Water_and_ions) has  7914 elements
# Select a group: Selected 1: 'Protein'
# Reading frame      90 time 1980.000
#
# GROMACS reminds you: "Unfortunately, "simulation" has become increasingly misused to mean nothing more than "calculation"" (Bill Jorgensen)
#
#                :-) GROMACS - gmx rms, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx rms, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx rms -s average1.pdb -f cady_D1.xtc -o rmsd_av1.xvg -tu ns
#
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary.
#
# Select group for least squares fit
# Group     0 (         System) has   390 elements
# Group     1 (        Protein) has   390 elements
# Group     2 (      Protein-H) has   188 elements
# Group     3 (        C-alpha) has    20 elements
# Group     4 (       Backbone) has    60 elements
# Group     5 (      MainChain) has    81 elements
# Group     6 (   MainChain+Cb) has   100 elements
# Group     7 (    MainChain+H) has   103 elements
# Group     8 (      SideChain) has   287 elements
# Group     9 (    SideChain-H) has   107 elements
# Select a group: Selected 4: 'Backbone'
# Select group for RMSD calculation
# Group     0 (         System) has   390 elements
# Group     1 (        Protein) has   390 elements
# Group     2 (      Protein-H) has   188 elements
# Group     3 (        C-alpha) has    20 elements
# Group     4 (       Backbone) has    60 elements
# Group     5 (      MainChain) has    81 elements
# Group     6 (   MainChain+Cb) has   100 elements
# Group     7 (    MainChain+H) has   103 elements
# Group     8 (      SideChain) has   287 elements
# Group     9 (    SideChain-H) has   107 elements
# Select a group: Selected 4: 'Backbone'
#
# WARNING: If there are molecules in the input trajectory file
#          that are broken across periodic boundaries, they
#          cannot be made whole (or treated as whole) without
#          you providing a run input file.
#
# Reading frame       0 time    0.000
# WARNING: topology has 390 atoms, whereas trajectory has 8304
# Last frame       1000 time    2.000
#
# GROMACS reminds you: "As we all know, blinking lights means science." (Joss Whedon)

# %%
time, rmsd = np.loadtxt('rmsd_av1.xvg',comments=['@','#'],unpack=True)
_, rmsd50 = np.loadtxt('rmsd1_2ns.xvg',comments=['@','#'],unpack=True)
_, rmsd0 = np.loadtxt('rmsd1.xvg',comments=['@','#'],unpack=True)
fig = plt.figure()
ax = fig.add_subplot(111,)
ax.plot(time,rmsd0,c='k',label='Ref: 0 ns')
ax.plot(time,rmsd50,c='r',label='Ref: 1.990 ns')
ax.plot(time,rmsd,c='b',label='Ref: [1.8-1.990]ns')
ax.set_xlim(time[0],time[-1])
m = np.max(np.concatenate((rmsd,rmsd50,rmsd0)))*1.05
ax.set_ylim(0,m)
ax.set_xlabel(r"Time [ns]")
ax.set_ylabel(r"RMSD [nm]")
ax.legend()
fig.tight_layout()

# %%
# %%bash
# echo "C-alpha" | gmx rmsf -f cady_D2.xtc -s cady_D2.tpr -o rmsf2.xvg -res
# Out:
# Selected 3: 'C-alpha'
#                :-) GROMACS - gmx rmsf, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx rmsf, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx rmsf -f cady_D2.xtc -s cady_D2.tpr -o rmsf2.xvg -res
#
# Reading file cady_D2.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
# Reading file cady_D2.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
# Select group(s) for root mean square calculation
# Group     0 (         System) has  8304 elements
# Group     1 (        Protein) has   390 elements
# Group     2 (      Protein-H) has   188 elements
# Group     3 (        C-alpha) has    20 elements
# Group     4 (       Backbone) has    60 elements
# Group     5 (      MainChain) has    81 elements
# Group     6 (   MainChain+Cb) has   100 elements
# Group     7 (    MainChain+H) has   103 elements
# Group     8 (      SideChain) has   287 elements
# Group     9 (    SideChain-H) has   107 elements
# Group    10 (    Prot-Masses) has   390 elements
# Group    11 (    non-Protein) has  7914 elements
# Group    12 (          Water) has  7893 elements
# Group    13 (            SOL) has  7893 elements
# Group    14 (      non-Water) has   411 elements
# Group    15 (            Ion) has    21 elements
# Group    16 (             NA) has     8 elements
# Group    17 (             CL) has    13 elements
# Group    18 ( Water_and_ions) has  7914 elements
# Last frame       1000 time 2000.000
#
# GROMACS reminds you: "Yeah, uh uh, Neil's Head !" (Neil)

# %%
# Load your data
res, rmsf = np.loadtxt('rmsf2.xvg',comments=['@','#'],unpack=True)

# Prepare the figure
fig = plt.figure()
ax = fig.add_subplot(111,)

# Plot your data
ax.plot(res,rmsf,c='k')

# Adjust the plot and personalize
ax.set_xlim(res[0],res[-1])
m = np.max(rmsf)*1.05
ax.set_ylim(0,m)
ax.set_xlabel(r"Residue number")
ax.set_ylabel(r"RMSF [nm]")

# This allows you to adjust the figure limits to make your figure nice
# (Recommended but not compulsory)
fig.tight_layout()

# %%
# %%bash
# echo "r 1
# r 20
# q" | gmx make_ndx -f cady_3.pdb -o index2.ndx
# gmx distance -f cady_D2.xtc -s cady_D2.tpr -select 'com of group "r_1" plus com of group "r_20"' \
# -n index2.ndx -oav distance2.xvg
# Out:
# Going to read 0 old index file(s)
# Analysing residue names:
# There are:    20    Protein residues
# Analysing Protein...
#
#   0 System              :   390 atoms
#   1 Protein             :   390 atoms
#   2 Protein-H           :   188 atoms
#   3 C-alpha             :    20 atoms
#   4 Backbone            :    60 atoms
#   5 MainChain           :    81 atoms
#   6 MainChain+Cb        :   100 atoms
#   7 MainChain+H         :   103 atoms
#   8 SideChain           :   287 atoms
#   9 SideChain-H         :   107 atoms
#
#  nr : group      '!': not  'name' nr name   'splitch' nr    Enter: list groups
#  'a': atom       '&': and  'del' nr         'splitres' nr   'l': list residues
#  't': atom type  '|': or   'keep' nr        'splitat' nr    'h': help
#  'r': residue              'res' nr         'chain' char
#  "name": group             'case': case sensitive           'q': save and quit
#  'ri': residue index
#
# >
#
#  10 r_1                 :     9 atoms
#
# >
#
#  11 r_20                :    11 atoms
#
# >
# com of group "r_1" plus com of group "r_20":
#   Number of samples:  1001
#   Average distance:   1.81881  nm
#   Standard deviation: 0.47827  nm
#              :-) GROMACS - gmx make_ndx, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx make_ndx, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx make_ndx -f cady_3.pdb -o index2.ndx
#
#
# Reading structure file
#
# GROMACS reminds you: "If mathematical analysis should ever hold a prominent place in chemistry - an aberration which is happily almost impossible - it would occasion a rapid and widespread degeneration of that science." (Aguste Comte, 1830)
#
#              :-) GROMACS - gmx distance, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx distance, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx distance -f cady_D2.xtc -s cady_D2.tpr -select 'com of group "r_1" plus com of group "r_20"' -n index2.ndx -oav distance2.xvg
#
# Reading file cady_D2.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
# Reading file cady_D2.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
# Last frame       1000 time 2000.000
# Analyzed 1001 frames, last time 2000.000
#
# GROMACS reminds you: "Same sex marriage is not a gay privilege, it's equal rights. Privilege would be something like gay people not paying taxes. Like churches don't." (Ricky Gervais)

# %%
time, d = np.loadtxt('distance2.xvg',comments=['@','#'],unpack=True)
time = time/1000 # gmx distance gives output only in ps
fig = plt.figure(figsize=(6,3))
# in time
ax1 = fig.add_subplot(121,)
ax1.plot(time,d,c='k')
ax1.set_xlim(time[0],time[-1])
M = np.max(d)*1.05
m = np.min(d)*0.95
ax1.set_ylim(m,M)
ax1.set_xlabel(r"Time [ps]")
ax1.set_ylabel(r"$d_{ee}$ [nm]")

# histogram
ax2 = fig.add_subplot(122,)
ax2.hist(d,color='k',density=True,alpha=0.5)
ax2.set_ylabel(r"Probability density")
ax2.set_xlabel(r"$d_{ee}$ [nm]")
fig.tight_layout()

# %%
# %%bash
# echo -e "Protein \n Water \n " | gmx hbond -f cady_D2.xtc -s cady_D2.tpr -num hb_water_protein2.xvg
# echo -e "Protein \n Protein \n " | gmx hbond -f cady_D2.xtc -s cady_D2.tpr -num hb_protein_protein2.xvg
# Out:
# Specify 2 groups to analyze:
# Selected 1: 'Protein'
# Selected 12: 'Water'
# Checking for overlap in atoms between Protein and Water
# Calculating hydrogen bonds between Protein (390 atoms) and Water (7893 atoms)
# Found 2671 donors and 2692 acceptors
#
# Will do grid-search on 11x11x8 grid, rcut=0.34999999
# Frame loop parallelized with OpenMP using 2 threads.
# Average number of hbonds per timeframe 70.591 out of 3.59517e+06 possible
# Specify 2 groups to analyze:
# Selected 1: 'Protein'
# Selected 1: 'Protein'
# Found 40 donors and 61 acceptors
#
# Will do grid-search on 11x11x8 grid, rcut=0.34999999
# Frame loop parallelized with OpenMP using 2 threads.
# Average number of hbonds per timeframe 1.530 out of 1220 possible
#               :-) GROMACS - gmx hbond, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx hbond, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx hbond -f cady_D2.xtc -s cady_D2.tpr -num hb_water_protein2.xvg
#
# Reading file cady_D2.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
# Group     0 (         System) has  8304 elements
# Group     1 (        Protein) has   390 elements
# Group     2 (      Protein-H) has   188 elements
# Group     3 (        C-alpha) has    20 elements
# Group     4 (       Backbone) has    60 elements
# Group     5 (      MainChain) has    81 elements
# Group     6 (   MainChain+Cb) has   100 elements
# Group     7 (    MainChain+H) has   103 elements
# Group     8 (      SideChain) has   287 elements
# Group     9 (    SideChain-H) has   107 elements
# Group    10 (    Prot-Masses) has   390 elements
# Group    11 (    non-Protein) has  7914 elements
# Group    12 (          Water) has  7893 elements
# Group    13 (            SOL) has  7893 elements
# Group    14 (      non-Water) has   411 elements
# Group    15 (            Ion) has    21 elements
# Group    16 (             NA) has     8 elements
# Group    17 (             CL) has    13 elements
# Group    18 ( Water_and_ions) has  7914 elements
# Last frame       1000 time 2000.000
#
# GROMACS reminds you: "Should we force science down the throats of those that have no taste for it? Is it our duty to drag them kicking and screaming into the twenty-first century? I am afraid that it is." (George Porter)
#
#               :-) GROMACS - gmx hbond, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx hbond, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx hbond -f cady_D2.xtc -s cady_D2.tpr -num hb_protein_protein2.xvg
#
# Reading file cady_D2.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
# Group     0 (         System) has  8304 elements
# Group     1 (        Protein) has   390 elements
# Group     2 (      Protein-H) has   188 elements
# Group     3 (        C-alpha) has    20 elements
# Group     4 (       Backbone) has    60 elements
# Group     5 (      MainChain) has    81 elements
# Group     6 (   MainChain+Cb) has   100 elements
# Group     7 (    MainChain+H) has   103 elements
# Group     8 (      SideChain) has   287 elements
# Group     9 (    SideChain-H) has   107 elements
# Group    10 (    Prot-Masses) has   390 elements
# Group    11 (    non-Protein) has  7914 elements
# Group    12 (          Water) has  7893 elements
# Group    13 (            SOL) has  7893 elements
# Group    14 (      non-Water) has   411 elements
# Group    15 (            Ion) has    21 elements
# Group    16 (             NA) has     8 elements
# Group    17 (             CL) has    13 elements
# Group    18 ( Water_and_ions) has  7914 elements
# Select a group: Select a group: Calculating hydrogen bonds in Protein (390 atoms)
# Last frame       1000 time 2000.000
#
# GROMACS reminds you: "Everybody Wants to Be Naked and Famous" (Tricky)

# %%
time, hb_protein_water, _ = np.loadtxt('hb_water_protein2.xvg',comments=['@','#'],unpack=True)
_, hb_protein_protein, _ = np.loadtxt('hb_protein_protein2.xvg',comments=['@','#'],unpack=True)
time /= 1000

fig = plt.figure(figsize=(11,4))
ax1 = fig.add_subplot(131,)
ax2 = fig.add_subplot(132,sharex = ax1)
ax3 = fig.add_subplot(133,)
ax1.plot(time,hb_protein_water,c='b')
ax2.plot(time,hb_protein_protein,c='r')
ax3.hist(hb_protein_water,color='b',density=True)
ax3.hist(hb_protein_protein,color='r',density=True)
ax1.set_xlim(time[0],time[-1])
ax1.set_xlabel(r"Time [ns]")
ax2.set_xlabel(r"Time [ns]")
ax3.set_xlabel(r"# HB")
ax1.set_ylabel(r"# HB")
ax2.set_ylabel(r"# HB")
ax3.set_ylabel("Probability density")
ax1.set_title('Water-Protein')
ax2.set_title('Protein-Protein')
m = np.min(np.concatenate((hb_protein_water,hb_protein_protein)))*0.95
M = np.max(np.concatenate((hb_protein_water,hb_protein_protein)))*1.05
ax3.set_xlim(m,M)
fig.tight_layout()

# %%
! echo -e "0 \n" | gmx trjconv -s posres1.tpr -f 01-posres/posres.xtc -pbc mol -o 01-posres/noPBC.xtc -ur compact

# %%
# !gmx trjconv -f cady_D1.xtc -o cady_D1_camp.xtc -dt 200
# Out:
#              :-) GROMACS - gmx trjconv, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx trjconv -f cady_D1.xtc -o cady_D1_camp.xtc -dt 200
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write xtc: Compressed trajectory (portable xdr format): xtc
# Reading frame       0 time    0.000
# Precision of cady_D1.xtc is 0.001 (nm)
# Using output precision of 0.001 (nm)
# Last frame       1000 time 2000.000
#
#
# GROMACS reminds you: "The Internet?  We are not interested in it." (Bill Gates, 1993)

# %%
# !echo "Protein" | gmx do_dssp -s posre1.tpr -f cady_D1.xtc -tu ns -dt 0.1
# Out:
#              :-) GROMACS - gmx do_dssp, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx do_dssp, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx do_dssp -s posre1.tpr -f cady_D1.xtc -tu ns -dt 0.1
#
# Reading file posre1.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
# Reading file posre1.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
# Not all residues were recognized (20 from 2672), the result may be inaccurate!
# Group     0 (         System) has  8304 elements
# Group     1 (        Protein) has   390 elements
# Group     2 (      Protein-H) has   188 elements
# Group     3 (        C-alpha) has    20 elements
# Group     4 (       Backbone) has    60 elements
# Group     5 (      MainChain) has    81 elements
# Group     6 (   MainChain+Cb) has   100 elements
# Group     7 (    MainChain+H) has   103 elements
# Group     8 (      SideChain) has   287 elements
# Group     9 (    SideChain-H) has   107 elements
# Group    10 (    Prot-Masses) has   390 elements
# Group    11 (    non-Protein) has  7914 elements
# Group    12 (          Water) has  7893 elements
# Group    13 (            SOL) has  7893 elements
# Group    14 (      non-Water) has   411 elements
# Group    15 (            Ion) has    21 elements
# Group    16 (             NA) has     8 elements
# Group    17 (             CL) has    13 elements
# Group    18 ( Water_and_ions) has  7914 elements
# Select a group: Selected 1: 'Protein'
# There are 20 residues in your selected group
# dssp cmd='/usr/local/bin/dssp -i ddn4EBlY 2>/dev/null'
# Reading frame       0 time    0.000
# Back Off! I just backed up ddn4EBlY to ./#ddn4EBlY.1#
# /bin/bash: line 1: 35928 Done                    echo "Protein"
#      35929 Segmentation fault      (core dumped) | gmx do_dssp -s posre1.tpr -f cady_D1.xtc -tu ns -dt 0.1

# %%
# %%bash
# echo "; Command line options of xpm2ps override the parameters in this file
# xbox                     = 4.0          ; x-size of a matrix element
# ybox                     = 8.0          ; x-size of a matrix element
# y-major                  = 5            ; y major ticks
# y-minor                  = 0
# " > options.m2p
# gmx xpm2ps -f ss.xpm -di options.m2p -o ss.eps
# convert_image(f="ss.eps",o="ss.png")
# Out:
#               :-) GROMACS - gmx xpm2ps, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx xpm2ps, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx xpm2ps -f ss.xpm -di options.m2p -o ss.eps
#
#
# -------------------------------------------------------
# Program:     gmx xpm2ps, version 2020.1-Ubuntu-2020.1-1
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 275)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -f
#     File 'ss.xpm' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
# bash: line 8: syntax error near unexpected token `f="ss.eps",o="ss.png"'
# bash: line 8: `convert_image(f="ss.eps",o="ss.png")'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-47-57c1f0dedb4f> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'echo "; Command line options of xpm2ps override the parameters in this file\nxbox                     = 4.0          ; x-size of a matrix element\nybox                     = 8.0          ; x-size of a matrix element\ny-major                  = 5            ; y major ticks\ny-minor                  = 0\n" > options.m2p\ngmx xpm2ps -f ss.xpm -di options.m2p -o ss.eps\nconvert_image(f="ss.eps",o="ss.png")\n')
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
#    2358                 args = (magic_arg_s, cell)
# -> 2359                 result = fn(*args, **kwargs)
#    2360             return result
#    2361
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'echo "; Command line options of xpm2ps override the parameters in this file\nxbox                     = 4.0          ; x-size of a matrix element\nybox                     = 8.0          ; x-size of a matrix element\ny-major                  = 5            ; y major ticks\ny-minor                  = 0\n" > options.m2p\ngmx xpm2ps -f ss.xpm -di options.m2p -o ss.eps\nconvert_image(f="ss.eps",o="ss.png")\n'' returned non-zero exit status 2.
