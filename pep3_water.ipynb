# %% [markdown]
# <a href="https://colab.research.google.com/github/piliroberta/Multiscala_progetto/blob/main/pep3_water.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Increase the output length 
from notebook.services.config import ConfigManager
cm = ConfigManager().update('notebook', {'limit_output': 10000000})

# %%
#@title Installing GROMACS and related packages
# !apt install gromacs &> /dev/null
# !apt install dssp &> /dev/null
# !ln -s /usr/bin/dssp /usr/local/bin/dssp
# !apt install ghostscript &> /dev/null

# %%
#@title Installing NGLview
# !pip install nglview  &> /dev/null
# !pip install simpletraj  &> /dev/null
# !pip install mdanalysis &> /dev/null
from google.colab import output
output.enable_custom_widget_manager()

# %%
# !mkdir pep

# %%
# !mv pep_3.pdb template.mdp pep/

# %%
# !gmx pdb2gmx -f pep/pep_3.pdb -p pep/pepw.top -o pep/pepw.gro -ff amber99sb-ildn -ignh -heavyh -water tip3p
# Out:
#              :-) GROMACS - gmx pdb2gmx, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx pdb2gmx, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx pdb2gmx -f pep/pep_3.pdb -p pep/pepw.top -o pep/pepw.gro -ff amber99sb-ildn -ignh -heavyh -water tip3p
#
#
# Using the Amber99sb-ildn force field in directory amber99sb-ildn.ff
#
# going to rename amber99sb-ildn.ff/aminoacids.r2b
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/aminoacids.r2b
# going to rename amber99sb-ildn.ff/dna.r2b
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/dna.r2b
# going to rename amber99sb-ildn.ff/rna.r2b
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/rna.r2b
# Reading pep/pep_3.pdb...
# Read 'GROningen Mixture of Alchemy and Childrens' Stories in water t= 30000.00000', 204 atoms
# Analyzing pdb file
# Splitting chemical chains based on TER records or chain id changing.
# There are 1 chains and 0 blocks of water and 21 residues with 204 atoms
#
#   chain  #res #atoms
#   1 ' '    21    204
#
# All occupancies are one
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/atomtypes.atp
# Reading residue database... (Amber99sb-ildn)
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/aminoacids.rtp
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/dna.rtp
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/rna.rtp
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/aminoacids.hdb
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/dna.hdb
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/rna.hdb
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/aminoacids.n.tdb
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/aminoacids.c.tdb
# Processing chain 1 (204 atoms, 21 residues)
# Identified residue LYS1 as a starting terminus.
# Identified residue VAL21 as a ending terminus.
# 8 out of 8 lines of specbond.dat converted successfully
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/aminoacids.arn
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/dna.arn
# Opening force field file /usr/share/gromacs/top/amber99sb-ildn.ff/rna.arn
# Checking for duplicate atoms....
# Generating any missing hydrogen atoms and/or adding termini.
# Now there are 21 residues with 402 atoms
# Making bonds...
# Number of bonds was 413, now 412
# Generating angles, dihedrals and pairs...
# Before cleaning: 1085 pairs
# Before cleaning: 1115 dihedrals
# Keeping all generated dihedrals
# Making cmap torsions...
# There are 1115 dihedrals,   85 impropers,  745 angles
#           1070 pairs,      412 bonds and     0 virtual sites
# Total mass 2851.294 a.m.u.
# Total charge 3.000 e
# Writing topology
#
# Writing coordinate file...
# 		--------- PLEASE NOTE ------------
# You have successfully generated a topology from: pep/pep_3.pdb.
# The Amber99sb-ildn force field and the tip3p water model are used.
# 		--------- ETON ESAELP ------------
#
# GROMACS reminds you: "Cut It Deep and Cut It Wide" (The Walkabouts)

# %%
# !gmx editconf -f pep/pepw.gro -o pep/box.gro -c -d 0.6 -bt dodecahedron
# Out:
#              :-) GROMACS - gmx editconf, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx editconf, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx editconf -f pep/pepw.gro -o pep/box.gro -c -d 0.6 -bt dodecahedron
#
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 402 atoms
# Volume: 276.555 nm^3, corresponds to roughly 124400 electrons
# No velocities found
#     system size :  2.565  2.638  2.347 (nm)
#     diameter    :  3.608               (nm)
#     center      :  3.282  3.319  3.174 (nm)
#     box vectors :  6.564  6.637  6.347 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  : 276.56               (nm^3)
#     shift       :  0.324  0.287 -1.474 (nm)
# new center      :  3.606  3.606  1.700 (nm)
# new box vectors :  4.808  4.808  4.808 (nm)
# new box angles  :  60.00  60.00  90.00 (degrees)
# new box volume  :  78.58               (nm^3)
#
# GROMACS reminds you: "You Dirty Switch, You're On Again" (The Breeders)

# %%
# !gmx solvate -cp pep/box.gro -o pep/solvated.gro -p pep/pepw.top
# Out:
#              :-) GROMACS - gmx solvate, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx solvate, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx solvate -cp pep/box.gro -o pep/solvated.gro -p pep/pepw.top
#
# Reading solute configuration
# Reading solvent configuration
#
# Initialising inter-atomic distances...
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary.
#
# NOTE: From version 5.0 gmx solvate uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#
# Generating solvent configuration
# Will generate new solvent configuration of 3x3x2 boxes
# Solvent box contains 9678 atoms in 3226 residues
# Removed 1878 solvent atoms due to solvent-solvent overlap
# Removed 375 solvent atoms due to solute-solvent overlap
# Sorting configuration
# Found 1 molecule type:
#     SOL (   3 atoms):  2475 residues
# Generated solvent containing 7425 atoms in 2475 residues
# Writing generated configuration to pep/solvated.gro
#
# Output configuration contains 7827 atoms in 2496 residues
# Volume                 :     78.5754 (nm^3)
# Density                :     1006.61 (g/l)
# Number of solvent molecules:   2475
#
# Processing topology
# Adding line for 2475 solvent molecules with resname (SOL) to topology file (pep/pepw.top)
#
# Back Off! I just backed up pep/pepw.top to pep/#pepw.top.1#
#
# GROMACS reminds you: "Stay Cool, This is a Robbery" (Pulp Fiction)

# %%
# !tail -n 20 pep/solvated.gro
# Out:
#  2490SOL    HW2 7809   4.230   4.471   2.466
#  2491SOL     OW 7810   4.583   4.680   2.723
#  2491SOL    HW1 7811   4.637   4.611   2.771
#  2491SOL    HW2 7812   4.551   4.749   2.789
#  2492SOL     OW 7813   3.803   4.964   2.515
#  2492SOL    HW1 7814   3.802   4.917   2.603
#  2492SOL    HW2 7815   3.885   4.936   2.464
#  2493SOL     OW 7816   4.152   4.148   2.382
#  2493SOL    HW1 7817   4.182   4.076   2.320
#  2493SOL    HW2 7818   4.113   4.108   2.465
#  2494SOL     OW 7819   4.041   4.271   3.142
#  2494SOL    HW1 7820   4.079   4.212   3.214
#  2494SOL    HW2 7821   4.081   4.245   3.054
#  2495SOL     OW 7822   4.725   3.758   3.016
#  2495SOL    HW1 7823   4.662   3.686   2.985
#  2495SOL    HW2 7824   4.818   3.722   3.016
#  2496SOL     OW 7825   3.763   4.801   2.162
#  2496SOL    HW1 7826   3.862   4.790   2.153
#  2496SOL    HW2 7827   3.723   4.715   2.194
#    4.80766   4.80766   3.39953   0.00000   0.00000   0.00000   0.00000   2.40383   2.40383

# %%
# !tail pep/pepw.top -n 5
# Out:
# [ molecules ]
# ; Compound        #mols
# Protein             1
# SOL              2475

# %%
# !touch pep/dummy.mdp

# %%
# !gmx grompp -f pep/dummy.mdp -c pep/solvated.gro -p pep/pepw.top -o pep/ions.tpr
# Out:
#               :-) GROMACS - gmx grompp, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx grompp -f pep/dummy.mdp -c pep/solvated.gro -p pep/pepw.top -o pep/ions.tpr
#
#
# NOTE 1 [file pep/dummy.mdp]:
#   For a correct single-point energy evaluation with nsteps = 0, use
#   continuation = yes to avoid constraining the input coordinates.
#
# Setting the LD random seed to 1654246100
# Generated 2145 of the 2145 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
# Generated 2145 of the 2145 1-4 parameter combinations
# Excluding 3 bonded neighbours molecule type 'Protein'
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# NOTE 2 [file pepw.top, line 3922]:
#   System has non-zero total charge: 3.000000
#   Total charge should normally be an integer. See
#   http://www.gromacs.org/Documentation/Floating_Point_Arithmetic
#   for discussion on how close it should be to an integer.
#
#
#
# Analysing residue names:
# There are:    21    Protein residues
# There are:  2475      Water residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group rest is 16053.00
#
# NOTE 3 [file pep/dummy.mdp]:
#   NVE simulation with an initial temperature of zero: will use a Verlet
#   buffer of 10%. Check your energy drift!
#
#
# NOTE 4 [file pep/dummy.mdp]:
#   You are using a plain Coulomb cut-off, which might produce artifacts.
#   You might want to consider using PME electrostatics.
#
#
# This run will generate roughly 1 Mb of data
#
# There were 4 notes
#
# GROMACS reminds you: "I don't believe in astrology; I'm a Sagittarian and we're skeptical." (Arthur C. Clarke)

# %%
# !echo "SOL" | gmx genion -s pep/ions.tpr -p pep/pepw.top -o pep/box_ions.gro -conc 0.15 -neutral
# Out:
#               :-) GROMACS - gmx genion, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx genion, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx genion -s pep/ions.tpr -p pep/pepw.top -o pep/box_ions.gro -conc 0.15 -neutral
#
# Reading file pep/ions.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
# Reading file pep/ions.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
# Will try to add 7 NA ions and 10 CL ions.
# Select a continuous group of solvent molecules
# Group     0 (         System) has  7827 elements
# Group     1 (        Protein) has   402 elements
# Group     2 (      Protein-H) has   204 elements
# Group     3 (        C-alpha) has    21 elements
# Group     4 (       Backbone) has    63 elements
# Group     5 (      MainChain) has    85 elements
# Group     6 (   MainChain+Cb) has   106 elements
# Group     7 (    MainChain+H) has   107 elements
# Group     8 (      SideChain) has   295 elements
# Group     9 (    SideChain-H) has   119 elements
# Group    10 (    Prot-Masses) has   402 elements
# Group    11 (    non-Protein) has  7425 elements
# Group    12 (          Water) has  7425 elements
# Group    13 (            SOL) has  7425 elements
# Group    14 (      non-Water) has   402 elements
# Select a group: Selected 13: 'SOL'
# Number of (3-atomic) solvent molecules: 2475
#
# Processing topology
# Replacing 17 solute molecules in topology file (pep/pepw.top)  by 7 NA and 10 CL ions.
#
# Back Off! I just backed up pep/pepw.top to pep/#pepw.top.2#
# Using random seed 1835476241.
# Replacing solvent molecule 124 (atom 774) with NA
# Replacing solvent molecule 814 (atom 2844) with NA
# Replacing solvent molecule 706 (atom 2520) with NA
# Replacing solvent molecule 83 (atom 651) with NA
# Replacing solvent molecule 679 (atom 2439) with NA
# Replacing solvent molecule 182 (atom 948) with NA
# Replacing solvent molecule 871 (atom 3015) with NA
# Replacing solvent molecule 2079 (atom 6639) with CL
# Replacing solvent molecule 1886 (atom 6060) with CL
# Replacing solvent molecule 342 (atom 1428) with CL
# Replacing solvent molecule 1252 (atom 4158) with CL
# Replacing solvent molecule 1772 (atom 5718) with CL
# Replacing solvent molecule 1727 (atom 5583) with CL
# Replacing solvent molecule 1814 (atom 5844) with CL
# Replacing solvent molecule 2037 (atom 6513) with CL
# Replacing solvent molecule 1854 (atom 5964) with CL
# Replacing solvent molecule 73 (atom 621) with CL
#
#
# GROMACS reminds you: "The sign of wisdom is to have more questions than answers." (Abhijit Naskar)

# %%
# !gmx grompp -f pep/template.mdp -p pep/pepw.top -c pep/box_ions.gro -o pep/pepw_min.tpr -maxwarn 1
# Out:
#               :-) GROMACS - gmx grompp, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx grompp -f pep/template.mdp -p pep/pepw.top -c pep/box_ions.gro -o pep/pepw_min.tpr -maxwarn 1
#
# Ignoring obsolete mdp entry 'ns-type'
#
# WARNING 1 [file pep/template.mdp]:
#   Removing the rotation around the center of mass in a periodic system,
#   this can lead to artifacts. Only use this on a single (cluster of)
#   molecules. This cluster should not cross periodic boundaries.
#
# Setting the LD random seed to -1654844020
# Generated 2145 of the 2145 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
# Generated 2145 of the 2145 1-4 parameter combinations
# Excluding 3 bonded neighbours molecule type 'Protein'
# turning all bonds into constraints...
# Excluding 2 bonded neighbours molecule type 'SOL'
# turning all bonds into constraints...
# Excluding 1 bonded neighbours molecule type 'NA'
# turning all bonds into constraints...
# Excluding 1 bonded neighbours molecule type 'CL'
# turning all bonds into constraints...
#
# NOTE 1 [file unknown]:
#   You are using constraints on all bonds, whereas the forcefield has been
#   parametrized only with constraints involving hydrogen atoms. We suggest
#   using constraints = h-bonds instead, this will also improve performance.
#
# Analysing residue names:
# There are:    21    Protein residues
# There are:  2458      Water residues
# There are:    17        Ion residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Number of degrees of freedom in T-Coupling group rest is 15587.00
#
# NOTE 2 [file pep/template.mdp]:
#   You are using a plain Coulomb cut-off, which might produce artifacts.
#   You might want to consider using PME electrostatics.
#
#
# This run will generate roughly 1 Mb of data
#
# There were 2 notes
#
# There was 1 warning
#
# GROMACS reminds you: "Raw data is like raw sewage, it requires some processing before it can be spread around. The opposite is true of theories." (Jim Carr)

# %%
! gmx mdrun -s pep/pepw_min.tpr -deffnm pep/pepw_min -v -ntmpi 2
# Out:
#               :-) GROMACS - gmx mdrun, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx mdrun, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx mdrun -s pep/pepw_min.tpr -deffnm pep/pepw_min -v -ntmpi 2
#
# Compiled SIMD: SSE2, but for this host/run AVX2_256 might be better (see log).
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file pep/pepw_min.tpr, VERSION 2020.1-Ubuntu-2020.1-1 (single precision)
#
# comm-mode angular will give incorrect results when the comm group partially crosses a periodic boundary
# Using 2 MPI threads
# Using 1 OpenMP thread per tMPI thread
#
#
# Steepest Descents:
#    Tolerance (Fmax)   =  1.00000e+01
#    Number of steps    =           -1
# Step=    0, Dmax= 1.0e-02 nm, Epot= -7.54032e+03 Fmax= 2.13867e+05, atom= 7788
# Step=    1, Dmax= 1.0e-02 nm, Epot= -2.75490e+04 Fmax= 8.19754e+04, atom= 7788
# Step=    2, Dmax= 1.2e-02 nm, Epot= -4.63235e+04 Fmax= 3.31930e+04, atom= 5536
# Step=    3, Dmax= 1.4e-02 nm, Epot= -6.10487e+04 Fmax= 1.33768e+04, atom= 5536
# Step=    4, Dmax= 1.7e-02 nm, Epot= -7.32875e+04 Fmax= 6.51237e+03, atom= 3643
# Step=    5, Dmax= 2.1e-02 nm, Epot= -8.26294e+04 Fmax= 2.80801e+03, atom= 6853
# Step=    6, Dmax= 2.5e-02 nm, Epot= -9.28616e+04 Fmax= 1.90748e+03, atom= 928
# Step=    7, Dmax= 3.0e-02 nm, Epot= -1.00764e+05 Fmax= 5.50889e+03, atom= 1555
# Step=    8, Dmax= 3.6e-02 nm, Epot= -1.03129e+05 Fmax= 1.61740e+03, atom= 138
#
# Step 9, time 0.018 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.007427, max 0.035666 (between atoms 135 and 138)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#     138    139   31.0    0.1356   0.1396      0.1352
# Step=    9, Dmax= 4.3e-02 nm, Epot= -1.06470e+05 Fmax= 6.60052e+03, atom= 1555
#
# Step 10, time 0.02 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.021323, max 0.096346 (between atoms 138 and 152)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#      88     89   33.5    0.1014   0.1047      0.1010
#     138    152   33.1    0.1509   0.1600      0.1459
#     135    138   35.3    0.1548   0.1594      0.1495
#     165    166   35.4    0.1017   0.1040      0.1010
#     133    134   36.0    0.1105   0.1174      0.1090
#     131    132   35.0    0.1024   0.1082      0.1010
#     129    131   34.3    0.1346   0.1448      0.1335
#
# Step 10, time 0.02 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.006025, max 0.026087 (between atoms 386 and 388)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#     400    401   40.8    0.1258   0.1282      0.1250
#     400    402   40.3    0.1258   0.1281      0.1250
# Step=   11, Dmax= 2.6e-02 nm, Epot= -1.10090e+05 Fmax= 2.41447e+03, atom= 138
# Step=   12, Dmax= 3.1e-02 nm, Epot= -1.10807e+05 Fmax= 7.29424e+03, atom= 176
#
# Step 13, time 0.026 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.008293, max 0.035699 (between atoms 167 and 168)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#     165    166   32.4    0.1030   0.1044      0.1010
# Step=   13, Dmax= 3.7e-02 nm, Epot= -1.12258e+05 Fmax= 5.90163e+03, atom= 167
#
# Step 14, time 0.028 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.012483, max 0.069345 (between atoms 165 and 166)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#      88     89   31.7    0.1039   0.1035      0.1010
#     165    166   36.1    0.1044   0.1080      0.1010
#     163    164   32.1    0.1106   0.1129      0.1080
# Step=   15, Dmax= 2.2e-02 nm, Epot= -1.13368e+05 Fmax= 2.41927e+03, atom= 167
# Step=   16, Dmax= 2.7e-02 nm, Epot= -1.13953e+05 Fmax= 6.90233e+03, atom= 167
# Step=   17, Dmax= 3.2e-02 nm, Epot= -1.14922e+05 Fmax= 4.46211e+03, atom= 176
# Step=   19, Dmax= 1.9e-02 nm, Epot= -1.15584e+05 Fmax= 2.79770e+03, atom= 167
# Step=   20, Dmax= 2.3e-02 nm, Epot= -1.16007e+05 Fmax= 5.33291e+03, atom= 176
# Step=   21, Dmax= 2.8e-02 nm, Epot= -1.16588e+05 Fmax= 4.86549e+03, atom= 167
# Step=   22, Dmax= 3.3e-02 nm, Epot= -1.16698e+05 Fmax= 6.53712e+03, atom= 176
#
# Step 23, time 0.046 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.009582, max 0.042002 (between atoms 167 and 168)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#     165    166   34.0    0.1039   0.1044      0.1010
# Step=   23, Dmax= 4.0e-02 nm, Epot= -1.16859e+05 Fmax= 7.46320e+03, atom= 167
#
# Step 24, time 0.048 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.015534, max 0.093108 (between atoms 165 and 166)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#      88     89   35.1    0.1047   0.1046      0.1010
#     165    166   39.5    0.1044   0.1104      0.1010
#     163    164   34.8    0.1111   0.1142      0.1080
#     167    168   30.4    0.1459   0.1459      0.1400
# Step=   25, Dmax= 2.4e-02 nm, Epot= -1.18280e+05 Fmax= 1.20649e+03, atom= 167
# Step=   26, Dmax= 2.9e-02 nm, Epot= -1.18461e+05 Fmax= 8.11687e+03, atom= 167
# Step=   27, Dmax= 3.5e-02 nm, Epot= -1.19912e+05 Fmax= 4.15435e+03, atom= 176
#
# Step 28, time 0.056 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.010401, max 0.040977 (between atoms 167 and 168)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#     165    166   31.0    0.1044   0.1029      0.1010
# Step=   29, Dmax= 2.1e-02 nm, Epot= -1.20363e+05 Fmax= 3.73926e+03, atom= 167
# Step=   30, Dmax= 2.5e-02 nm, Epot= -1.20484e+05 Fmax= 5.11257e+03, atom= 176
# Step=   31, Dmax= 3.0e-02 nm, Epot= -1.20683e+05 Fmax= 5.85229e+03, atom= 167
# Step=   33, Dmax= 1.8e-02 nm, Epot= -1.21566e+05 Fmax= 7.59040e+02, atom= 167
# Step=   34, Dmax= 2.1e-02 nm, Epot= -1.22032e+05 Fmax= 6.41626e+03, atom= 167
# Step=   35, Dmax= 2.6e-02 nm, Epot= -1.23019e+05 Fmax= 2.90161e+03, atom= 176
# Step=   37, Dmax= 1.5e-02 nm, Epot= -1.23327e+05 Fmax= 2.95614e+03, atom= 167
# Step=   38, Dmax= 1.9e-02 nm, Epot= -1.23500e+05 Fmax= 3.74441e+03, atom= 167
# Step=   39, Dmax= 2.2e-02 nm, Epot= -1.23648e+05 Fmax= 4.54815e+03, atom= 167
# Step=   40, Dmax= 2.7e-02 nm, Epot= -1.23754e+05 Fmax= 4.96674e+03, atom= 176
# Step=   42, Dmax= 1.6e-02 nm, Epot= -1.24466e+05 Fmax= 8.95933e+02, atom= 167
# Step=   44, Dmax= 9.6e-03 nm, Epot= -1.24738e+05 Fmax= 2.68156e+03, atom= 167
# Step=   45, Dmax= 1.2e-02 nm, Epot= -1.25041e+05 Fmax= 1.61741e+03, atom= 167
# Step=   46, Dmax= 1.4e-02 nm, Epot= -1.25143e+05 Fmax= 3.39928e+03, atom= 167
# Step=   47, Dmax= 1.7e-02 nm, Epot= -1.25441e+05 Fmax= 2.80113e+03, atom= 167
# Step=   49, Dmax= 1.0e-02 nm, Epot= -1.25733e+05 Fmax= 9.23472e+02, atom= 167
# Step=   50, Dmax= 1.2e-02 nm, Epot= -1.25894e+05 Fmax= 3.42156e+03, atom= 167
# Step=   51, Dmax= 1.4e-02 nm, Epot= -1.26254e+05 Fmax= 1.87573e+03, atom= 167
# Step=   53, Dmax= 8.6e-03 nm, Epot= -1.26453e+05 Fmax= 1.33543e+03, atom= 167
# Step=   54, Dmax= 1.0e-02 nm, Epot= -1.26591e+05 Fmax= 2.47675e+03, atom= 167
# Step=   55, Dmax= 1.2e-02 nm, Epot= -1.26799e+05 Fmax= 2.15777e+03, atom= 167
# Step=   56, Dmax= 1.5e-02 nm, Epot= -1.26859e+05 Fmax= 3.26611e+03, atom= 167
# Step=   57, Dmax= 1.8e-02 nm, Epot= -1.27017e+05 Fmax= 3.39410e+03, atom= 167
# Step=   59, Dmax= 1.1e-02 nm, Epot= -1.27364e+05 Fmax= 6.01752e+02, atom= 167
# Step=   60, Dmax= 1.3e-02 nm, Epot= -1.27487e+05 Fmax= 3.95631e+03, atom= 167
# Step=   61, Dmax= 1.5e-02 nm, Epot= -1.27947e+05 Fmax= 1.73304e+03, atom= 167
# Step=   63, Dmax= 9.3e-03 nm, Epot= -1.28120e+05 Fmax= 1.73659e+03, atom= 167
# Step=   64, Dmax= 1.1e-02 nm, Epot= -1.28228e+05 Fmax= 2.36649e+03, atom= 167
# Step=   65, Dmax= 1.3e-02 nm, Epot= -1.28353e+05 Fmax= 2.60920e+03, atom= 167
# Step=   66, Dmax= 1.6e-02 nm, Epot= -1.28412e+05 Fmax= 3.22878e+03, atom= 167
# Step=   67, Dmax= 1.9e-02 nm, Epot= -1.28457e+05 Fmax= 3.92451e+03, atom= 167
# Step=   68, Dmax= 2.3e-02 nm, Epot= -1.28474e+05 Fmax= 4.35634e+03, atom= 176
# Step=   70, Dmax= 1.4e-02 nm, Epot= -1.29023e+05 Fmax= 7.52632e+02, atom= 167
# Step=   72, Dmax= 8.3e-03 nm, Epot= -1.29126e+05 Fmax= 2.33327e+03, atom= 167
# Step=   73, Dmax= 1.0e-02 nm, Epot= -1.29339e+05 Fmax= 1.38300e+03, atom= 167
# Step=   74, Dmax= 1.2e-02 nm, Epot= -1.29351e+05 Fmax= 2.97767e+03, atom= 167
# Step=   75, Dmax= 1.4e-02 nm, Epot= -1.29558e+05 Fmax= 2.37031e+03, atom= 167
# Step=   77, Dmax= 8.6e-03 nm, Epot= -1.29753e+05 Fmax= 8.34867e+02, atom= 167
# Step=   78, Dmax= 1.0e-02 nm, Epot= -1.29785e+05 Fmax= 2.93801e+03, atom= 167
# Step=   79, Dmax= 1.2e-02 nm, Epot= -1.30047e+05 Fmax= 1.64253e+03, atom= 167
# Step=   81, Dmax= 7.4e-03 nm, Epot= -1.30179e+05 Fmax= 1.12431e+03, atom= 167
# Step=   82, Dmax= 8.9e-03 nm, Epot= -1.30238e+05 Fmax= 2.16182e+03, atom= 167
# Step=   83, Dmax= 1.1e-02 nm, Epot= -1.30385e+05 Fmax= 1.82622e+03, atom= 167
# Step=   84, Dmax= 1.3e-02 nm, Epot= -1.30391e+05 Fmax= 2.87211e+03, atom= 167
# Step=   85, Dmax= 1.5e-02 nm, Epot= -1.30508e+05 Fmax= 2.87770e+03, atom= 167
# Step=   87, Dmax= 9.2e-03 nm, Epot= -1.30761e+05 Fmax= 5.87650e+02, atom= 220
# Step=   89, Dmax= 5.5e-03 nm, Epot= -1.30863e+05 Fmax= 1.41082e+03, atom= 229
# Step=   90, Dmax= 6.7e-03 nm, Epot= -1.30994e+05 Fmax= 1.11036e+03, atom= 220
# Step=   91, Dmax= 8.0e-03 nm, Epot= -1.31064e+05 Fmax= 1.82821e+03, atom= 220
# Step=   92, Dmax= 9.6e-03 nm, Epot= -1.31172e+05 Fmax= 1.76506e+03, atom= 220
# Step=   93, Dmax= 1.1e-02 nm, Epot= -1.31212e+05 Fmax= 2.50982e+03, atom= 220
# Step=   94, Dmax= 1.4e-02 nm, Epot= -1.31297e+05 Fmax= 2.60509e+03, atom= 220
# Step=   96, Dmax= 8.3e-03 nm, Epot= -1.31503e+05 Fmax= 4.75912e+02, atom= 229
# Step=   98, Dmax= 5.0e-03 nm, Epot= -1.31599e+05 Fmax= 1.38689e+03, atom= 220
# Step=   99, Dmax= 6.0e-03 nm, Epot= -1.31726e+05 Fmax= 8.16084e+02, atom= 229
# Step=  100, Dmax= 7.2e-03 nm, Epot= -1.31787e+05 Fmax= 1.87370e+03, atom= 220
# Step=  101, Dmax= 8.6e-03 nm, Epot= -1.31922e+05 Fmax= 1.30768e+03, atom= 229
# Step=  102, Dmax= 1.0e-02 nm, Epot= -1.31928e+05 Fmax= 2.52780e+03, atom= 220
# Step=  103, Dmax= 1.2e-02 nm, Epot= -1.32066e+05 Fmax= 2.06477e+03, atom= 220
# Step=  105, Dmax= 7.4e-03 nm, Epot= -1.32206e+05 Fmax= 7.35775e+02, atom= 220
# Step=  106, Dmax= 8.9e-03 nm, Epot= -1.32214e+05 Fmax= 2.48330e+03, atom= 220
# Step=  107, Dmax= 1.1e-02 nm, Epot= -1.32400e+05 Fmax= 1.51224e+03, atom= 220
# Step=  109, Dmax= 6.4e-03 nm, Epot= -1.32499e+05 Fmax= 8.66424e+02, atom= 229
# Step=  110, Dmax= 7.7e-03 nm, Epot= -1.32530e+05 Fmax= 1.99783e+03, atom= 220
# Step=  111, Dmax= 9.2e-03 nm, Epot= -1.32658e+05 Fmax= 1.41816e+03, atom= 229
# Step=  113, Dmax= 5.5e-03 nm, Epot= -1.32747e+05 Fmax= 6.82560e+02, atom= 220
# Step=  114, Dmax= 6.6e-03 nm, Epot= -1.32787e+05 Fmax= 1.71250e+03, atom= 220
# Step=  115, Dmax= 8.0e-03 nm, Epot= -1.32911e+05 Fmax= 1.29429e+03, atom= 220
# Step=  116, Dmax= 9.6e-03 nm, Epot= -1.32935e+05 Fmax= 2.23564e+03, atom= 220
# Step=  117, Dmax= 1.1e-02 nm, Epot= -1.33028e+05 Fmax= 2.05533e+03, atom= 220
# Step=  119, Dmax= 6.9e-03 nm, Epot= -1.33153e+05 Fmax= 5.15786e+02, atom= 229
# Step=  121, Dmax= 4.1e-03 nm, Epot= -1.33209e+05 Fmax= 1.04387e+03, atom= 220
# Step=  122, Dmax= 5.0e-03 nm, Epot= -1.33294e+05 Fmax= 7.88188e+02, atom= 229
# Step=  123, Dmax= 6.0e-03 nm, Epot= -1.33339e+05 Fmax= 1.46021e+03, atom= 220
# Step=  124, Dmax= 7.1e-03 nm, Epot= -1.33431e+05 Fmax= 1.19692e+03, atom= 229
# Step=  125, Dmax= 8.6e-03 nm, Epot= -1.33457e+05 Fmax= 2.02250e+03, atom= 220
# Step=  126, Dmax= 1.0e-02 nm, Epot= -1.33541e+05 Fmax= 1.80127e+03, atom= 220
# Step=  128, Dmax= 6.2e-03 nm, Epot= -1.33641e+05 Fmax= 5.34417e+02, atom= 220
# Step=  130, Dmax= 3.7e-03 nm, Epot= -1.33690e+05 Fmax= 8.21173e+02, atom= 229
# Step=  131, Dmax= 4.4e-03 nm, Epot= -1.33757e+05 Fmax= 8.69393e+02, atom= 220
# Step=  132, Dmax= 5.3e-03 nm, Epot= -1.33809e+05 Fmax= 1.10526e+03, atom= 229
# Step=  133, Dmax= 6.4e-03 nm, Epot= -1.33865e+05 Fmax= 1.30791e+03, atom= 220
# Step=  134, Dmax= 7.7e-03 nm, Epot= -1.33917e+05 Fmax= 1.53744e+03, atom= 229
# Step=  135, Dmax= 9.2e-03 nm, Epot= -1.33956e+05 Fmax= 1.91735e+03, atom= 220
# Step=  136, Dmax= 1.1e-02 nm, Epot= -1.33999e+05 Fmax= 2.20472e+03, atom= 220
# Step=  137, Dmax= 1.3e-02 nm, Epot= -1.34017e+05 Fmax= 2.69925e+03, atom= 220
# Step=  138, Dmax= 1.6e-02 nm, Epot= -1.34029e+05 Fmax= 3.25989e+03, atom= 220
# Step=  140, Dmax= 9.6e-03 nm, Epot= -1.34242e+05 Fmax= 3.34688e+02, atom= 220
# Step=  142, Dmax= 5.7e-03 nm, Epot= -1.34248e+05 Fmax= 1.63528e+03, atom= 220
# Step=  143, Dmax= 6.9e-03 nm, Epot= -1.34403e+05 Fmax= 9.55643e+02, atom= 220
# Step=  144, Dmax= 8.3e-03 nm, Epot= -1.34433e+05 Fmax= 2.10442e+03, atom= 220
# Step=  145, Dmax= 9.9e-03 nm, Epot= -1.34536e+05 Fmax= 1.60511e+03, atom= 220
# Step=  147, Dmax= 5.9e-03 nm, Epot= -1.34613e+05 Fmax= 6.18548e+02, atom= 229
# Step=  149, Dmax= 3.6e-03 nm, Epot= -1.34654e+05 Fmax= 7.38851e+02, atom= 220
# Step=  150, Dmax= 4.3e-03 nm, Epot= -1.34703e+05 Fmax= 8.48577e+02, atom= 229
# Step=  151, Dmax= 5.1e-03 nm, Epot= -1.34752e+05 Fmax= 1.09548e+03, atom= 220
# Step=  152, Dmax= 6.2e-03 nm, Epot= -1.34803e+05 Fmax= 1.18872e+03, atom= 229
# Step=  153, Dmax= 7.4e-03 nm, Epot= -1.34840e+05 Fmax= 1.59673e+03, atom= 220
# Step=  154, Dmax= 8.9e-03 nm, Epot= -1.34889e+05 Fmax= 1.70361e+03, atom= 220
# Step=  155, Dmax= 1.1e-02 nm, Epot= -1.34906e+05 Fmax= 2.26619e+03, atom= 220
# Step=  156, Dmax= 1.3e-02 nm, Epot= -1.34946e+05 Fmax= 2.51113e+03, atom= 220
# Step=  158, Dmax= 7.7e-03 nm, Epot= -1.35075e+05 Fmax= 3.88510e+02, atom= 220
# Step=  160, Dmax= 4.6e-03 nm, Epot= -1.35095e+05 Fmax= 1.25715e+03, atom= 229
# Step=  161, Dmax= 5.5e-03 nm, Epot= -1.35196e+05 Fmax= 8.37224e+02, atom= 220
# Step=  162, Dmax= 6.6e-03 nm, Epot= -1.35221e+05 Fmax= 1.60490e+03, atom= 220
# Step=  163, Dmax= 7.9e-03 nm, Epot= -1.35291e+05 Fmax= 1.39186e+03, atom= 220
# Step=  164, Dmax= 9.5e-03 nm, Epot= -1.35301e+05 Fmax= 2.15660e+03, atom= 220
# Step=  165, Dmax= 1.1e-02 nm, Epot= -1.35355e+05 Fmax= 2.11812e+03, atom= 220
# Step=  167, Dmax= 6.9e-03 nm, Epot= -1.35450e+05 Fmax= 4.46694e+02, atom= 229
# Step=  169, Dmax= 4.1e-03 nm, Epot= -1.35474e+05 Fmax= 1.11240e+03, atom= 220
# Step=  170, Dmax= 4.9e-03 nm, Epot= -1.35548e+05 Fmax= 7.27192e+02, atom= 229
# Step=  171, Dmax= 5.9e-03 nm, Epot= -1.35562e+05 Fmax= 1.50099e+03, atom= 220
# Step=  172, Dmax= 7.1e-03 nm, Epot= -1.35637e+05 Fmax= 1.14346e+03, atom= 229
# Step=  173, Dmax= 8.5e-03 nm, Epot= -1.35637e+05 Fmax= 2.04665e+03, atom= 220
# Step=  174, Dmax= 1.0e-02 nm, Epot= -1.35707e+05 Fmax= 1.77654e+03, atom= 220
# Step=  176, Dmax= 6.2e-03 nm, Epot= -1.35781e+05 Fmax= 5.60160e+02, atom= 220
# Step=  178, Dmax= 3.7e-03 nm, Epot= -1.35806e+05 Fmax= 8.02822e+02, atom= 229
# Step=  179, Dmax= 4.4e-03 nm, Epot= -1.35849e+05 Fmax= 8.75700e+02, atom= 220
# Step=  180, Dmax= 5.3e-03 nm, Epot= -1.35887e+05 Fmax= 1.10617e+03, atom= 229
# Step=  181, Dmax= 6.4e-03 nm, Epot= -1.35925e+05 Fmax= 1.30309e+03, atom= 220
# Step=  182, Dmax= 7.7e-03 nm, Epot= -1.35960e+05 Fmax= 1.54128e+03, atom= 229
# Step=  183, Dmax= 9.2e-03 nm, Epot= -1.35986e+05 Fmax= 1.89972e+03, atom= 220
# Step=  184, Dmax= 1.1e-02 nm, Epot= -1.36014e+05 Fmax= 2.20640e+03, atom= 220
# Step=  185, Dmax= 1.3e-02 nm, Epot= -1.36024e+05 Fmax= 2.68712e+03, atom= 220
# Step=  186, Dmax= 1.6e-02 nm, Epot= -1.36028e+05 Fmax= 3.24559e+03, atom= 220
# Step=  188, Dmax= 9.5e-03 nm, Epot= -1.36194e+05 Fmax= 3.26179e+02, atom= 220
# Step=  191, Dmax= 2.9e-03 nm, Epot= -1.36216e+05 Fmax= 6.91581e+02, atom= 229
# Step=  192, Dmax= 3.4e-03 nm, Epot= -1.36275e+05 Fmax= 6.04893e+02, atom= 220
# Step=  193, Dmax= 4.1e-03 nm, Epot= -1.36305e+05 Fmax= 9.12531e+02, atom= 229
# Step=  194, Dmax= 4.9e-03 nm, Epot= -1.36350e+05 Fmax= 9.59407e+02, atom= 220
# Step=  195, Dmax= 5.9e-03 nm, Epot= -1.36381e+05 Fmax= 1.25007e+03, atom= 229
# Step=  196, Dmax= 7.1e-03 nm, Epot= -1.36417e+05 Fmax= 1.42404e+03, atom= 220
# Step=  197, Dmax= 8.5e-03 nm, Epot= -1.36444e+05 Fmax= 1.75792e+03, atom= 229
# Step=  198, Dmax= 1.0e-02 nm, Epot= -1.36468e+05 Fmax= 2.06311e+03, atom= 220
# Step=  199, Dmax= 1.2e-02 nm, Epot= -1.36483e+05 Fmax= 2.52730e+03, atom= 220
# Step=  200, Dmax= 1.5e-02 nm, Epot= -1.36495e+05 Fmax= 2.90896e+03, atom= 220
# Step=  202, Dmax= 8.8e-03 nm, Epot= -1.36638e+05 Fmax= 3.93645e+02, atom= 229
# Step=  205, Dmax= 2.7e-03 nm, Epot= -1.36662e+05 Fmax= 6.21996e+02, atom= 220
# Step=  206, Dmax= 3.2e-03 nm, Epot= -1.36701e+05 Fmax= 5.61564e+02, atom= 229
# Step=  207, Dmax= 3.8e-03 nm, Epot= -1.36726e+05 Fmax= 8.82137e+02, atom= 220
# Step=  208, Dmax= 4.6e-03 nm, Epot= -1.36776e+05 Fmax= 8.28957e+02, atom= 229
# Step=  209, Dmax= 5.5e-03 nm, Epot= -1.36801e+05 Fmax= 1.24675e+03, atom= 220
# Step=  210, Dmax= 6.6e-03 nm, Epot= -1.36845e+05 Fmax= 1.21452e+03, atom= 229
# Step=  211, Dmax= 7.9e-03 nm, Epot= -1.36858e+05 Fmax= 1.75531e+03, atom= 220
# Step=  212, Dmax= 9.5e-03 nm, Epot= -1.36898e+05 Fmax= 1.79874e+03, atom= 229
# Step=  214, Dmax= 5.7e-03 nm, Epot= -1.36969e+05 Fmax= 3.57598e+02, atom= 220
# Step=  216, Dmax= 3.4e-03 nm, Epot= -1.36978e+05 Fmax= 8.83394e+02, atom= 229
# Step=  217, Dmax= 4.1e-03 nm, Epot= -1.37043e+05 Fmax= 6.81333e+02, atom= 220
# Step=  218, Dmax= 4.9e-03 nm, Epot= -1.37061e+05 Fmax= 1.15441e+03, atom= 229
# Step=  219, Dmax= 5.9e-03 nm, Epot= -1.37111e+05 Fmax= 1.07481e+03, atom= 220
# Step=  220, Dmax= 7.1e-03 nm, Epot= -1.37126e+05 Fmax= 1.56721e+03, atom= 229
# Step=  221, Dmax= 8.5e-03 nm, Epot= -1.37166e+05 Fmax= 1.62469e+03, atom= 220
# Step=  222, Dmax= 1.0e-02 nm, Epot= -1.37176e+05 Fmax= 2.17362e+03, atom= 220
# Step=  223, Dmax= 1.2e-02 nm, Epot= -1.37201e+05 Fmax= 2.38195e+03, atom= 220
# Step=  225, Dmax= 7.4e-03 nm, Epot= -1.37299e+05 Fmax= 3.74060e+02, atom= 229
# Step=  228, Dmax= 2.2e-03 nm, Epot= -1.37324e+05 Fmax= 4.62165e+02, atom= 220
# Step=  229, Dmax= 2.6e-03 nm, Epot= -1.37348e+05 Fmax= 5.20866e+02, atom= 229
# Step=  230, Dmax= 3.2e-03 nm, Epot= -1.37384e+05 Fmax= 6.86713e+02, atom= 220
# Step=  231, Dmax= 3.8e-03 nm, Epot= -1.37418e+05 Fmax= 7.31434e+02, atom= 229
# Step=  232, Dmax= 4.6e-03 nm, Epot= -1.37447e+05 Fmax= 9.98661e+02, atom= 220
# Step=  233, Dmax= 5.5e-03 nm, Epot= -1.37481e+05 Fmax= 1.04429e+03, atom= 229
# Step=  234, Dmax= 6.6e-03 nm, Epot= -1.37500e+05 Fmax= 1.43924e+03, atom= 220
# Step=  235, Dmax= 7.9e-03 nm, Epot= -1.37535e+05 Fmax= 1.49663e+03, atom= 229
# Step=  236, Dmax= 9.5e-03 nm, Epot= -1.37545e+05 Fmax= 2.04767e+03, atom= 220
# Step=  237, Dmax= 1.1e-02 nm, Epot= -1.37574e+05 Fmax= 2.20637e+03, atom= 220
# Step=  239, Dmax= 6.8e-03 nm, Epot= -1.37658e+05 Fmax= 3.64660e+02, atom= 220
# Step=  242, Dmax= 2.0e-03 nm, Epot= -1.37680e+05 Fmax= 4.03057e+02, atom= 229
# Step=  243, Dmax= 2.5e-03 nm, Epot= -1.37700e+05 Fmax= 5.27621e+02, atom= 220
# Step=  244, Dmax= 3.0e-03 nm, Epot= -1.37738e+05 Fmax= 5.69835e+02, atom= 229
# Step=  245, Dmax= 3.5e-03 nm, Epot= -1.37762e+05 Fmax= 7.72680e+02, atom= 220
# Step=  246, Dmax= 4.3e-03 nm, Epot= -1.37798e+05 Fmax= 8.04776e+02, atom= 229
# Step=  247, Dmax= 5.1e-03 nm, Epot= -1.37818e+05 Fmax= 1.12078e+03, atom= 220
# Step=  248, Dmax= 6.1e-03 nm, Epot= -1.37852e+05 Fmax= 1.14670e+03, atom= 229
# Step=  249, Dmax= 7.3e-03 nm, Epot= -1.37866e+05 Fmax= 1.60945e+03, atom= 220
# Step=  250, Dmax= 8.8e-03 nm, Epot= -1.37900e+05 Fmax= 1.66437e+03, atom= 229
# Step=  251, Dmax= 1.1e-02 nm, Epot= -1.37901e+05 Fmax= 2.28650e+03, atom= 220
# Step=  252, Dmax= 1.3e-02 nm, Epot= -1.37926e+05 Fmax= 2.45948e+03, atom= 220
# Step=  254, Dmax= 7.6e-03 nm, Epot= -1.38019e+05 Fmax= 3.98324e+02, atom= 220
# Step=  257, Dmax= 2.3e-03 nm, Epot= -1.38036e+05 Fmax= 4.46816e+02, atom= 229
# Step=  258, Dmax= 2.7e-03 nm, Epot= -1.38052e+05 Fmax= 5.80972e+02, atom= 220
# Step=  259, Dmax= 3.3e-03 nm, Epot= -1.38088e+05 Fmax= 6.34038e+02, atom= 229
# Step=  260, Dmax= 3.9e-03 nm, Epot= -1.38111e+05 Fmax= 8.45096e+02, atom= 220
# Step=  261, Dmax= 4.7e-03 nm, Epot= -1.38144e+05 Fmax= 9.01361e+02, atom= 229
# Step=  262, Dmax= 5.7e-03 nm, Epot= -1.38161e+05 Fmax= 1.24348e+03, atom= 220
# Step=  263, Dmax= 6.8e-03 nm, Epot= -1.38195e+05 Fmax= 1.27914e+03, atom= 229
# Step=  264, Dmax= 8.2e-03 nm, Epot= -1.38203e+05 Fmax= 1.78251e+03, atom= 220
# Step=  265, Dmax= 9.8e-03 nm, Epot= -1.38235e+05 Fmax= 1.88393e+03, atom= 220
# Step=  267, Dmax= 5.9e-03 nm, Epot= -1.38303e+05 Fmax= 3.38714e+02, atom= 220
# Step=  270, Dmax= 1.8e-03 nm, Epot= -1.38322e+05 Fmax= 3.15505e+02, atom= 229
# Step=  271, Dmax= 2.1e-03 nm, Epot= -1.38329e+05 Fmax= 4.73580e+02, atom= 220
# Step=  272, Dmax= 2.5e-03 nm, Epot= -1.38376e+05 Fmax= 4.63729e+02, atom= 229
# Step=  273, Dmax= 3.1e-03 nm, Epot= -1.38391e+05 Fmax= 6.88123e+02, atom= 220
# Step=  274, Dmax= 3.7e-03 nm, Epot= -1.38428e+05 Fmax= 6.61995e+02, atom= 229
# Step=  275, Dmax= 4.4e-03 nm, Epot= -1.38444e+05 Fmax= 9.92241e+02, atom= 220
# Step=  276, Dmax= 5.3e-03 nm, Epot= -1.38478e+05 Fmax= 9.59127e+02, atom= 229
# Step=  277, Dmax= 6.3e-03 nm, Epot= -1.38486e+05 Fmax= 1.42218e+03, atom= 220
# Step=  278, Dmax= 7.6e-03 nm, Epot= -1.38519e+05 Fmax= 1.40303e+03, atom= 229
# Step=  280, Dmax= 4.6e-03 nm, Epot= -1.38572e+05 Fmax= 3.17244e+02, atom= 220
# Step=  283, Dmax= 1.4e-03 nm, Epot= -1.38590e+05 Fmax= 2.83196e+02, atom= 7790
# Step=  284, Dmax= 1.6e-03 nm, Epot= -1.38599e+05 Fmax= 2.80695e+02, atom= 1759
# Step=  285, Dmax= 2.0e-03 nm, Epot= -1.38613e+05 Fmax= 3.66274e+02, atom= 229
# Step=  286, Dmax= 2.4e-03 nm, Epot= -1.38647e+05 Fmax= 5.19422e+02, atom= 220
# Step=  287, Dmax= 2.8e-03 nm, Epot= -1.38686e+05 Fmax= 5.24522e+02, atom= 229
# Step=  288, Dmax= 3.4e-03 nm, Epot= -1.38702e+05 Fmax= 7.50185e+02, atom= 220
# Step=  289, Dmax= 4.1e-03 nm, Epot= -1.38732e+05 Fmax= 7.64384e+02, atom= 229
# Step=  290, Dmax= 4.9e-03 nm, Epot= -1.38742e+05 Fmax= 1.06904e+03, atom= 220
# Step=  291, Dmax= 5.9e-03 nm, Epot= -1.38774e+05 Fmax= 1.11986e+03, atom= 229
# Step=  292, Dmax= 7.1e-03 nm, Epot= -1.38781e+05 Fmax= 1.52120e+03, atom= 220
# Step=  293, Dmax= 8.5e-03 nm, Epot= -1.38805e+05 Fmax= 1.63306e+03, atom= 229
# Step=  295, Dmax= 5.1e-03 nm, Epot= -1.38868e+05 Fmax= 2.97628e+02, atom= 5722
# Step=  298, Dmax= 1.5e-03 nm, Epot= -1.38882e+05 Fmax= 2.89749e+02, atom= 5152
# Step=  299, Dmax= 1.8e-03 nm, Epot= -1.38885e+05 Fmax= 3.58410e+02, atom= 220
# Step=  300, Dmax= 2.2e-03 nm, Epot= -1.38917e+05 Fmax= 4.55896e+02, atom= 229
# Step=  301, Dmax= 2.6e-03 nm, Epot= -1.38942e+05 Fmax= 5.30108e+02, atom= 220
# Step=  302, Dmax= 3.2e-03 nm, Epot= -1.38966e+05 Fmax= 6.46153e+02, atom= 229
# Step=  303, Dmax= 3.8e-03 nm, Epot= -1.38985e+05 Fmax= 7.68828e+02, atom= 220
# Step=  304, Dmax= 4.6e-03 nm, Epot= -1.39009e+05 Fmax= 9.25086e+02, atom= 229
# Step=  305, Dmax= 5.5e-03 nm, Epot= -1.39026e+05 Fmax= 1.12048e+03, atom= 220
# Step=  306, Dmax= 6.6e-03 nm, Epot= -1.39044e+05 Fmax= 1.31672e+03, atom= 229
# Step=  307, Dmax= 7.9e-03 nm, Epot= -1.39053e+05 Fmax= 1.64078e+03, atom= 220
# Step=  308, Dmax= 9.4e-03 nm, Epot= -1.39066e+05 Fmax= 1.87905e+03, atom= 220
# Step=  310, Dmax= 5.7e-03 nm, Epot= -1.39143e+05 Fmax= 2.74837e+02, atom= 5951
# Step=  313, Dmax= 1.7e-03 nm, Epot= -1.39148e+05 Fmax= 3.36881e+02, atom= 3946
# Step=  314, Dmax= 2.0e-03 nm, Epot= -1.39160e+05 Fmax= 4.25034e+02, atom= 220
# Step=  315, Dmax= 2.4e-03 nm, Epot= -1.39191e+05 Fmax= 4.81159e+02, atom= 229
# Step=  316, Dmax= 2.9e-03 nm, Epot= -1.39205e+05 Fmax= 6.27385e+02, atom= 220
# Step=  317, Dmax= 3.5e-03 nm, Epot= -1.39232e+05 Fmax= 6.89271e+02, atom= 229
# Step=  318, Dmax= 4.2e-03 nm, Epot= -1.39244e+05 Fmax= 8.93215e+02, atom= 220
# Step=  319, Dmax= 5.1e-03 nm, Epot= -1.39266e+05 Fmax= 1.00080e+03, atom= 229
# Step=  320, Dmax= 6.1e-03 nm, Epot= -1.39275e+05 Fmax= 1.27999e+03, atom= 220
# Step=  321, Dmax= 7.3e-03 nm, Epot= -1.39294e+05 Fmax= 1.43884e+03, atom= 229
# Step=  323, Dmax= 4.4e-03 nm, Epot= -1.39354e+05 Fmax= 2.21220e+02, atom= 220
# Step=  326, Dmax= 1.3e-03 nm, Epot= -1.39360e+05 Fmax= 3.10543e+02, atom= 2680
# Step=  327, Dmax= 1.6e-03 nm, Epot= -1.39378e+05 Fmax= 3.26995e+02, atom= 3946
# Step=  328, Dmax= 1.9e-03 nm, Epot= -1.39393e+05 Fmax= 3.81942e+02, atom= 2680
# Step=  329, Dmax= 2.3e-03 nm, Epot= -1.39408e+05 Fmax= 3.59356e+02, atom= 220
# Step=  330, Dmax= 2.7e-03 nm, Epot= -1.39412e+05 Fmax= 6.41395e+02, atom= 229
# Step=  331, Dmax= 3.3e-03 nm, Epot= -1.39457e+05 Fmax= 5.97289e+02, atom= 220
# Step=  332, Dmax= 3.9e-03 nm, Epot= -1.39466e+05 Fmax= 8.62807e+02, atom= 229
# Step=  333, Dmax= 4.7e-03 nm, Epot= -1.39486e+05 Fmax= 9.23304e+02, atom= 220
# Step=  334, Dmax= 5.7e-03 nm, Epot= -1.39494e+05 Fmax= 1.17877e+03, atom= 229
# Step=  335, Dmax= 6.8e-03 nm, Epot= -1.39505e+05 Fmax= 1.37777e+03, atom= 220
# Step=  336, Dmax= 8.1e-03 nm, Epot= -1.39512e+05 Fmax= 1.66033e+03, atom= 220
# Step=  338, Dmax= 4.9e-03 nm, Epot= -1.39587e+05 Fmax= 1.91977e+02, atom= 4786
# Step=  342, Dmax= 7.3e-04 nm, Epot= -1.39602e+05 Fmax= 3.03614e+02, atom= 2680
# Step=  343, Dmax= 8.8e-04 nm, Epot= -1.39615e+05 Fmax= 2.60595e+02, atom= 2680
# Step=  344, Dmax= 1.1e-03 nm, Epot= -1.39621e+05 Fmax= 3.83364e+02, atom= 2680
# Step=  345, Dmax= 1.3e-03 nm, Epot= -1.39636e+05 Fmax= 2.56812e+02, atom= 7790
# Step=  347, Dmax= 7.6e-04 nm, Epot= -1.39649e+05 Fmax= 2.60899e+02, atom= 4249
# Step=  348, Dmax= 9.1e-04 nm, Epot= -1.39656e+05 Fmax= 3.14612e+02, atom= 7784
# Step=  349, Dmax= 1.1e-03 nm, Epot= -1.39668e+05 Fmax= 2.66532e+02, atom= 7567
# Step=  351, Dmax= 6.6e-04 nm, Epot= -1.39682e+05 Fmax= 2.37775e+02, atom= 7793
# Step=  352, Dmax= 7.9e-04 nm, Epot= -1.39690e+05 Fmax= 3.11999e+02, atom= 2680
# Step=  353, Dmax= 9.5e-04 nm, Epot= -1.39700e+05 Fmax= 2.89311e+02, atom= 7793
# Step=  354, Dmax= 1.1e-03 nm, Epot= -1.39706e+05 Fmax= 3.15616e+02, atom= 7784
# Step=  355, Dmax= 1.4e-03 nm, Epot= -1.39713e+05 Fmax= 3.19286e+02, atom= 7784
# Step=  356, Dmax= 1.6e-03 nm, Epot= -1.39724e+05 Fmax= 3.82245e+02, atom= 2680
# Step=  357, Dmax= 2.0e-03 nm, Epot= -1.39741e+05 Fmax= 3.53090e+02, atom= 7793
# Step=  358, Dmax= 2.4e-03 nm, Epot= -1.39746e+05 Fmax= 3.84109e+02, atom= 2680
# Step=  359, Dmax= 2.8e-03 nm, Epot= -1.39755e+05 Fmax= 4.29689e+02, atom= 7784
# Step=  360, Dmax= 3.4e-03 nm, Epot= -1.39776e+05 Fmax= 3.39944e+02, atom= 7784
# Step=  362, Dmax= 2.0e-03 nm, Epot= -1.39827e+05 Fmax= 2.79461e+02, atom= 259
# Step=  363, Dmax= 2.4e-03 nm, Epot= -1.39827e+05 Fmax= 4.69119e+02, atom= 294
# Step=  364, Dmax= 2.9e-03 nm, Epot= -1.39867e+05 Fmax= 4.63470e+02, atom= 294
# Step=  365, Dmax= 3.5e-03 nm, Epot= -1.39875e+05 Fmax= 6.47536e+02, atom= 294
# Step=  366, Dmax= 4.2e-03 nm, Epot= -1.39896e+05 Fmax= 7.17268e+02, atom= 90
# Step=  368, Dmax= 2.5e-03 nm, Epot= -1.39953e+05 Fmax= 2.26867e+02, atom= 359
# Step=  370, Dmax= 1.5e-03 nm, Epot= -1.39959e+05 Fmax= 3.64856e+02, atom= 90
# Step=  371, Dmax= 1.8e-03 nm, Epot= -1.39980e+05 Fmax= 3.03557e+02, atom= 99
# Step=  373, Dmax= 1.1e-03 nm, Epot= -1.40006e+05 Fmax= 1.90385e+02, atom= 6478
# Step=  375, Dmax= 6.6e-04 nm, Epot= -1.40019e+05 Fmax= 2.23964e+02, atom= 6004
# Step=  376, Dmax= 7.9e-04 nm, Epot= -1.40028e+05 Fmax= 2.97201e+02, atom= 2680
# Step=  377, Dmax= 9.4e-04 nm, Epot= -1.40040e+05 Fmax= 2.68892e+02, atom= 970
# Step=  378, Dmax= 1.1e-03 nm, Epot= -1.40044e+05 Fmax= 3.16628e+02, atom= 2680
# Step=  379, Dmax= 1.4e-03 nm, Epot= -1.40054e+05 Fmax= 3.98180e+02, atom= 7793
# Step=  380, Dmax= 1.6e-03 nm, Epot= -1.40070e+05 Fmax= 2.53677e+02, atom= 7793
# Step=  382, Dmax= 9.8e-04 nm, Epot= -1.40085e+05 Fmax= 3.18884e+02, atom= 6388
# Step=  383, Dmax= 1.2e-03 nm, Epot= -1.40097e+05 Fmax= 2.52220e+02, atom= 6388
# Step=  385, Dmax= 7.0e-04 nm, Epot= -1.40111e+05 Fmax= 2.16179e+02, atom= 6079
# Step=  386, Dmax= 8.5e-04 nm, Epot= -1.40116e+05 Fmax= 2.77044e+02, atom= 5884
# Step=  387, Dmax= 1.0e-03 nm, Epot= -1.40126e+05 Fmax= 2.40842e+02, atom= 6961
# Step=  388, Dmax= 1.2e-03 nm, Epot= -1.40128e+05 Fmax= 4.05427e+02, atom= 2680
# Step=  389, Dmax= 1.5e-03 nm, Epot= -1.40152e+05 Fmax= 2.87946e+02, atom= 2680
# Step=  391, Dmax= 8.8e-04 nm, Epot= -1.40169e+05 Fmax= 2.42621e+02, atom= 715
# Step=  392, Dmax= 1.1e-03 nm, Epot= -1.40171e+05 Fmax= 3.57222e+02, atom= 7793
# Step=  393, Dmax= 1.3e-03 nm, Epot= -1.40187e+05 Fmax= 4.07448e+02, atom= 2680
# Step=  394, Dmax= 1.5e-03 nm, Epot= -1.40198e+05 Fmax= 4.12457e+02, atom= 7793
# Step=  395, Dmax= 1.8e-03 nm, Epot= -1.40202e+05 Fmax= 3.71104e+02, atom= 7793
# Step=  397, Dmax= 1.1e-03 nm, Epot= -1.40223e+05 Fmax= 2.59122e+02, atom= 715
# Step=  399, Dmax= 6.5e-04 nm, Epot= -1.40234e+05 Fmax= 2.17822e+02, atom= 2077
# Step=  400, Dmax= 7.9e-04 nm, Epot= -1.40238e+05 Fmax= 2.81536e+02, atom= 5116
# Step=  401, Dmax= 9.4e-04 nm, Epot= -1.40247e+05 Fmax= 2.75588e+02, atom= 6388
# Step=  402, Dmax= 1.1e-03 nm, Epot= -1.40251e+05 Fmax= 2.78234e+02, atom= 5581
# Step=  403, Dmax= 1.4e-03 nm, Epot= -1.40256e+05 Fmax= 4.55984e+02, atom= 2680
# Step=  404, Dmax= 1.6e-03 nm, Epot= -1.40281e+05 Fmax= 3.70800e+02, atom= 7793
# Step=  405, Dmax= 2.0e-03 nm, Epot= -1.40283e+05 Fmax= 4.11314e+02, atom= 7793
# Step=  406, Dmax= 2.3e-03 nm, Epot= -1.40285e+05 Fmax= 3.89787e+02, atom= 7793
# Step=  407, Dmax= 2.8e-03 nm, Epot= -1.40286e+05 Fmax= 4.87960e+02, atom= 7793
# Step=  408, Dmax= 3.4e-03 nm, Epot= -1.40309e+05 Fmax= 3.46032e+02, atom= 37
# Step=  410, Dmax= 2.0e-03 nm, Epot= -1.40347e+05 Fmax= 3.02154e+02, atom= 5116
# Step=  412, Dmax= 1.2e-03 nm, Epot= -1.40378e+05 Fmax= 2.16434e+02, atom= 7204
# Step=  414, Dmax= 7.3e-04 nm, Epot= -1.40393e+05 Fmax= 2.90055e+02, atom= 6388
# Step=  415, Dmax= 8.8e-04 nm, Epot= -1.40404e+05 Fmax= 2.26100e+02, atom= 4681
# Step=  417, Dmax= 5.3e-04 nm, Epot= -1.40414e+05 Fmax= 2.26555e+02, atom= 6004
# Step=  418, Dmax= 6.3e-04 nm, Epot= -1.40419e+05 Fmax= 2.50616e+02, atom= 6439
# Step=  419, Dmax= 7.6e-04 nm, Epot= -1.40425e+05 Fmax= 2.46109e+02, atom= 3460
# Step=  420, Dmax= 9.1e-04 nm, Epot= -1.40429e+05 Fmax= 2.62829e+02, atom= 895
# Step=  421, Dmax= 1.1e-03 nm, Epot= -1.40434e+05 Fmax= 2.73322e+02, atom= 6079
# Step=  422, Dmax= 1.3e-03 nm, Epot= -1.40440e+05 Fmax= 3.07428e+02, atom= 6388
# Step=  423, Dmax= 1.6e-03 nm, Epot= -1.40447e+05 Fmax= 2.80789e+02, atom= 4288
# Step=  425, Dmax= 9.4e-04 nm, Epot= -1.40477e+05 Fmax= 2.20170e+02, atom= 2278
# Step=  426, Dmax= 1.1e-03 nm, Epot= -1.40479e+05 Fmax= 2.99854e+02, atom= 2278
# Step=  427, Dmax= 1.4e-03 nm, Epot= -1.40488e+05 Fmax= 3.23857e+02, atom= 7793
# Step=  428, Dmax= 1.6e-03 nm, Epot= -1.40499e+05 Fmax= 3.18171e+02, atom= 6388
# Step=  430, Dmax= 9.8e-04 nm, Epot= -1.40523e+05 Fmax= 2.61243e+02, atom= 6818
# Step=  431, Dmax= 1.2e-03 nm, Epot= -1.40527e+05 Fmax= 2.69051e+02, atom= 4288
# Step=  433, Dmax= 7.0e-04 nm, Epot= -1.40545e+05 Fmax= 2.49300e+02, atom= 6818
# Step=  434, Dmax= 8.4e-04 nm, Epot= -1.40550e+05 Fmax= 3.31368e+02, atom= 6388
# Step=  435, Dmax= 1.0e-03 nm, Epot= -1.40559e+05 Fmax= 2.71422e+02, atom= 6818
# Step=  437, Dmax= 6.1e-04 nm, Epot= -1.40571e+05 Fmax= 2.70382e+02, atom= 6818
# Step=  438, Dmax= 7.3e-04 nm, Epot= -1.40575e+05 Fmax= 2.49401e+02, atom= 7735
# Step=  439, Dmax= 8.7e-04 nm, Epot= -1.40576e+05 Fmax= 2.83576e+02, atom= 6439
# Step=  440, Dmax= 1.0e-03 nm, Epot= -1.40582e+05 Fmax= 3.53154e+02, atom= 4147
# Step=  441, Dmax= 1.3e-03 nm, Epot= -1.40594e+05 Fmax= 3.07575e+02, atom= 2680
# Step=  443, Dmax= 7.6e-04 nm, Epot= -1.40609e+05 Fmax= 2.33773e+02, atom= 6818
# Step=  444, Dmax= 9.1e-04 nm, Epot= -1.40611e+05 Fmax= 3.09034e+02, atom= 2680
# Step=  445, Dmax= 1.1e-03 nm, Epot= -1.40617e+05 Fmax= 3.28416e+02, atom= 6388
# Step=  446, Dmax= 1.3e-03 nm, Epot= -1.40625e+05 Fmax= 2.75464e+02, atom= 6256
# Step=  448, Dmax= 7.8e-04 nm, Epot= -1.40641e+05 Fmax= 2.30977e+02, atom= 3979
# Step=  449, Dmax= 9.4e-04 nm, Epot= -1.40644e+05 Fmax= 3.33531e+02, atom= 6388
# Step=  450, Dmax= 1.1e-03 nm, Epot= -1.40653e+05 Fmax= 2.30124e+02, atom= 6232
# Step=  452, Dmax= 6.8e-04 nm, Epot= -1.40667e+05 Fmax= 2.88008e+02, atom= 2278
# Step=  453, Dmax= 8.1e-04 nm, Epot= -1.40674e+05 Fmax= 2.58118e+02, atom= 2278
# Step=  454, Dmax= 9.7e-04 nm, Epot= -1.40675e+05 Fmax= 2.60729e+02, atom= 4288
# Step=  455, Dmax= 1.2e-03 nm, Epot= -1.40675e+05 Fmax= 3.01275e+02, atom= 649
# Step=  456, Dmax= 1.4e-03 nm, Epot= -1.40684e+05 Fmax= 3.39427e+02, atom= 982
# Step=  457, Dmax= 1.7e-03 nm, Epot= -1.40695e+05 Fmax= 3.11900e+02, atom= 6388
# Step=  459, Dmax= 1.0e-03 nm, Epot= -1.40721e+05 Fmax= 3.43474e+02, atom= 7735
# Step=  460, Dmax= 1.2e-03 nm, Epot= -1.40730e+05 Fmax= 2.64126e+02, atom= 7417
# Step=  462, Dmax= 7.3e-04 nm, Epot= -1.40740e+05 Fmax= 2.50119e+02, atom= 4960
# Step=  463, Dmax= 8.7e-04 nm, Epot= -1.40744e+05 Fmax= 3.12997e+02, atom= 6388
# Step=  464, Dmax= 1.0e-03 nm, Epot= -1.40752e+05 Fmax= 2.82123e+02, atom= 2278
# Step=  465, Dmax= 1.3e-03 nm, Epot= -1.40752e+05 Fmax= 3.31946e+02, atom= 7333
# Step=  466, Dmax= 1.5e-03 nm, Epot= -1.40759e+05 Fmax= 3.37082e+02, atom= 7333
# Step=  467, Dmax= 1.8e-03 nm, Epot= -1.40766e+05 Fmax= 3.39856e+02, atom= 7333
# Step=  469, Dmax= 1.1e-03 nm, Epot= -1.40795e+05 Fmax= 2.49911e+02, atom= 4132
# Step=  470, Dmax= 1.3e-03 nm, Epot= -1.40795e+05 Fmax= 3.31865e+02, atom= 4582
# Step=  471, Dmax= 1.6e-03 nm, Epot= -1.40803e+05 Fmax= 3.17778e+02, atom= 1588
# Step=  472, Dmax= 1.9e-03 nm, Epot= -1.40807e+05 Fmax= 3.35544e+02, atom= 355
# Step=  474, Dmax= 1.1e-03 nm, Epot= -1.40840e+05 Fmax= 2.99288e+02, atom= 2680
# Step=  475, Dmax= 1.4e-03 nm, Epot= -1.40848e+05 Fmax= 3.24715e+02, atom= 6388
# Step=  476, Dmax= 1.6e-03 nm, Epot= -1.40848e+05 Fmax= 2.90292e+02, atom= 3328
# Step=  478, Dmax= 9.7e-04 nm, Epot= -1.40875e+05 Fmax= 2.59851e+02, atom= 1327
# Step=  479, Dmax= 1.2e-03 nm, Epot= -1.40878e+05 Fmax= 2.87685e+02, atom= 1978
# Step=  480, Dmax= 1.4e-03 nm, Epot= -1.40882e+05 Fmax= 3.06421e+02, atom= 7333
# Step=  481, Dmax= 1.7e-03 nm, Epot= -1.40888e+05 Fmax= 2.87196e+02, atom= 2584
# Step=  483, Dmax= 1.0e-03 nm, Epot= -1.40917e+05 Fmax= 2.47573e+02, atom= 730
# Step=  484, Dmax= 1.2e-03 nm, Epot= -1.40923e+05 Fmax= 3.15632e+02, atom= 7735
# Step=  485, Dmax= 1.5e-03 nm, Epot= -1.40930e+05 Fmax= 3.37815e+02, atom= 7792
# Step=  486, Dmax= 1.7e-03 nm, Epot= -1.40938e+05 Fmax= 3.10942e+02, atom= 7213
# Step=  488, Dmax= 1.0e-03 nm, Epot= -1.40964e+05 Fmax= 2.20105e+02, atom= 2719
# Step=  490, Dmax= 6.3e-04 nm, Epot= -1.40976e+05 Fmax= 2.15886e+02, atom= 5224
# Step=  491, Dmax= 7.5e-04 nm, Epot= -1.40980e+05 Fmax= 4.34879e+02, atom= 1327
# Step=  492, Dmax= 9.0e-04 nm, Epot= -1.40993e+05 Fmax= 2.02235e+02, atom= 6388
# Step=  494, Dmax= 5.4e-04 nm, Epot= -1.40998e+05 Fmax= 2.71657e+02, atom= 4375
# Step=  495, Dmax= 6.5e-04 nm, Epot= -1.41004e+05 Fmax= 2.33827e+02, atom= 7333
# Step=  496, Dmax= 7.8e-04 nm, Epot= -1.41005e+05 Fmax= 3.14425e+02, atom= 7333
# Step=  497, Dmax= 9.4e-04 nm, Epot= -1.41013e+05 Fmax= 2.53643e+02, atom= 4237
# Step=  499, Dmax= 5.6e-04 nm, Epot= -1.41026e+05 Fmax= 2.22379e+02, atom= 7633
# Step=  500, Dmax= 6.7e-04 nm, Epot= -1.41029e+05 Fmax= 2.44656e+02, atom= 5989
# Step=  501, Dmax= 8.1e-04 nm, Epot= -1.41032e+05 Fmax= 3.49625e+02, atom= 1327
# Step=  502, Dmax= 9.7e-04 nm, Epot= -1.41044e+05 Fmax= 2.36379e+02, atom= 730
# Step=  504, Dmax= 5.8e-04 nm, Epot= -1.41054e+05 Fmax= 2.19782e+02, atom= 4234
# Step=  505, Dmax= 7.0e-04 nm, Epot= -1.41055e+05 Fmax= 2.87636e+02, atom= 4801
# Step=  506, Dmax= 8.4e-04 nm, Epot= -1.41062e+05 Fmax= 2.70124e+02, atom= 6256
# Step=  507, Dmax= 1.0e-03 nm, Epot= -1.41063e+05 Fmax= 3.43308e+02, atom= 4132
# Step=  508, Dmax= 1.2e-03 nm, Epot= -1.41073e+05 Fmax= 2.87489e+02, atom= 3952
# Step=  510, Dmax= 7.2e-04 nm, Epot= -1.41089e+05 Fmax= 2.58487e+02, atom= 7785
# Step=  511, Dmax= 8.7e-04 nm, Epot= -1.41092e+05 Fmax= 2.59188e+02, atom= 6079
# Step=  513, Dmax= 5.2e-04 nm, Epot= -1.41104e+05 Fmax= 2.30520e+02, atom= 4576
# Step=  514, Dmax= 6.3e-04 nm, Epot= -1.41106e+05 Fmax= 2.46580e+02, atom= 5641
# Step=  515, Dmax= 7.5e-04 nm, Epot= -1.41108e+05 Fmax= 2.63650e+02, atom= 4801
# Step=  516, Dmax= 9.0e-04 nm, Epot= -1.41113e+05 Fmax= 3.39373e+02, atom= 4132
# Step=  517, Dmax= 1.1e-03 nm, Epot= -1.41122e+05 Fmax= 2.74595e+02, atom= 6079
# Step=  519, Dmax= 6.5e-04 nm, Epot= -1.41135e+05 Fmax= 2.59810e+02, atom= 6079
# Step=  520, Dmax= 7.8e-04 nm, Epot= -1.41138e+05 Fmax= 2.77157e+02, atom= 6079
# Step=  521, Dmax= 9.3e-04 nm, Epot= -1.41140e+05 Fmax= 2.64553e+02, atom= 6079
# Step=  523, Dmax= 5.6e-04 nm, Epot= -1.41155e+05 Fmax= 2.26943e+02, atom= 3721
# Step=  524, Dmax= 6.7e-04 nm, Epot= -1.41157e+05 Fmax= 2.61737e+02, atom= 2584
# Step=  525, Dmax= 8.1e-04 nm, Epot= -1.41161e+05 Fmax= 2.43474e+02, atom= 7784
# Step=  527, Dmax= 4.8e-04 nm, Epot= -1.41174e+05 Fmax= 2.48387e+02, atom= 6985
# Step=  528, Dmax= 5.8e-04 nm, Epot= -1.41178e+05 Fmax= 2.83952e+02, atom= 4132
# Step=  529, Dmax= 7.0e-04 nm, Epot= -1.41180e+05 Fmax= 2.58299e+02, atom= 6079
# Step=  531, Dmax= 4.2e-04 nm, Epot= -1.41190e+05 Fmax= 2.13072e+02, atom= 7189
# Step=  532, Dmax= 5.0e-04 nm, Epot= -1.41192e+05 Fmax= 2.67704e+02, atom= 5584
# Step=  533, Dmax= 6.0e-04 nm, Epot= -1.41195e+05 Fmax= 2.76915e+02, atom= 3019
# Step=  534, Dmax= 7.2e-04 nm, Epot= -1.41198e+05 Fmax= 2.91746e+02, atom= 7785
# Step=  535, Dmax= 8.7e-04 nm, Epot= -1.41201e+05 Fmax= 2.50408e+02, atom= 2932
# Step=  537, Dmax= 5.2e-04 nm, Epot= -1.41214e+05 Fmax= 2.39930e+02, atom= 7264
# Step=  538, Dmax= 6.3e-04 nm, Epot= -1.41217e+05 Fmax= 3.54282e+02, atom= 4132
# Step=  539, Dmax= 7.5e-04 nm, Epot= -1.41223e+05 Fmax= 2.57916e+02, atom= 6100
# Step=  541, Dmax= 4.5e-04 nm, Epot= -1.41230e+05 Fmax= 2.48071e+02, atom= 4375
# Step=  542, Dmax= 5.4e-04 nm, Epot= -1.41232e+05 Fmax= 2.55942e+02, atom= 6079
# Step=  543, Dmax= 6.5e-04 nm, Epot= -1.41233e+05 Fmax= 2.86489e+02, atom= 4132
# Step=  544, Dmax= 7.8e-04 nm, Epot= -1.41237e+05 Fmax= 2.69700e+02, atom= 1327
# Step=  545, Dmax= 9.3e-04 nm, Epot= -1.41237e+05 Fmax= 2.92073e+02, atom= 4132
# Step=  546, Dmax= 1.1e-03 nm, Epot= -1.41242e+05 Fmax= 2.82412e+02, atom= 6256
# Step=  548, Dmax= 6.7e-04 nm, Epot= -1.41261e+05 Fmax= 2.60874e+02, atom= 5512
# Step=  549, Dmax= 8.1e-04 nm, Epot= -1.41266e+05 Fmax= 2.88179e+02, atom= 7333
# Step=  550, Dmax= 9.7e-04 nm, Epot= -1.41267e+05 Fmax= 2.54088e+02, atom= 2629
# Step=  552, Dmax= 5.8e-04 nm, Epot= -1.41282e+05 Fmax= 2.32163e+02, atom= 7735
# Step=  553, Dmax= 7.0e-04 nm, Epot= -1.41284e+05 Fmax= 2.58863e+02, atom= 7785
# Step=  554, Dmax= 8.4e-04 nm, Epot= -1.41286e+05 Fmax= 2.85442e+02, atom= 7333
# Step=  555, Dmax= 1.0e-03 nm, Epot= -1.41292e+05 Fmax= 3.63294e+02, atom= 4132
# Step=  556, Dmax= 1.2e-03 nm, Epot= -1.41301e+05 Fmax= 2.61496e+02, atom= 6079
# Step=  558, Dmax= 7.2e-04 nm, Epot= -1.41313e+05 Fmax= 2.36179e+02, atom= 7735
# Step=  560, Dmax= 4.3e-04 nm, Epot= -1.41322e+05 Fmax= 2.22034e+02, atom= 2557
# Step=  561, Dmax= 5.2e-04 nm, Epot= -1.41326e+05 Fmax= 2.55176e+02, atom= 2620
# Step=  562, Dmax= 6.2e-04 nm, Epot= -1.41330e+05 Fmax= 2.47594e+02, atom= 649
# Step=  563, Dmax= 7.5e-04 nm, Epot= -1.41332e+05 Fmax= 2.89254e+02, atom= 4132
# Step=  564, Dmax= 9.0e-04 nm, Epot= -1.41336e+05 Fmax= 2.85817e+02, atom= 7333
# Step=  565, Dmax= 1.1e-03 nm, Epot= -1.41338e+05 Fmax= 3.12882e+02, atom= 6115
# Step=  566, Dmax= 1.3e-03 nm, Epot= -1.41342e+05 Fmax= 3.06922e+02, atom= 6892
# Step=  567, Dmax= 1.6e-03 nm, Epot= -1.41344e+05 Fmax= 3.56979e+02, atom= 4132
# Step=  568, Dmax= 1.9e-03 nm, Epot= -1.41351e+05 Fmax= 3.06918e+02, atom= 5722
# Step=  570, Dmax= 1.1e-03 nm, Epot= -1.41381e+05 Fmax= 2.54806e+02, atom= 6100
# Step=  572, Dmax= 6.7e-04 nm, Epot= -1.41394e+05 Fmax= 1.95511e+02, atom= 5512
# Step=  574, Dmax= 4.0e-04 nm, Epot= -1.41401e+05 Fmax= 2.07613e+02, atom= 2932
# Step=  575, Dmax= 4.8e-04 nm, Epot= -1.41406e+05 Fmax= 2.54942e+02, atom= 7793
# Step=  576, Dmax= 5.8e-04 nm, Epot= -1.41411e+05 Fmax= 2.30481e+02, atom= 7784
# Step=  577, Dmax= 7.0e-04 nm, Epot= -1.41411e+05 Fmax= 2.97338e+02, atom= 4879
# Step=  578, Dmax= 8.3e-04 nm, Epot= -1.41418e+05 Fmax= 2.57914e+02, atom= 2536
# Step=  580, Dmax= 5.0e-04 nm, Epot= -1.41429e+05 Fmax= 2.08954e+02, atom= 2077
# Step=  581, Dmax= 6.0e-04 nm, Epot= -1.41431e+05 Fmax= 2.57516e+02, atom= 7132
# Step=  582, Dmax= 7.2e-04 nm, Epot= -1.41434e+05 Fmax= 2.73627e+02, atom= 7132
# Step=  583, Dmax= 8.7e-04 nm, Epot= -1.41438e+05 Fmax= 3.17127e+02, atom= 6430
# Step=  584, Dmax= 1.0e-03 nm, Epot= -1.41443e+05 Fmax= 2.83811e+02, atom= 6079
# Step=  586, Dmax= 6.2e-04 nm, Epot= -1.41457e+05 Fmax= 1.98810e+02, atom= 4204
# Step=  588, Dmax= 3.7e-04 nm, Epot= -1.41463e+05 Fmax= 2.29462e+02, atom= 4828
# Step=  589, Dmax= 4.5e-04 nm, Epot= -1.41466e+05 Fmax= 3.12473e+02, atom= 6256
# Step=  590, Dmax= 5.4e-04 nm, Epot= -1.41471e+05 Fmax= 2.78981e+02, atom= 6430
# Step=  591, Dmax= 6.5e-04 nm, Epot= -1.41472e+05 Fmax= 2.59314e+02, atom= 7793
# Step=  593, Dmax= 3.9e-04 nm, Epot= -1.41479e+05 Fmax= 2.78400e+02, atom= 5719
# Step=  594, Dmax= 4.7e-04 nm, Epot= -1.41482e+05 Fmax= 2.49803e+02, atom= 3952
# Step=  596, Dmax= 2.8e-04 nm, Epot= -1.41487e+05 Fmax= 2.34091e+02, atom= 7078
# Step=  597, Dmax= 3.3e-04 nm, Epot= -1.41489e+05 Fmax= 2.21001e+02, atom= 7785
# Step=  599, Dmax= 2.0e-04 nm, Epot= -1.41493e+05 Fmax= 2.42690e+02, atom= 6079
# Step=  600, Dmax= 2.4e-04 nm, Epot= -1.41495e+05 Fmax= 2.24136e+02, atom= 6256
# Step=  601, Dmax= 2.9e-04 nm, Epot= -1.41495e+05 Fmax= 2.29648e+02, atom= 6256
# Step=  602, Dmax= 3.5e-04 nm, Epot= -1.41496e+05 Fmax= 2.55277e+02, atom= 2536
# Step=  603, Dmax= 4.2e-04 nm, Epot= -1.41498e+05 Fmax= 2.28080e+02, atom= 6256
# Step=  605, Dmax= 2.5e-04 nm, Epot= -1.41504e+05 Fmax= 2.58272e+02, atom= 7793
# Step=  606, Dmax= 3.0e-04 nm, Epot= -1.41506e+05 Fmax= 2.53289e+02, atom= 2356
# Step=  607, Dmax= 3.6e-04 nm, Epot= -1.41507e+05 Fmax= 2.50115e+02, atom= 6540
# Step=  608, Dmax= 4.3e-04 nm, Epot= -1.41508e+05 Fmax= 3.08605e+02, atom= 6892
# Step=  609, Dmax= 5.2e-04 nm, Epot= -1.41511e+05 Fmax= 2.46562e+02, atom= 6540
# Step=  611, Dmax= 3.1e-04 nm, Epot= -1.41517e+05 Fmax= 3.10593e+02, atom= 6256
# Step=  612, Dmax= 3.7e-04 nm, Epot= -1.41520e+05 Fmax= 3.17889e+02, atom= 1510
# Step=  613, Dmax= 4.5e-04 nm, Epot= -1.41521e+05 Fmax= 2.52080e+02, atom= 4351
# Step=  615, Dmax= 2.7e-04 nm, Epot= -1.41525e+05 Fmax= 2.39190e+02, atom= 6540
# Step=  616, Dmax= 3.2e-04 nm, Epot= -1.41527e+05 Fmax= 2.72614e+02, atom= 6256
# Step=  617, Dmax= 3.9e-04 nm, Epot= -1.41528e+05 Fmax= 2.53754e+02, atom= 2536
# Step=  618, Dmax= 4.6e-04 nm, Epot= -1.41528e+05 Fmax= 3.15056e+02, atom= 6256
# Step=  619, Dmax= 5.6e-04 nm, Epot= -1.41532e+05 Fmax= 3.01310e+02, atom= 5722
# Step=  620, Dmax= 6.7e-04 nm, Epot= -1.41533e+05 Fmax= 3.44352e+02, atom= 7788
# Step=  621, Dmax= 8.0e-04 nm, Epot= -1.41536e+05 Fmax= 2.44169e+02, atom= 1915
# Step=  623, Dmax= 4.8e-04 nm, Epot= -1.41544e+05 Fmax= 3.14003e+02, atom= 6256
# Step=  624, Dmax= 5.8e-04 nm, Epot= -1.41549e+05 Fmax= 2.73058e+02, atom= 6892
# Step=  626, Dmax= 3.5e-04 nm, Epot= -1.41554e+05 Fmax= 2.98451e+02, atom= 5119
# Step=  627, Dmax= 4.2e-04 nm, Epot= -1.41557e+05 Fmax= 3.16971e+02, atom= 1510
# Step=  628, Dmax= 5.0e-04 nm, Epot= -1.41558e+05 Fmax= 2.63471e+02, atom= 916
# Step=  630, Dmax= 3.0e-04 nm, Epot= -1.41563e+05 Fmax= 2.80693e+02, atom= 4132
# Step=  631, Dmax= 3.6e-04 nm, Epot= -1.41564e+05 Fmax= 2.57900e+02, atom= 6256
# Step=  633, Dmax= 2.2e-04 nm, Epot= -1.41568e+05 Fmax= 2.14430e+02, atom= 6540
# Step=  634, Dmax= 2.6e-04 nm, Epot= -1.41569e+05 Fmax= 3.15894e+02, atom= 1510
# Step=  635, Dmax= 3.1e-04 nm, Epot= -1.41572e+05 Fmax= 3.15640e+02, atom= 6256
# Step=  636, Dmax= 3.7e-04 nm, Epot= -1.41573e+05 Fmax= 2.58618e+02, atom= 6256
# Step=  638, Dmax= 2.2e-04 nm, Epot= -1.41576e+05 Fmax= 2.12290e+02, atom= 5389
# Step=  640, Dmax= 1.3e-04 nm, Epot= -1.41578e+05 Fmax= 2.15244e+02, atom= 7021
# Step=  641, Dmax= 1.6e-04 nm, Epot= -1.41579e+05 Fmax= 2.15836e+02, atom= 5002
# Step=  642, Dmax= 1.9e-04 nm, Epot= -1.41580e+05 Fmax= 2.22694e+02, atom= 4828
# Step=  643, Dmax= 2.3e-04 nm, Epot= -1.41580e+05 Fmax= 2.76562e+02, atom= 6379
# Step=  644, Dmax= 2.8e-04 nm, Epot= -1.41582e+05 Fmax= 3.00714e+02, atom= 5722
# Step=  645, Dmax= 3.3e-04 nm, Epot= -1.41584e+05 Fmax= 2.57398e+02, atom= 6256
# Step=  647, Dmax= 2.0e-04 nm, Epot= -1.41587e+05 Fmax= 1.90744e+02, atom= 4768
# Step=  649, Dmax= 1.2e-04 nm, Epot= -1.41589e+05 Fmax= 2.25797e+02, atom= 7630
# Step=  650, Dmax= 1.4e-04 nm, Epot= -1.41590e+05 Fmax= 2.08982e+02, atom= 5581
# Step=  651, Dmax= 1.7e-04 nm, Epot= -1.41590e+05 Fmax= 2.49683e+02, atom= 5389
# Step=  652, Dmax= 2.1e-04 nm, Epot= -1.41591e+05 Fmax= 2.90180e+02, atom= 4132
# Step=  653, Dmax= 2.5e-04 nm, Epot= -1.41593e+05 Fmax= 2.70614e+02, atom= 6079
# Step=  655, Dmax= 1.5e-04 nm, Epot= -1.41595e+05 Fmax= 2.42830e+02, atom= 3895
# Step=  656, Dmax= 1.8e-04 nm, Epot= -1.41596e+05 Fmax= 2.51941e+02, atom= 2719
# Step=  657, Dmax= 2.2e-04 nm, Epot= -1.41596e+05 Fmax= 2.66822e+02, atom= 6892
# Step=  658, Dmax= 2.6e-04 nm, Epot= -1.41597e+05 Fmax= 3.16486e+02, atom= 6256
# Step=  659, Dmax= 3.1e-04 nm, Epot= -1.41598e+05 Fmax= 2.57086e+02, atom= 6256
# Step=  661, Dmax= 1.9e-04 nm, Epot= -1.41602e+05 Fmax= 1.96933e+02, atom= 7784
# Step=  663, Dmax= 1.1e-04 nm, Epot= -1.41604e+05 Fmax= 2.36032e+02, atom= 4828
# Step=  664, Dmax= 1.3e-04 nm, Epot= -1.41604e+05 Fmax= 2.68003e+02, atom= 6256
# Step=  665, Dmax= 1.6e-04 nm, Epot= -1.41605e+05 Fmax= 2.45043e+02, atom= 6256
# Step=  667, Dmax= 9.6e-05 nm, Epot= -1.41607e+05 Fmax= 2.24931e+02, atom= 2875
# Step=  668, Dmax= 1.2e-04 nm, Epot= -1.41607e+05 Fmax= 2.11314e+02, atom= 2077
# Step=  670, Dmax= 6.9e-05 nm, Epot= -1.41608e+05 Fmax= 2.43216e+02, atom= 7786
# Step=  671, Dmax= 8.3e-05 nm, Epot= -1.41609e+05 Fmax= 1.78057e+02, atom= 5450
# Step=  673, Dmax= 5.0e-05 nm, Epot= -1.41610e+05 Fmax= 2.30961e+02, atom= 1510
# Step=  674, Dmax= 6.0e-05 nm, Epot= -1.41610e+05 Fmax= 2.08852e+02, atom= 7784
# Step=  675, Dmax= 7.2e-05 nm, Epot= -1.41610e+05 Fmax= 2.48293e+02, atom= 5389
# Step=  676, Dmax= 8.6e-05 nm, Epot= -1.41611e+05 Fmax= 2.53300e+02, atom= 6256
# Step=  677, Dmax= 1.0e-04 nm, Epot= -1.41611e+05 Fmax= 3.15010e+02, atom= 6256
# Step=  678, Dmax= 1.2e-04 nm, Epot= -1.41612e+05 Fmax= 2.34302e+02, atom= 6256
# Step=  680, Dmax= 7.5e-05 nm, Epot= -1.41613e+05 Fmax= 2.23053e+02, atom= 6540
# Step=  681, Dmax= 9.0e-05 nm, Epot= -1.41613e+05 Fmax= 2.43536e+02, atom= 7786
# Step=  682, Dmax= 1.1e-04 nm, Epot= -1.41613e+05 Fmax= 2.72507e+02, atom= 5512
# Step=  683, Dmax= 1.3e-04 nm, Epot= -1.41614e+05 Fmax= 2.21021e+02, atom= 6540
# Step=  685, Dmax= 7.7e-05 nm, Epot= -1.41615e+05 Fmax= 2.20676e+02, atom= 6540
# Step=  686, Dmax= 9.3e-05 nm, Epot= -1.41616e+05 Fmax= 2.74037e+02, atom= 6256
# Step=  687, Dmax= 1.1e-04 nm, Epot= -1.41616e+05 Fmax= 2.54975e+02, atom= 6256
# Step=  688, Dmax= 1.3e-04 nm, Epot= -1.41617e+05 Fmax= 3.14635e+02, atom= 6256
# Step=  689, Dmax= 1.6e-04 nm, Epot= -1.41618e+05 Fmax= 2.95591e+02, atom= 4132
# Step=  690, Dmax= 1.9e-04 nm, Epot= -1.41618e+05 Fmax= 3.15986e+02, atom= 1510
# Step=  691, Dmax= 2.3e-04 nm, Epot= -1.41618e+05 Fmax= 2.73606e+02, atom= 6379
# Step=  693, Dmax= 1.4e-04 nm, Epot= -1.41621e+05 Fmax= 2.35665e+02, atom= 6540
# Step=  694, Dmax= 1.7e-04 nm, Epot= -1.41621e+05 Fmax= 3.15752e+02, atom= 1510
# Step=  695, Dmax= 2.0e-04 nm, Epot= -1.41622e+05 Fmax= 2.63088e+02, atom= 6540
# Step=  697, Dmax= 1.2e-04 nm, Epot= -1.41624e+05 Fmax= 3.15898e+02, atom= 7786
# Step=  698, Dmax= 1.4e-04 nm, Epot= -1.41625e+05 Fmax= 2.46014e+02, atom= 6540
# Step=  700, Dmax= 8.6e-05 nm, Epot= -1.41626e+05 Fmax= 3.14190e+02, atom= 6256
# Step=  701, Dmax= 1.0e-04 nm, Epot= -1.41627e+05 Fmax= 2.54678e+02, atom= 6256
# Step=  703, Dmax= 6.2e-05 nm, Epot= -1.41628e+05 Fmax= 2.43393e+02, atom= 6540
# Step=  704, Dmax= 7.5e-05 nm, Epot= -1.41628e+05 Fmax= 2.39012e+02, atom= 6540
# Step=  705, Dmax= 8.9e-05 nm, Epot= -1.41628e+05 Fmax= 2.42959e+02, atom= 6540
# Step=  706, Dmax= 1.1e-04 nm, Epot= -1.41628e+05 Fmax= 2.41551e+02, atom= 3895
# Step=  707, Dmax= 1.3e-04 nm, Epot= -1.41628e+05 Fmax= 2.73148e+02, atom= 5512
# Step=  708, Dmax= 1.5e-04 nm, Epot= -1.41629e+05 Fmax= 2.38199e+02, atom= 7784
# Step=  710, Dmax= 9.3e-05 nm, Epot= -1.41631e+05 Fmax= 2.22468e+02, atom= 6540
# Step=  711, Dmax= 1.1e-04 nm, Epot= -1.41632e+05 Fmax= 2.23845e+02, atom= 6540
# Step=  713, Dmax= 6.7e-05 nm, Epot= -1.41633e+05 Fmax= 2.52754e+02, atom= 6256
# Step=  714, Dmax= 8.0e-05 nm, Epot= -1.41633e+05 Fmax= 2.31462e+02, atom= 1510
# Step=  715, Dmax= 9.6e-05 nm, Epot= -1.41633e+05 Fmax= 3.14178e+02, atom= 6256
# Step=  716, Dmax= 1.2e-04 nm, Epot= -1.41635e+05 Fmax= 2.18981e+02, atom= 6540
# Step=  718, Dmax= 6.9e-05 nm, Epot= -1.41635e+05 Fmax= 2.22529e+02, atom= 6540
# Step=  719, Dmax= 8.3e-05 nm, Epot= -1.41636e+05 Fmax= 2.41298e+02, atom= 3895
# Step=  720, Dmax= 1.0e-04 nm, Epot= -1.41636e+05 Fmax= 3.04725e+02, atom= 6256
# Step=  721, Dmax= 1.2e-04 nm, Epot= -1.41637e+05 Fmax= 2.56568e+02, atom= 7786
# Step=  723, Dmax= 7.2e-05 nm, Epot= -1.41638e+05 Fmax= 2.43321e+02, atom= 5389
# Step=  724, Dmax= 8.6e-05 nm, Epot= -1.41638e+05 Fmax= 2.15531e+02, atom= 6540
# Step=  726, Dmax= 5.2e-05 nm, Epot= -1.41639e+05 Fmax= 2.17225e+02, atom= 6540
# Step=  727, Dmax= 6.2e-05 nm, Epot= -1.41640e+05 Fmax= 2.14556e+02, atom= 6540
# Step=  729, Dmax= 3.7e-05 nm, Epot= -1.41640e+05 Fmax= 2.31414e+02, atom= 1510
# Step=  730, Dmax= 4.5e-05 nm, Epot= -1.41640e+05 Fmax= 2.13961e+02, atom= 6540
# Step=  731, Dmax= 5.4e-05 nm, Epot= -1.41640e+05 Fmax= 2.29718e+02, atom= 1510
# Step=  732, Dmax= 6.4e-05 nm, Epot= -1.41641e+05 Fmax= 2.41065e+02, atom= 3895
# Step=  733, Dmax= 7.7e-05 nm, Epot= -1.41641e+05 Fmax= 2.76040e+02, atom= 6079
# Step=  734, Dmax= 9.3e-05 nm, Epot= -1.41641e+05 Fmax= 2.27469e+02, atom= 2620
# Step=  736, Dmax= 5.6e-05 nm, Epot= -1.41642e+05 Fmax= 2.13638e+02, atom= 6540
# Step=  737, Dmax= 6.7e-05 nm, Epot= -1.41643e+05 Fmax= 3.15135e+02, atom= 7786
# Step=  738, Dmax= 8.0e-05 nm, Epot= -1.41643e+05 Fmax= 2.20830e+02, atom= 5263
# Step=  740, Dmax= 4.8e-05 nm, Epot= -1.41644e+05 Fmax= 2.10264e+02, atom= 6540
# Step=  741, Dmax= 5.8e-05 nm, Epot= -1.41644e+05 Fmax= 2.50595e+02, atom= 6540
# Step=  742, Dmax= 6.9e-05 nm, Epot= -1.41645e+05 Fmax= 2.45633e+02, atom= 6540
# Step=  743, Dmax= 8.3e-05 nm, Epot= -1.41645e+05 Fmax= 2.50612e+02, atom= 6540
# Step=  744, Dmax= 1.0e-04 nm, Epot= -1.41645e+05 Fmax= 2.76544e+02, atom= 6079
# Step=  745, Dmax= 1.2e-04 nm, Epot= -1.41646e+05 Fmax= 2.45393e+02, atom= 6256
# Step=  747, Dmax= 7.2e-05 nm, Epot= -1.41647e+05 Fmax= 2.29976e+02, atom= 1510
# Step=  748, Dmax= 8.6e-05 nm, Epot= -1.41647e+05 Fmax= 2.32269e+02, atom= 6540
# Step=  750, Dmax= 5.2e-05 nm, Epot= -1.41648e+05 Fmax= 2.27426e+02, atom= 6540
# Step=  751, Dmax= 6.2e-05 nm, Epot= -1.41649e+05 Fmax= 2.64825e+02, atom= 2875
# Step=  752, Dmax= 7.4e-05 nm, Epot= -1.41649e+05 Fmax= 2.41579e+02, atom= 3895
# Step=  753, Dmax= 8.9e-05 nm, Epot= -1.41649e+05 Fmax= 3.14848e+02, atom= 1510
# Step=  754, Dmax= 1.1e-04 nm, Epot= -1.41650e+05 Fmax= 2.39043e+02, atom= 7774
# Step=  756, Dmax= 6.4e-05 nm, Epot= -1.41651e+05 Fmax= 3.14545e+02, atom= 7786
# Step=  757, Dmax= 7.7e-05 nm, Epot= -1.41651e+05 Fmax= 2.24384e+02, atom= 6540
# Step=  759, Dmax= 4.6e-05 nm, Epot= -1.41652e+05 Fmax= 2.40639e+02, atom= 4723
# Step=  760, Dmax= 5.5e-05 nm, Epot= -1.41652e+05 Fmax= 2.27826e+02, atom= 6540
# Step=  761, Dmax= 6.7e-05 nm, Epot= -1.41652e+05 Fmax= 2.23160e+02, atom= 6540
# Step=  762, Dmax= 8.0e-05 nm, Epot= -1.41652e+05 Fmax= 3.82593e+02, atom= 7786
# Step=  763, Dmax= 9.6e-05 nm, Epot= -1.41653e+05 Fmax= 2.22139e+02, atom= 6540
# Step=  765, Dmax= 5.7e-05 nm, Epot= -1.41654e+05 Fmax= 2.21764e+02, atom= 6540
# Step=  767, Dmax= 3.4e-05 nm, Epot= -1.41654e+05 Fmax= 2.21497e+02, atom= 6540
# Step=  768, Dmax= 4.1e-05 nm, Epot= -1.41655e+05 Fmax= 2.25314e+02, atom= 6540
# Step=  769, Dmax= 5.0e-05 nm, Epot= -1.41655e+05 Fmax= 2.20757e+02, atom= 6540
# Step=  771, Dmax= 3.0e-05 nm, Epot= -1.41656e+05 Fmax= 2.20597e+02, atom= 6540
# Step=  772, Dmax= 3.6e-05 nm, Epot= -1.41656e+05 Fmax= 2.32555e+02, atom= 6540
# Step=  773, Dmax= 4.3e-05 nm, Epot= -1.41656e+05 Fmax= 2.20007e+02, atom= 6540
# Step=  775, Dmax= 2.6e-05 nm, Epot= -1.41656e+05 Fmax= 2.30721e+02, atom= 1510
# Step=  776, Dmax= 3.1e-05 nm, Epot= -1.41657e+05 Fmax= 2.73733e+02, atom= 5512
# Step=  778, Dmax= 1.9e-05 nm, Epot= -1.41657e+05 Fmax= 2.23569e+02, atom= 6540
# Step=  779, Dmax= 2.2e-05 nm, Epot= -1.41657e+05 Fmax= 2.19361e+02, atom= 5263
# Step=  780, Dmax= 2.7e-05 nm, Epot= -1.41657e+05 Fmax= 2.23162e+02, atom= 6540
# Step=  782, Dmax= 1.6e-05 nm, Epot= -1.41658e+05 Fmax= 2.19014e+02, atom= 6540
# Step=  784, Dmax= 9.6e-06 nm, Epot= -1.41658e+05 Fmax= 2.18947e+02, atom= 6540
# Step=  785, Dmax= 1.2e-05 nm, Epot= -1.41658e+05 Fmax= 2.18868e+02, atom= 6540
# Step=  786, Dmax= 1.4e-05 nm, Epot= -1.41658e+05 Fmax= 2.31025e+02, atom= 6540
# Step=  787, Dmax= 1.7e-05 nm, Epot= -1.41658e+05 Fmax= 2.18664e+02, atom= 6540
# Step=  789, Dmax= 1.0e-05 nm, Epot= -1.41658e+05 Fmax= 2.18592e+02, atom= 6540
# Step=  792, Dmax= 3.0e-06 nm, Epot= -1.41658e+05 Fmax= 2.18569e+02, atom= 6540
# Step=  793, Dmax= 3.6e-06 nm, Epot= -1.41658e+05 Fmax= 2.18550e+02, atom= 6540
# Step=  794, Dmax= 4.3e-06 nm, Epot= -1.41658e+05 Fmax= 2.18519e+02, atom= 6540
# Step=  795, Dmax= 5.2e-06 nm, Epot= -1.41658e+05 Fmax= 2.18484e+02, atom= 6540
# Step=  797, Dmax= 3.1e-06 nm, Epot= -1.41658e+05 Fmax= 2.18466e+02, atom= 6540
# Step=  799, Dmax= 1.9e-06 nm, Epot= -1.41658e+05 Fmax= 2.22448e+02, atom= 6540
# Energy minimization has stopped, but the forces have not converged to the
# requested precision Fmax < 10 (which may not be possible for your system). It
# stopped because the algorithm tried to make a new step whose size was too
# small, or there was no change in the energy since last step. Either way, we
# regard the minimization as converged to within the available machine
# precision, given your starting configuration and EM parameters.
#
# Double precision normally gives you higher accuracy, but this is often not
# needed for preparing to run molecular dynamics.
# You might need to increase your constraint accuracy, or turn
# off constraints altogether (set constraints = none in mdp file)
#
# writing lowest energy coordinates.
#
# Steepest Descents did not converge to Fmax < 10 in 800 steps.
# Potential Energy  = -1.4165833e+05
# Maximum force     =  2.1846573e+02 on atom 6540
# Norm of force     =  3.1543871e+01
#
# GROMACS reminds you: "Every Sperm is Sacred" (Monty Python)
